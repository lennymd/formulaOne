# %% [markdown]
# # Looking for the best Formula 1 season
#
# For my master's project, I'm making a piece about answering the question: **What championship winning team had the best Formula 1 season?**
#
# To do this I was working with data provided by the [Ergast Developer API](https://ergast.com/mrd/). I noticed an error in the driver-constructor pairing for the 1950 season and wanted to verify things without moving forward. I was originally going to create a table of the driver-constructor pairs for each race, and then compare it with the data I had.
#
# Instead I've chosen to go straight to the source for F1 information ([formula1.com](https://formula1.com)) and scrape the race results for each race. I did this scraping on 2019-06-21 and 2019-06-22 and I'll be now working with that data to do my analysis.
#
# Because it is data from a primary-source, I have some more confidence in it.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# The first thing to do is to import the data

# %%
race_results = pd.read_csv("../formula1-data/results_all.csv")

# %%
race_results.head()
# Out:
#    raceId  year  raceRound         date           prix driverFirstName  \
# 0       1  1950          1  13 May 1950  Great Britain            Nino
# 1       1  1950          1  13 May 1950  Great Britain           Luigi
# 2       1  1950          1  13 May 1950  Great Britain             Reg
# 3       1  1950          1  13 May 1950  Great Britain     Yves Giraud
# 4       1  1950          1  13 May 1950  Great Britain           Louis
#
#   driverLastName driverCode  constructor finishingPosition  positionOrder  \
# 0         Farina        FAR   Alfa Romeo                 1              1
# 1        Fagioli        FAG   Alfa Romeo                 2              2
# 2        Parnell        PAR   Alfa Romeo                 3              3
# 3      Cabantous        CAB  Talbot-Lago                 4              4
# 4         Rosier        ROS  Talbot-Lago                 5              5
#
#    laps         time  points
# 0  70.0  2:13:23.600     9.0
# 1  70.0      +2.600s     6.0
# 2  70.0     +52.000s     4.0
# 3  68.0      +2 laps     3.0
# 4  68.0      +2 laps     2.0

# %%
race_results.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22598 entries, 0 to 22597
# Data columns (total 14 columns):
# raceId               22598 non-null int64
# year                 22598 non-null int64
# raceRound            22598 non-null int64
# date                 22598 non-null object
# prix                 22598 non-null object
# driverFirstName      22598 non-null object
# driverLastName       22598 non-null object
# driverCode           22598 non-null object
# constructor          22572 non-null object
# finishingPosition    22598 non-null object
# positionOrder        22598 non-null int64
# laps                 22365 non-null float64
# time                 22590 non-null object
# points               22598 non-null float64
# dtypes: float64(2), int64(4), object(8)
# memory usage: 2.4+ MB

# %% [markdown]
# Let's also check how many races we have:

# %%
race_results.raceId.max()
# Out:
# 1007

# %% [markdown]
# Things seem to be in good order. For most of the work, I won't particularly care for a few of the columns, namely:
#
# * laps
# * points
# * driverCode
# * date
#
# So, let's drop those:

# %%
results = race_results.copy().drop(columns=["date", "laps", "points", "driverCode"])
results = results[results.year < 2019]

# %%
results.head()
# Out:
#    raceId  year  raceRound           prix driverFirstName driverLastName  \
# 0       1  1950          1  Great Britain            Nino         Farina
# 1       1  1950          1  Great Britain           Luigi        Fagioli
# 2       1  1950          1  Great Britain             Reg        Parnell
# 3       1  1950          1  Great Britain     Yves Giraud      Cabantous
# 4       1  1950          1  Great Britain           Louis         Rosier
#
#    constructor finishingPosition  positionOrder         time
# 0   Alfa Romeo                 1              1  2:13:23.600
# 1   Alfa Romeo                 2              2      +2.600s
# 2   Alfa Romeo                 3              3     +52.000s
# 3  Talbot-Lago                 4              4      +2 laps
# 4  Talbot-Lago                 5              5      +2 laps

# %% [markdown]
# For most of my analysis, I'm looking only at the teams that won championships, so let's slice the results table and keep only the different championship runs.

# %%
teams = pd.read_csv("../formula1-data/championship_teams.csv")

# %%
teams.head()
# Out:
#    year constructor
# 0  1950  Alfa Romeo
# 1  1951  Alfa Romeo
# 2  1952     Ferrari
# 3  1953     Ferrari
# 4  1954    Mercedes

# %%
results.constructor.unique()
# Out:
# array(['Alfa Romeo', 'Talbot-Lago', 'ERA', 'Maserati', 'Alta', 'Ferrari',
#        'Simca-Gordini', 'Cooper JAP', 'Kurtis Kraft Offenhauser',
#        'Deidt Offenhauser', 'Moore Offenhauser', 'Lesovsky Offenhauser',
#        'Nichels Offenhauser', 'Marchese Offenhauser',
#        'Stevens Offenhauser', 'Langley Offenhauser', 'Ewing Offenhauser',
#        'Maserati Offenhauser', 'Rae Offenhauser', 'Olson Offenhauser',
#        'Wetteroth Offerhauser', 'Snowberger Offenhauser',
#        'Adams Offenhauser', 'Kurtis Kraft Cummins', 'Watson Offenhauser',
#        'Maserati Milano', 'Ferrari Jaguar', 'HWM Alta', 'Veritas',
#        'Sherman Offenhauser', 'Schroeder Offenhauser',
#        'Kurtis Kraft Novi', 'Kuzma Offenhauser', 'Pawl Offenhauser',
#        'Hall Offenhauser', 'Bromme Offenhauser', 'Trevis Offenhauser',
#        'Maserati-Offenhauser', 'Thin Wall Ferrari', 'BRM', 'OSCA',
#        'Maserati OSCA', 'Gordini', 'Frazer Nash', 'Cooper Bristol',
#        'Maserati Plate', 'AFM Kuchen', 'Aston Butterworth', 'ERA Bristol',
#        'Connaught Lea Francis', 'Frazer Nash Bristol', 'AFM BMW', 'BMW',
#        'Turner Offenhauser', 'Del Roy Offenhauser', 'Cooper Alta', 'EMW',
#        'AFM Bristol', 'Phillips Offenhauser', 'Pankratz Offenhauser',
#        'Mercedes-Benz', 'Vanwall', 'Klenk BMW', 'Lancia',
#        'Epperly Offenhauser', 'Connaught Alta', 'Bugatti',
#        'Emeryson Alta', 'Cooper Climax', 'Dunn Offenhauser',
#        'Porsche (F2)', 'Lotus Climax', 'Porsche', 'Cooper Maserati',
#        'Elder Offenhauser', 'Christensen Offenhauser',
#        'Sutton Offenhauser', 'Aston Martin', 'Cooper Borgward',
#        'JBW Maserati', 'Cooper OSCA', 'Tec-Mec Maserati', 'Behra-Porsche',
#        'Meskowski Offenhauser', 'Scarab', 'Cooper Castellotti',
#        'BRM Climax', 'De Tomaso OSCA', 'Gilby Climax', 'Ferguson Climax',
#        'Lotus Maserati', 'De Tomaso Alfa Romeo', 'JBW Climax',
#        'Emeryson Climax', 'Lola Climax', 'Lotus BRM', 'ENB Maserati',
#        'Brabham Climax', 'Gilby BRM', 'LDS Alfa Romeo',
#        'Cooper Alfa Romeo', 'Scirocco BRM', 'ATS', 'BRP BRM', nan,
#        'Stebro Ford', 'Lotus Ford', 'Brabham Ford', 'Brabham BRM',
#        'Scirocco Climax', 'Cooper Ford', 'Honda',
#        'Derrington-Francis ATS', 'Brabham Repco', 'McLaren Ford',
#        'Eagle Climax', 'McLaren Serenissima', 'Cooper Ferrari',
#        'Shannon Climax', 'Matra BRM', 'Matra Cosworth', 'Eagle Weslake',
#        'LDS Climax', 'McLaren BRM', 'Matra Ford', 'Cooper ATS',
#        'Lola BMW', 'Mclaren BRM', 'LDS Repco', 'Cooper BRM', 'Matra',
#        'March Ford', 'De Tomaso Ford', 'McLaren Alfa Romeo',
#        'Surtees Ford', 'Bellasi Ford', 'Tyrrell Ford', 'March Alfa Romeo',
#        'Lotus Pratt & Whitney', 'Eifelland Ford', 'Tecno',
#        'Politoys Ford', 'Connew Ford', 'Iso Marlboro Ford', 'Shadow Ford',
#        'Ensign Ford', 'Lola Ford', 'Hesketh Ford', 'Trojan Ford',
#        'Amon Ford', 'Token Ford', 'Parnelli Ford', 'Penske Ford',
#        'Frank Williams Racing Cars/Williams', 'Fittipaldi Ford',
#        'Hill Ford', 'Lyncar Ford', 'Shadow Matra', 'Wolf-Williams',
#        'Brabham Alfa Romeo', 'Ligier Matra', 'Boro Ford', 'Kojima Ford',
#        'Wolf Ford', 'LEC Ford', 'Renault', 'ATS Ford', 'Williams Ford',
#        'Merzario Ford', 'Arrows Ford', 'Theodore Ford', 'Martini Ford',
#        'Ligier Ford', 'Rebaque Ford', 'Osella Ford', 'Osella Hart',
#        'Toleman Hart', 'Brabham BMW', 'RAM Ford', 'ATS BMW',
#        'Lotus Renault', 'Osella Alfa Romeo', 'Spirit Honda',
#        'McLaren TAG', 'Williams Honda', 'RAM Hart', 'Ligier Renault',
#        'Spirit Hart', 'Arrows BMW', 'Minardi Ford', 'Zakspeed',
#        'Minardi Motori Moderni', 'Tyrrell Renault', 'Lola Hart',
#        'Benetton BMW', 'AGS Motori Moderni', 'Benetton Ford',
#        'Lotus Honda', 'AGS Ford', 'Arrows Megatron', 'Ligier Megatron',
#        'Coloni Ford', 'McLaren Honda', 'Ligier Judd', 'Rial Ford',
#        'Euro Brun Ford', 'Williams Judd', 'March Judd', 'Dallara Ford',
#        'Osella', 'Lotus Judd', 'Lola Lamborghini', 'Williams Renault',
#        'Zakspeed Yamaha', 'Brabham Judd', 'Onyx Ford', 'Euro Brun Judd',
#        'Leyton House Judd', 'Lotus Lamborghini', 'Tyrrell Honda',
#        'Lambo Lamborghini', 'Minardi Ferrari', 'Jordan Ford',
#        'Brabham Yamaha', 'Footwork Porsche', 'Leyton House Ilmor',
#        'Ligier Lamborghini', 'Dallara Judd', 'Fondmetal Ford',
#        'Footwork Mugen Honda', 'Jordan Yamaha', 'Venturi Lamborghini',
#        'Tyrrell Ilmor', 'Dallara Ferrari', 'Minardi Lamborghini',
#        'March Ilmor', 'Moda Judd', 'Sauber', 'Lola Ferrari',
#        'Larrousse Lamborghini', 'Jordan Hart', 'Tyrrell Yamaha',
#        'Sauber Mercedes', 'Lotus Mugen Honda', 'Larrousse Ford',
#        'Simtek Ford', 'McLaren Peugeot', 'Footwork Ford', 'Pacific Ilmor',
#        'Benetton Renault', 'McLaren Mercedes', 'Ligier Mugen Honda',
#        'Forti Ford', 'Footwork Hart', 'Sauber Ford', 'Jordan Peugeot',
#        'Prost Mugen Honda', 'Sauber Petronas', 'Minardi Hart',
#        'Arrows Yamaha', 'Stewart Ford', 'Williams Mecachrome',
#        'Benetton Playlife', 'Jordan Mugen Honda', 'Prost Peugeot',
#        'Arrows', 'Williams Supertec', 'BAR Supertec', 'Williams BMW',
#        'BAR Honda', 'Minardi Fondmetal', 'Arrows Supertec',
#        'Jaguar Cosworth', 'Jordan Honda', 'Prost Acer', 'Arrows Asiatech',
#        'Minardi European', 'Minardi Asiatech', 'Toyota',
#        'Arrows Cosworth', 'Minardi Cosworth', 'RBR Cosworth',
#        'Jordan Toyota', 'Williams Cosworth', 'RBR Ferrari',
#        'STR Cosworth', 'Sauber BMW', 'MF1 Toyota', 'Super Aguri Honda',
#        'Williams Toyota', 'Red Bull Renault', 'STR Ferrari',
#        'Spyker Ferrari', 'Force India Ferrari', 'Brawn Mercedes',
#        'Force India Mercedes', 'RBR Renault', 'Mercedes',
#        'Lotus Cosworth', 'Sauber Ferrari', 'HRT Cosworth',
#        'Virgin Cosworth', 'Red Bull Racing Renault', 'Marussia Cosworth',
#        'Caterham Renault', 'Williams Mercedes', 'STR Renault',
#        'Marussia Ferrari', 'Lotus Mercedes', 'Red Bull Racing TAG Heuer',
#        'Haas Ferrari', 'Toro Rosso Ferrari', 'MRT Mercedes', 'Toro Rosso',
#        'McLaren Renault', 'Scuderia Toro Rosso Honda'], dtype=object)
