# %% [markdown]
# # Exploring the results table
#
# For my visualization I need to figure out two things from the results table:
#
# 1. The wins each team had in a season (which grand prix, which driver)
# 1. The reasons a team retired from a race during the season (which grand prix, which driver, which reason)
#
# Of the two, the first seems quicker to tackle

# %%
import pandas as pd
import numpy as np

# %%
results = pd.read_csv("../data/f1db_results.csv").sort_values("raceId2")

# %%
results.head()
# Out:
#     raceId2            prixName  year  round    prixDate constructorName  \
# 0         1  British Grand Prix  1950      1  1950-05-13      Alfa Romeo
# 22        1  British Grand Prix  1950      1  1950-05-13             ERA
# 21        1  British Grand Prix  1950      1  1950-05-13             ERA
# 20        1  British Grand Prix  1950      1  1950-05-13             ERA
# 19        1  British Grand Prix  1950      1  1950-05-13     Talbot-Lago
#
#         driverName  grid positionText  positionOrder  points        status
# 0      Nino Farina     1            1              1     9.0      Finished
# 22  Leslie Johnson    12            R             21     0.0  Supercharger
# 21    Peter Walker    10            R             20     0.0       Gearbox
# 20       Tony Rolt    10            R             20     0.0       Gearbox
# 19   Eugène Martin     7            R             19     0.0  Oil pressure

# %%
results.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 24277 entries, 0 to 24276
# Data columns (total 12 columns):
# raceId2            24277 non-null int64
# prixName           24277 non-null object
# year               24277 non-null int64
# round              24277 non-null int64
# prixDate           24277 non-null object
# constructorName    24277 non-null object
# driverName         24277 non-null object
# grid               24277 non-null int64
# positionText       24277 non-null object
# positionOrder      24277 non-null int64
# points             24277 non-null float64
# status             24277 non-null object
# dtypes: float64(1), int64(5), object(6)
# memory usage: 2.4+ MB

# %%
results[results.year == 2018]
# Out:
#        raceId2               prixName  year  round    prixDate  \
# 23789      977  Australian Grand Prix  2018      1  2018-03-25
# 23790      977  Australian Grand Prix  2018      1  2018-03-25
# 23791      977  Australian Grand Prix  2018      1  2018-03-25
# 23792      977  Australian Grand Prix  2018      1  2018-03-25
# 23796      977  Australian Grand Prix  2018      1  2018-03-25
# 23794      977  Australian Grand Prix  2018      1  2018-03-25
# 23795      977  Australian Grand Prix  2018      1  2018-03-25
# 23788      977  Australian Grand Prix  2018      1  2018-03-25
# 23793      977  Australian Grand Prix  2018      1  2018-03-25
# 23787      977  Australian Grand Prix  2018      1  2018-03-25
# 23777      977  Australian Grand Prix  2018      1  2018-03-25
# 23785      977  Australian Grand Prix  2018      1  2018-03-25
# 23778      977  Australian Grand Prix  2018      1  2018-03-25
# 23779      977  Australian Grand Prix  2018      1  2018-03-25
# 23780      977  Australian Grand Prix  2018      1  2018-03-25
# 23786      977  Australian Grand Prix  2018      1  2018-03-25
# 23782      977  Australian Grand Prix  2018      1  2018-03-25
# 23783      977  Australian Grand Prix  2018      1  2018-03-25
# 23784      977  Australian Grand Prix  2018      1  2018-03-25
# 23781      977  Australian Grand Prix  2018      1  2018-03-25
# 23808      978     Bahrain Grand Prix  2018      2  2018-04-08
# 23815      978     Bahrain Grand Prix  2018      2  2018-04-08
# 23814      978     Bahrain Grand Prix  2018      2  2018-04-08
# 23813      978     Bahrain Grand Prix  2018      2  2018-04-08
# 23812      978     Bahrain Grand Prix  2018      2  2018-04-08
# 23811      978     Bahrain Grand Prix  2018      2  2018-04-08
# 23810      978     Bahrain Grand Prix  2018      2  2018-04-08
# 23809      978     Bahrain Grand Prix  2018      2  2018-04-08
# 23816      978     Bahrain Grand Prix  2018      2  2018-04-08
# 23807      978     Bahrain Grand Prix  2018      2  2018-04-08
# ...        ...                    ...   ...    ...         ...
# 24166      996   Brazilian Grand Prix  2018     20  2018-11-11
# 24164      996   Brazilian Grand Prix  2018     20  2018-11-11
# 24163      996   Brazilian Grand Prix  2018     20  2018-11-11
# 24162      996   Brazilian Grand Prix  2018     20  2018-11-11
# 24161      996   Brazilian Grand Prix  2018     20  2018-11-11
# 24160      996   Brazilian Grand Prix  2018     20  2018-11-11
# 24159      996   Brazilian Grand Prix  2018     20  2018-11-11
# 24158      996   Brazilian Grand Prix  2018     20  2018-11-11
# 24157      996   Brazilian Grand Prix  2018     20  2018-11-11
# 24165      996   Brazilian Grand Prix  2018     20  2018-11-11
# 24189      997   Abu Dhabi Grand Prix  2018     21  2018-11-25
# 24190      997   Abu Dhabi Grand Prix  2018     21  2018-11-25
# 24191      997   Abu Dhabi Grand Prix  2018     21  2018-11-25
# 24196      997   Abu Dhabi Grand Prix  2018     21  2018-11-25
# 24195      997   Abu Dhabi Grand Prix  2018     21  2018-11-25
# 24193      997   Abu Dhabi Grand Prix  2018     21  2018-11-25
# 24194      997   Abu Dhabi Grand Prix  2018     21  2018-11-25
# 24188      997   Abu Dhabi Grand Prix  2018     21  2018-11-25
# 24192      997   Abu Dhabi Grand Prix  2018     21  2018-11-25
# 24187      997   Abu Dhabi Grand Prix  2018     21  2018-11-25
# 24181      997   Abu Dhabi Grand Prix  2018     21  2018-11-25
# 24185      997   Abu Dhabi Grand Prix  2018     21  2018-11-25
# 24184      997   Abu Dhabi Grand Prix  2018     21  2018-11-25
# 
# 24182         Renault       Carlos Sainz    11            6              6
# 24180        Red Bull   Daniel Ricciardo     5            4              4
# 24179        Red Bull     Max Verstappen     6            3              3
# 24178         Ferrari   Sebastian Vettel     3            2              2
# 24177        Mercedes     Lewis Hamilton     1            1              1
# 24186    Haas F1 Team    Kevin Magnussen    13           10             10
#
#        points      status
# 23789     0.0    Finished
# 23790     0.0    Finished
# 23791     0.0      +1 Lap
# 23792     0.0       Wheel
# 23796     0.0      Brakes
# 23794     0.0      Engine
# 23795     0.0    Steering
# 23788     0.0    Finished
# 23793     0.0       Wheel
# 23787     0.0    Finished
# 23777    25.0    Finished
# 23785     2.0    Finished
# 23778    18.0    Finished
# 23779    15.0    Finished
# 23780    12.0    Finished
# 23786     1.0    Finished
# 23782     8.0    Finished
# 23783     6.0    Finished
# 23784     4.0    Finished
# 23781    10.0    Finished
# 23808     0.0      +1 Lap
# 23815     0.0    Puncture
# 23814     0.0       Wheel
# 23813     0.0      +1 Lap
# 23812     0.0      +1 Lap
# 23811     0.0      +1 Lap
# 23810     0.0      +1 Lap
# 23809     0.0      +1 Lap
# 23816     0.0  Electrical
# 23807     0.0      +1 Lap
# ...       ...         ...
# 24166     1.0      +1 Lap
# 24164     4.0    Finished
# 24163     6.0    Finished
# 24162     8.0    Finished
# 24161    10.0    Finished
# 24160    12.0    Finished
# 24159    15.0    Finished
# 24158    18.0    Finished
# 24157    25.0    Finished
# 24165     2.0    Finished
# 24189     0.0      +1 Lap
# 24190     0.0      +1 Lap
# 24191     0.0      +1 Lap
# 24196     0.0   Collision
# 24195     0.0  Power loss
# 24193     0.0      Engine
# 24194     0.0  Power loss
# 24188     0.0      +1 Lap
# 24192     0.0      Engine
# 24187     0.0      +1 Lap
# 24181    10.0    Finished
# 24185     2.0      +1 Lap
# 24184     4.0    Finished
# 24183     6.0    Finished
# 24182     8.0    Finished
# 24180    12.0    Finished
# 24179    15.0    Finished
# 24178    18.0    Finished
# 24177    25.0    Finished
# 24186     1.0      +1 Lap
#
# [420 rows x 12 columns]

# %% [markdown]
# Things seem to have loaded up properly. Let's look at 1950

# %%
y1950 = results[results.year == 1950]

# %%
y1950
# Out:
#      raceId2            prixName  year  round    prixDate constructorName  \
# 0          1  British Grand Prix  1950      1  1950-05-13      Alfa Romeo
# 22         1  British Grand Prix  1950      1  1950-05-13             ERA
# 21         1  British Grand Prix  1950      1  1950-05-13             ERA
# 20         1  British Grand Prix  1950      1  1950-05-13             ERA
# 19         1  British Grand Prix  1950      1  1950-05-13     Talbot-Lago
# 18         1  British Grand Prix  1950      1  1950-05-13        Maserati
# 17         1  British Grand Prix  1950      1  1950-05-13        Maserati
# 15         1  British Grand Prix  1950      1  1950-05-13        Maserati
# 14         1  British Grand Prix  1950      1  1950-05-13        Maserati
# 13         1  British Grand Prix  1950      1  1950-05-13            Alta
# 12         1  British Grand Prix  1950      1  1950-05-13      Alfa Romeo
# 16         1  British Grand Prix  1950      1  1950-05-13            Alta
# 10         1  British Grand Prix  1950      1  1950-05-13        Maserati
# 11         1  British Grand Prix  1950      1  1950-05-13     Talbot-Lago
# 2          1  British Grand Prix  1950      1  1950-05-13      Alfa Romeo
# 3          1  British Grand Prix  1950      1  1950-05-13     Talbot-Lago
# 4          1  British Grand Prix  1950      1  1950-05-13     Talbot-Lago
# 5          1  British Grand Prix  1950      1  1950-05-13             ERA
# 1          1  British Grand Prix  1950      1  1950-05-13      Alfa Romeo
# 7          1  British Grand Prix  1950      1  1950-05-13     Talbot-Lago
# 147           Juan Fangio     1            R             15     1.0
# 148          Johnny Claes    22            R             16     0.0
# 149        Alberto Ascari     2            R             17     0.0
# 150    Clemente Biondetti    25            R             18     0.0
# 159        Felice Bonetto    23            W             27     0.0
# 152        Franco Comotti    26            R             20     0.0
# 157           Prince Bira    15            R             25     0.0
# 154          Louis Chiron    19            R             22     0.0
# 155       Consalvo Sanesi     4            R             23     0.0
# 156         Robert Manzon    10            R             24     0.0
# 158          Paul Pietsch    27            R             26     0.0
# 146         Pierre Levegh    20            R             14     0.0
# 153   Maurice Trintignant    12            R             21     0.0
# 145         Piero Taruffi     7            R             13     0.0
# 151         Henri Louveau    16            R             19     0.0
# 143            Franco Rol     9            R             12     0.0
# 131           Nino Farina     3            1              1     8.0
# 144           Juan Fangio     7            R             13     0.0
# 133       Dorino Serafini     6            2              2     3.0
# 134         Luigi Fagioli     5            3              3     4.0
# 135          Louis Rosier    13            4              4     3.0
# 136    Philippe Étancelin    16            5              5     2.0
# 132        Alberto Ascari     6            2              2     3.0
# 138       Peter Whitehead    18            7              7     0.0
# 139          David Murray    24            R              8     0.0
# 140         Cuth Harrison    21            R              9     0.0
# 141        Raymond Sommer     8            R             10     0.0
# 142          Guy Mairesse    11            R             11     0.0
# 137  Toulo de Graffenried    17            6              6     0.0
#
#              status
# 0          Finished
# 22     Supercharger
# 21          Gearbox
# 20          Gearbox
# 19     Oil pressure
# 18           Clutch
# 17           Engine
# 15           Engine
# 14      Out of fuel
# 13   Not classified
# 12         Oil leak
# 16     Transmission
# 10          +6 Laps
# 11          +6 Laps
# 2          Finished
# 3           +2 Laps
# 4           +2 Laps
# 5           +3 Laps
# 1          Finished
# 7           +5 Laps
# 8           +6 Laps
# 9           +6 Laps
# 6           +3 Laps
# 35         Accident
# 43         Accident
# 42           Engine
# 41        Collision
# 40         Accident
# 39         Accident
# 38         Accident
# ..              ...
# 120        +12 Laps
# 147         Gearbox
# 148     Overheating
# 149          Engine
# 150          Engine
# 159        Withdrew
# 152         Retired
# 157          Engine
# 154    Oil pressure
# 155          Engine
# 156    Transmission
# 158          Engine
# 146         Gearbox
# 153      Water pipe
# 145          Engine
# 151          Brakes
# 143         Retired
# 131        Finished
# 144          Engine
# 133        Finished
# 134        Finished
# 135         +5 Laps
# 136         +5 Laps
# 132        Finished
# 138         +8 Laps
# 139         Gearbox
# 140        Radiator
# 141         Gearbox
# 142        Oil pipe
# 137         +8 Laps
#
# [160 rows x 12 columns]

# %% [markdown]
# In 1950, Alfa Romeo's driver Nino Farina won the driver's championship, so let's see how the team did:

# %%
y1950[y1950.constructorName == "Alfa Romeo"]
# Out:
#      raceId2            prixName  year  round    prixDate constructorName  \
# 0          1  British Grand Prix  1950      1  1950-05-13      Alfa Romeo
# 12         1  British Grand Prix  1950      1  1950-05-13      Alfa Romeo
# 2          1  British Grand Prix  1950      1  1950-05-13      Alfa Romeo
# 1          1  British Grand Prix  1950      1  1950-05-13      Alfa Romeo
# 34         2   Monaco Grand Prix  1950      2  1950-05-21      Alfa Romeo
# 33         2   Monaco Grand Prix  1950      2  1950-05-21      Alfa Romeo
# 23         2   Monaco Grand Prix  1950      2  1950-05-21      Alfa Romeo
# 90         4    Swiss Grand Prix  1950      4  1950-06-04      Alfa Romeo
# 80         4    Swiss Grand Prix  1950      4  1950-06-04      Alfa Romeo
# 79         4    Swiss Grand Prix  1950      4  1950-06-04      Alfa Romeo
# 98         5  Belgian Grand Prix  1950      5  1950-06-18      Alfa Romeo
# 100        5  Belgian Grand Prix  1950      5  1950-06-18      Alfa Romeo
# 97         5  Belgian Grand Prix  1950      5  1950-06-18      Alfa Romeo
# 119        6   French Grand Prix  1950      6  1950-07-02      Alfa Romeo
# 112        6   French Grand Prix  1950      6  1950-07-02      Alfa Romeo
# 111        6   French Grand Prix  1950      6  1950-07-02      Alfa Romeo
# 147        7  Italian Grand Prix  1950      7  1950-09-03      Alfa Romeo
# 155        7  Italian Grand Prix  1950      7  1950-09-03      Alfa Romeo
# 145        7  Italian Grand Prix  1950      7  1950-09-03      Alfa Romeo
# 131        7  Italian Grand Prix  1950      7  1950-09-03      Alfa Romeo
# 144        7  Italian Grand Prix  1950      7  1950-09-03      Alfa Romeo
# 134        7  Italian Grand Prix  1950      7  1950-09-03      Alfa Romeo
# 132        7  Italian Grand Prix  1950      7  1950-09-03      Alfa Romeo
#
#           driverName  grid positionText  positionOrder  points     status
# 0        Nino Farina     1            1              1     9.0   Finished
# 12       Juan Fangio     3            R             12     0.0   Oil leak
# 2        Reg Parnell     4            3              3     4.0   Finished
# 1      Luigi Fagioli     2            2              2     6.0   Finished
# 34     Luigi Fagioli     5            R             12     0.0   Accident
# 33       Nino Farina     2            R             11     0.0   Accident
# 23       Juan Fangio     1            1              1     9.0   Finished
# 90       Juan Fangio     1            R             12     0.0     Engine
# 80     Luigi Fagioli     3            2              2     6.0   Finished
# 79       Nino Farina     2            1              1     9.0   Finished
# 98     Luigi Fagioli     3            2              2     6.0   Finished
# 100      Nino Farina     1            4              4     4.0   Finished
# 97       Juan Fangio     2            1              1     8.0   Finished
# 119      Nino Farina     2            7              7     0.0  Fuel pump
# 112    Luigi Fagioli     3            2              2     6.0   Finished
# 111      Juan Fangio     1            1              1     9.0   Finished
# 147      Juan Fangio     1            R             15     1.0    Gearbox
# 155  Consalvo Sanesi     4            R             23     0.0     Engine
# 145    Piero Taruffi     7            R             13     0.0     Engine
# 131      Nino Farina     3            1              1     8.0   Finished
# 144      Juan Fangio     7            R             13     0.0     Engine
# 134    Luigi Fagioli     5            3              3     4.0   Finished
# 132   Alberto Ascari     6            2              2     3.0   Finished

# %%
alfaRomeo1950 = y1950[y1950.constructorName == "Alfa Romeo"]

# %%
alfaRomeo1950_wins = alfaRomeo1950[alfaRomeo1950.positionText == "1"]

# %%
alfaRomeo1950_wins
# Out:
#      raceId2            prixName  year  round    prixDate constructorName  \
# 0          1  British Grand Prix  1950      1  1950-05-13      Alfa Romeo
# 23         2   Monaco Grand Prix  1950      2  1950-05-21      Alfa Romeo
# 79         4    Swiss Grand Prix  1950      4  1950-06-04      Alfa Romeo
# 97         5  Belgian Grand Prix  1950      5  1950-06-18      Alfa Romeo
# 111        6   French Grand Prix  1950      6  1950-07-02      Alfa Romeo
# 131        7  Italian Grand Prix  1950      7  1950-09-03      Alfa Romeo
#
#       driverName  grid positionText  positionOrder  points    status
# 0    Nino Farina     1            1              1     9.0  Finished
# 23   Juan Fangio     1            1              1     9.0  Finished
# 79   Nino Farina     2            1              1     9.0  Finished
# 97   Juan Fangio     2            1              1     8.0  Finished
# 111  Juan Fangio     1            1              1     9.0  Finished
# 131  Nino Farina     3            1              1     8.0  Finished

# %% [markdown]
# So they won everything... but the Indy500... do we have that on here?

# %%
indy500_y1950 = y1950[y1950.raceId2 == 3]

# %%
indy500_y1950
# Out:
#     raceId2          prixName  year  round    prixDate constructorName  \
# 69        3  Indianapolis 500  1950      3  1950-05-30        Maserati
# 64        3  Indianapolis 500  1950      3  1950-05-30        Maserati
# 65        3  Indianapolis 500  1950      3  1950-05-30    Kurtis Kraft
#
# 56       Duane Carter    13           12             12     0.0        +5 Laps
# 57      Mack Hellings    26           13             13     0.0        +6 Laps
# 58       Jack McGrath     6           14             14     0.0       Spun off
# 52      George Connor     4            8              8     0.0        +3 Laps
# 59       Troy Ruttman    24           15             15     0.0        +8 Laps

# %% [markdown]
# It doesn't seem to be like there is an Alfa Romeo entry in the 1950 Indy500. I went to check on [StatsF1](https://www.statsf1.com/en/1950/indianapolis/grille.aspx) and the Wikipedia [entry](https://en.wikipedia.org/wiki/1950_Indianapolis_500) for that specific Indy500. Looking at the qualifiers, there was one entry, but it didn't make it to the grid. So we know that they won 6 of the 7 races.
#
# ---
#
# Can I write something now that takes the results table, the year and the team, and tells me:
#
# * number of rounds in the season
# * number and names of races the team won that year
# * percentage win for the season
#
# There are a few other things I want to summarize:
#
# * the names of the drivers in the season
# * who had the most points from the winning team (a.k.a the champion)
# * what were the reasons why the cars didn't finish the race.
#
# But we'll start with the percentages.

# %% [markdown]
# ## Finding the win percentage of a team during a season
#
# Let's keep playing with the 1950 data to figure out the three things I want:
#
# 1. Number of rounds in the season

# %%
y1950["round"].max()
# Out:
# 7

# %% [markdown]
# 2. (a) number of races the team won that year
#
# Earlier we got the subset of races that a team won in a given year. in our example, Alfa Romeo in 1950.

# %%
alfaRomeo1950_wins
# Out:
#      raceId2            prixName  year  round    prixDate constructorName  \
# 0          1  British Grand Prix  1950      1  1950-05-13      Alfa Romeo
# 23         2   Monaco Grand Prix  1950      2  1950-05-21      Alfa Romeo
# 79         4    Swiss Grand Prix  1950      4  1950-06-04      Alfa Romeo
# 97         5  Belgian Grand Prix  1950      5  1950-06-18      Alfa Romeo
# 111        6   French Grand Prix  1950      6  1950-07-02      Alfa Romeo
# 131        7  Italian Grand Prix  1950      7  1950-09-03      Alfa Romeo
#
#       driverName  grid positionText  positionOrder  points    status
# 0    Nino Farina     1            1              1     9.0  Finished
# 23   Juan Fangio     1            1              1     9.0  Finished
# 79   Nino Farina     2            1              1     9.0  Finished
# 97   Juan Fangio     2            1              1     8.0  Finished
# 111  Juan Fangio     1            1              1     9.0  Finished
# 131  Nino Farina     3            1              1     8.0  Finished

# %%
alfaRomeo1950_wins.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6 entries, 0 to 131
# Data columns (total 12 columns):
# raceId2            6 non-null int64
# prixName           6 non-null object
# year               6 non-null int64
# round              6 non-null int64
# prixDate           6 non-null object
# constructorName    6 non-null object
# driverName         6 non-null object
# grid               6 non-null int64
# positionText       6 non-null object
# positionOrder      6 non-null int64
# points             6 non-null float64
# status             6 non-null object
# dtypes: float64(1), int64(5), object(6)
# memory usage: 624.0+ bytes

# %%
len(alfaRomeo1950_wins.index)
# Out:
# 6

# %% [markdown]
# 2. (b) the names of the races the team won

# %%
alfa_romeo = alfaRomeo1950_wins

# %%
alfa_romeo.prixName
# Out:
# 0      British Grand Prix
# 23      Monaco Grand Prix
# 79       Swiss Grand Prix
# 97     Belgian Grand Prix
# 111     French Grand Prix
# 131    Italian Grand Prix
# Name: prixName, dtype: object

# %% [markdown]
# Cool, now let's make it a list.

# %%
races_won = list(alfa_romeo.prixName)

# %%
races_won
# Out:
# ['British Grand Prix',
#  'Monaco Grand Prix',
#  'Swiss Grand Prix',
#  'Belgian Grand Prix',
#  'French Grand Prix',
#  'Italian Grand Prix']

# %% [markdown]
# I guess I can try adding the year to the name to make sure there are no future duplicates

# %%
year = 1950

for i in range(0,len(races_won)):
    races_won[i] = str(year) + " " + races_won[i]
    print(i+1, races_won[i])
# Out:
# 1 1950 British Grand Prix
# 2 1950 Monaco Grand Prix
# 3 1950 Swiss Grand Prix
# 4 1950 Belgian Grand Prix
# 5 1950 French Grand Prix
# 6 1950 Italian Grand Prix

# %% [markdown]
# Alrighty. now for the quick part:
#
# 3. percentage of race wins
#
# **note**: `len(races_won)` also gives us the same answer as `len(alfaRomeo1950_wins.index)` when looking at how many races won in a season. And it's also shorter, so it might be better to use that:

# %%
races_won
# Out:
# ['1950 British Grand Prix',
#  '1950 Monaco Grand Prix',
#  '1950 Swiss Grand Prix',
#  '1950 Belgian Grand Prix',
#  '1950 French Grand Prix',
#  '1950 Italian Grand Prix']

# %%
rounds = float(y1950["round"].max())
rounds_won = float(len(list(alfa_romeo.prixName)))
team = "Alfa Romeo"
statement = "In "+ str(year) + " the " + team + " team won " + str(rounds_won) + " of " + str(rounds) + " races, " + str(rounds_won / rounds)
print(statement)
# Out:
# In 1950 the Alfa Romeo team won 6.0 of 7.0 races, 0.8571428571428571

# %% [markdown]
# Now can I take this all into a function?

# %%
def race_victories(year, teamName):
    championship = results[results.year == year] #get the right set of races
    team = championship[championship.constructorName == teamName] #get the results for the team in question
    team_wins = team[championship.positionText == "1"] #get all the victories of the team
    
    rounds = championship["round"].max() #how many total races in the season
    
    victories = list(team_wins.prixName) #the list of all races won
    rounds_won = len(victories) #number of races won
    
    dominance = rounds_won / float(rounds)
    return [year, teamName, dominance, rounds, rounds_won, victories]

# %%
race_victories(1950, "Alfa Romeo")
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# [1950,
#  'Alfa Romeo',
#  0.8571428571428571,
#  7,
#  6,
#  ['British Grand Prix',
#   'Monaco Grand Prix',
#   'Swiss Grand Prix',
#   'Belgian Grand Prix',
#   'French Grand Prix',
#   'Italian Grand Prix']]

# %% [markdown]
# From this I can feed it an array of year,team combinations and get the info I want.

# %%
import csv

# %%
with open("../data/teams.csv", "r") as f:
    teams = csv.reader(f)
    constructors = list(teams)

# %%
test = [["year", "team", "dominance %", "rounds", "races won",  "victories"]]
for i in range(1,len(constructors)):
    year = int(constructors[i][0])
    team = str(constructors[i][1])
    line = race_victories(year, team)
    test.append(line)
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.

# %%
constructors[0]
# Out:
# ['year', 'constructor']

# %%
test[0:3]
# Out:
# [['year', 'team', 'dominance %', 'rounds', 'races won', 'victories'],
#  [1950,
#   'Alfa Romeo',
#   0.8571428571428571,
#   7,
#   6,
#   ['British Grand Prix',
#    'Monaco Grand Prix',
#    'Swiss Grand Prix',
#    'Belgian Grand Prix',
#    'French Grand Prix',
#    'Italian Grand Prix']],
#  [1951,
#   'Alfa Romeo',
#   0.625,
#   8,
#   5,
#   ['Swiss Grand Prix',
#    'Belgian Grand Prix',
#    'French Grand Prix',
#    'French Grand Prix',
#    'Spanish Grand Prix']]]

# %%
df = pd.DataFrame(np.array(test[1:]), columns= test[0])

info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 230 entries, 812 to 1011
# Data columns (total 12 columns):
# raceId2            230 non-null int64
# prixName           230 non-null object
# year               230 non-null int64
# round              230 non-null int64
# prixDate           230 non-null object
# constructorName    230 non-null object
# driverName         230 non-null object
# grid               230 non-null int64
# positionText       230 non-null object
# positionOrder      230 non-null int64
# points             230 non-null float64
# status             230 non-null object
# dtypes: float64(1), int64(5), object(6)
# memory usage: 23.4+ KB

# %%
championship.constructorName.unique()
# Out:
# array(['Maserati', 'Gordini', 'Ferrari', 'Nichels', 'Kurtis Kraft',
#        'Pawl', 'Schroeder', 'Bromme', 'Stevens', 'Pankratz', 'Phillips',
#        'Kuzma', 'Mercedes', 'HWM', 'Connaught', 'Vanwall', 'Cooper',
#        'Klenk', 'Lancia'], dtype=object)

# %% [markdown]
# Let's make this a function to get things quickly.

# %%
def competingTeams(year):
    return list(results[results.year == year].constructorName.unique())

# %%
competingTeams(1954)
# Out:
# ['Maserati',
#  'Gordini',
#  'Ferrari',
#  'Nichels',
#  'Kurtis Kraft',
#  'Pawl',
#  'Schroeder',
#  'Bromme',
#  'Stevens',
#  'Pankratz',
#  'Phillips',
#  'Kuzma',
#  'Mercedes',
#  'HWM',
#  'Connaught',
#  'Vanwall',
#  'Cooper',
#  'Klenk',
#  'Lancia']

# %% [markdown]
# Now I'll go amend a copy of the teams csv to make sure the names are good.

# %%
competingTeams(2014)
# Out:
# ['Marussia',
#  'Lotus F1',
#  'Caterham',
#  'Mercedes',
#  'Williams',
#  'Red Bull',
#  'Sauber',
#  'Force India',
#  'Toro Rosso',
#  'Ferrari',
#  'McLaren']

# %% [markdown]
# That takes care of all the mercedes entries. Now to Lotus

# %%
competingTeams(1968)
# Out:
# ['LDS',
#  'Cooper-Climax',
#  'BRM',
#  'Brabham-Repco',
#  'Cooper-BRM',
#  'Cooper-Maserati',
#  'Matra-Ford',
#  'Ferrari',
#  'Brabham-Climax',
#  'Eagle-Weslake',
#  'Lotus-Ford',
#  'McLaren-BRM',
#  'Honda',
#  'McLaren-Ford',
#  'Matra',
#  'McLaren',
#  'Lola']

# %% [markdown]
# Okay... time to do this en mass and then update the csv

# %%
wrongInfoYears = list(df[df["dominance %"] == 0].year)

# %%
wrongInfoYears
# Out:
# [1954,
#  1955,
#  1959,
#  1960,
#  1963,
#  1965,
#  1966,
#  1967,
#  1967,
#  1968,
#  1969,
#  1970,
#  1972,
#  1978,
#  2009,
#  2014,
#  2015,
#  2016,
#  2017,
#  2018]

# %%
for year in wrongInfoYears:
    print(year)
    print(competingTeams(year))
    print("#######")
    print()
# Out:
# 1954
# ['Maserati', 'Gordini', 'Ferrari', 'Nichels', 'Kurtis Kraft', 'Pawl', 'Schroeder', 'Bromme', 'Stevens', 'Pankratz', 'Phillips', 'Kuzma', 'Mercedes', 'HWM', 'Connaught', 'Vanwall', 'Cooper', 'Klenk', 'Lancia']
# #######
#
# 1955
# ['Lancia', 'Maserati', 'Gordini', 'Ferrari', 'Mercedes', 'HWM', 'Vanwall', 'Kuzma', 'Kurtis Kraft', 'Schroeder', 'Pawl', 'Stevens', 'Trevis', 'Pankratz', 'Phillips', 'Epperly', 'Connaught', 'Cooper', 'Arzani-Volpini']
# #######
#
# 1959
# ['Ferrari', 'Maserati', 'Cooper-Climax', 'Team Lotus', 'Porsche', 'BRM', 'Cooper-Maserati', 'Kurtis Kraft', 'Kuzma', 'Watson', 'Elder', 'Phillips', 'Epperly', 'Christensen', 'Sutton', 'Lesovsky', 'Moore', 'Dunn', 'Aston Martin', 'JBW', 'Vanwall', 'Fry', 'Cooper-Borgward', 'Tec-Mec', 'Connaught', 'Cooper-OSCA']
# #######
#
# 1960
# ['Cooper-Climax', 'BRM', 'Behra-Porsche', 'Maserati', 'Team Lotus', 'Ferrari', 'Cooper-Maserati', 'JBW', 'Cooper-Castellotti', 'Scarab', 'Epperly', 'Watson', 'Ewing', 'Kurtis Kraft', 'Christensen', 'Kuzma', 'Meskowski', 'Phillips', 'Lesovsky', 'Trevis', 'Aston Martin', 'Vanwall', 'Porsche']
# #######
#
# 1963
# ['Lola', 'Lotus-Climax', 'ATS', 'Lotus-BRM', 'Porsche', 'Scirocco', 'De Tomaso', 'BRM', 'Brabham', 'Cooper-Climax', 'Ferrari', 'BRP', 'Gilby', 'Lotus-Borgward', 'De Tomaso-Ferrari', 'Lotus-Maserati', 'Cooper-Maserati', 'Stebro', 'Team Lotus', 'LDS', 'Lotus-Ford', 'Alfa Romeo']
# #######
#
# 1965
# ['Cooper-Climax', 'Brabham-Climax', 'Cooper-Ford', 'Lotus-Climax', 'LDS-Climax', 'Lotus-Ford', 'RE', 'LDS-Alfa Romeo', 'Cooper-Maserati', 'Ferrari', 'BRM', 'Brabham-BRM', 'Brabham-Ford', 'Alfa Romeo', 'Lotus-BRM', 'Honda']
# #######
#
# 1966
# ['Brabham-BRM', 'Brabham-Climax', 'McLaren-Ford', 'Ferrari', 'Brabham-Repco', 'Lotus-BRM', 'Cooper-Maserati', 'Lotus-Climax', 'BRM', 'McLaren-Serenissima', 'Eagle-Climax', 'Shannon', 'Cooper-Ferrari', 'Honda', 'Eagle-Weslake']
# #######
#
# 1967
# ['Cooper-Maserati', 'BRM', 'Lotus-BRM', 'Eagle-Climax', 'Brabham-Repco', 'Brabham-Climax', 'LDS-Climax', 'Honda', 'Cooper-Climax', 'Eagle-Weslake', 'Matra', 'Lotus-Climax', 'Ferrari', 'McLaren-BRM', 'Lotus-Ford', 'Cooper-ATS', 'Lola', 'Protos', 'Brabham-Ford', 'McLaren-Ford']
# #######
#
# 1967
# ['Cooper-Maserati', 'BRM', 'Lotus-BRM', 'Eagle-Climax', 'Brabham-Repco', 'Brabham-Climax', 'LDS-Climax', 'Honda', 'Cooper-Climax', 'Eagle-Weslake', 'Matra', 'Lotus-Climax', 'Ferrari', 'McLaren-BRM', 'Lotus-Ford', 'Cooper-ATS', 'Lola', 'Protos', 'Brabham-Ford', 'McLaren-Ford']
# #######
#
# 1968
# ['LDS', 'Cooper-Climax', 'BRM', 'Brabham-Repco', 'Cooper-BRM', 'Cooper-Maserati', 'Matra-Ford', 'Ferrari', 'Brabham-Climax', 'Eagle-Weslake', 'Lotus-Ford', 'McLaren-BRM', 'Honda', 'McLaren-Ford', 'Matra', 'McLaren', 'Lola']
# #######
#
# 1969
# ['BRM', 'McLaren-Ford', 'Brabham-Ford', 'Lotus-Ford', 'Ferrari', 'Brabham-Repco', 'Matra-Ford', 'Cooper-Maserati', 'BRM-Ford', 'Brabham-Climax', 'Eagle-Climax']
# #######
#
# 1970
# ['McLaren-Ford', 'BRM', 'March', 'De Tomaso', 'Brabham', 'Ferrari', 'Team Lotus', 'Matra', 'McLaren-Alfa Romeo', 'Bellasi', 'Surtees', 'Tyrrell']
# #######
#
# 1972
# ['BRM', 'McLaren', 'Ferrari', 'Surtees', 'Team Lotus', 'Matra', 'Tyrrell', 'Brabham', 'March', 'Tecno', 'Politoys', 'Connew']
# #######
#
# 1978
# ['Ensign', 'Brabham', 'Williams', 'Surtees', 'Shadow', 'Team Lotus', 'Theodore', 'Hesketh', 'Ligier', 'Merzario', 'McLaren', 'ATS', 'Wolf', 'Fittipaldi', 'Ferrari', 'Tyrrell', 'Arrows', 'Renault', 'Martini']
# #######
#
# 2009
# ['Red Bull', 'BMW Sauber', 'Ferrari', 'McLaren', 'Williams', 'Renault', 'Force India', 'Brawn', 'Toyota', 'Toro Rosso']
# #######
#
# 2014
# ['Marussia', 'Lotus F1', 'Caterham', 'Mercedes', 'Williams', 'Red Bull', 'Sauber', 'Force India', 'Toro Rosso', 'Ferrari', 'McLaren']
# #######
#
# 2015
# ['Force India', 'McLaren', 'Red Bull', 'Lotus F1', 'Toro Rosso', 'Ferrari', 'Williams', 'Sauber', 'Mercedes', 'Manor Marussia']
# #######
#
# 2016
# ['Red Bull', 'Renault', 'Haas F1 Team', 'Manor Marussia', 'Ferrari', 'Sauber', 'McLaren', 'Force India', 'Toro Rosso', 'Williams', 'Mercedes']
# #######
#
# 2017
# ['Sauber', 'Haas F1 Team', 'Renault', 'Red Bull', 'Williams', 'McLaren', 'Toro Rosso', 'Force India', 'Ferrari', 'Mercedes']
# #######
#
# 2018
# ['Sauber', 'Williams', 'Toro Rosso', 'Haas F1 Team', 'Force India', 'Ferrari', 'McLaren', 'Mercedes', 'Red Bull', 'Renault']
# #######

# %% [markdown]
# That took a while, but let's redo everything with `teams2.csv`

# %%
with open("../data/teams2.csv", "r") as f:
    teams = csv.reader(f)
    constructors = list(teams)
    
summary = [["year", "team", "dominance %", "rounds", "races won",  "victories"]]
for i in range(1,len(constructors)):
    year = int(constructors[i][0])
    team = str(constructors[i][1])
    line = race_victories(year, team)
    summary.append(line)
    
df = pd.DataFrame(np.array(summary[1:]), columns= summary[0])
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.

# %%
df.head()
# Out:
#    year        team dominance % rounds races won  \
# 0  1950  Alfa Romeo    0.857143      7         6
# 1  1951  Alfa Romeo       0.625      8         5
# 2  1952     Ferrari       0.875      8         7
# 3  1953     Ferrari    0.777778      9         7
# 4  1954    Maserati    0.222222      9         2
#
#                                            victories
# 0  [British Grand Prix, Monaco Grand Prix, Swiss ...
# 1  [Swiss Grand Prix, Belgian Grand Prix, French ...
# 2  [Swiss Grand Prix, Belgian Grand Prix, French ...
# 3  [Argentine Grand Prix, Dutch Grand Prix, Belgi...
# 4         [Argentine Grand Prix, Belgian Grand Prix]

# %% [markdown]
# Cool, now let's see the best 5 seasons

# %%
df.sort_values("dominance %",ascending = False).head(5)
# Out:
#     year        team dominance % rounds races won  \
# 40  1988     McLaren      0.9375     16        15
# 68  2016    Mercedes    0.904762     21        19
# 54  2002     Ferrari    0.882353     17        15
# 2   1952     Ferrari       0.875      8         7
# 0   1950  Alfa Romeo    0.857143      7         6
#
#                                             victories
# 40  [Brazilian Grand Prix, San Marino Grand Prix, ...
# 68  [Australian Grand Prix, Bahrain Grand Prix, Ch...
# 54  [Australian Grand Prix, Brazilian Grand Prix, ...
# 2   [Swiss Grand Prix, Belgian Grand Prix, French ...
# 0   [British Grand Prix, Monaco Grand Prix, Swiss ...

# %%
df.sort_values("dominance %",ascending = False).head(20)
# Out:
#     year          team dominance % rounds races won  \
# 40  1988       McLaren      0.9375     16        15
# 68  2016      Mercedes    0.904762     21        19
# 54  2002       Ferrari    0.882353     17        15
# 2   1952       Ferrari       0.875      8         7
# 0   1950    Alfa Romeo    0.857143      7         6
# 67  2015      Mercedes    0.842105     19        16
# 66  2014      Mercedes    0.842105     19        16
# 56  2004       Ferrari    0.833333     18        15
# 3   1953       Ferrari    0.777778      9         7
# 48  1996      Williams        0.75     16        12
# 36  1984       McLaren        0.75     16        12
# 7   1956       Ferrari        0.75      8         6
# 6   1955      Mercedes    0.714286      7         5
# 14  1963  Lotus-Climax         0.7     10         7
# 65  2013      Red Bull    0.684211     19        13
# 47  1995      Benetton    0.647059     17        11
# 23  1971       Tyrrell    0.636364     11         7
# 63  2011      Red Bull    0.631579     19        12
# 1   1951    Alfa Romeo       0.625      8         5
# 41  1989       McLaren       0.625     16        10
#
#                                             victories
# 40  [Brazilian Grand Prix, San Marino Grand Prix, ...
# 68  [Australian Grand Prix, Bahrain Grand Prix, Ch...
# 54  [Australian Grand Prix, Brazilian Grand Prix, ...
# 2   [Swiss Grand Prix, Belgian Grand Prix, French ...
# 0   [British Grand Prix, Monaco Grand Prix, Swiss ...
# 67  [Australian Grand Prix, Chinese Grand Prix, Ba...
# 66  [Australian Grand Prix, Malaysian Grand Prix, ...
# 56  [Australian Grand Prix, Malaysian Grand Prix, ...
# 3   [Argentine Grand Prix, Dutch Grand Prix, Belgi...
# 48  [Australian Grand Prix, Brazilian Grand Prix, ...
# 36  [Brazilian Grand Prix, South African Grand Pri...
# 7   [Argentine Grand Prix, Argentine Grand Prix, B...
# 6   [Argentine Grand Prix, Belgian Grand Prix, Dut...
# 14  [Belgian Grand Prix, Dutch Grand Prix, French ...
# 65  [Malaysian Grand Prix, Bahrain Grand Prix, Can...
# 47  [Brazilian Grand Prix, Spanish Grand Prix, Mon...
# 23  [Spanish Grand Prix, Monaco Grand Prix, French...
# 63  [Australian Grand Prix, Malaysian Grand Prix, ...
# 1   [Swiss Grand Prix, Belgian Grand Prix, French ...
# 41  [San Marino Grand Prix, Monaco Grand Prix, Mex...

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt

# %%
x = list(df["dominance %"])
plt.hist(x, density= True, bins= 20)
plt.show()

# %%
df.sort_values("dominance %").head(3)
# Out:
#     year      team dominance % rounds races won  \
# 34  1982  Williams      0.0625     16         1
# 9   1958   Ferrari    0.181818     11         2
# 33  1981   Brabham         0.2     15         3
#
#                                             victories
# 34                                 [Swiss Grand Prix]
# 9             [French Grand Prix, British Grand Prix]
# 33  [Argentine Grand Prix, San Marino Grand Prix, ...

# %%
df.to_csv("../data/cars_dominance.csv", index=False)

# %% [markdown]
# **From my journal:** *A better way to frame the question this data answers, or the point of this data: how dominant was the car/team when X won the driver championship in Y?*
#
# This is the peak dominance, just first place. We can later expand this to:
#
# * podiums
# * average position at the end of race
#
# I might revisit the podium idea later, but for now, we'll look at the next thing: the names of the drivers in the season

# %% [markdown]
# ## Finding the drivers in each season

# %%
results.head()
# Out:
#     raceId2            prixName  year  round    prixDate constructorName  \
# 0         1  British Grand Prix  1950      1  1950-05-13      Alfa Romeo
# 22        1  British Grand Prix  1950      1  1950-05-13             ERA
# 21        1  British Grand Prix  1950      1  1950-05-13             ERA
# 20        1  British Grand Prix  1950      1  1950-05-13             ERA
# 19        1  British Grand Prix  1950      1  1950-05-13     Talbot-Lago
#
#         driverName  grid positionText  positionOrder  points        status
# 0      Nino Farina     1            1              1     9.0      Finished
# 22  Leslie Johnson    12            R             21     0.0  Supercharger
# 21    Peter Walker    10            R             20     0.0       Gearbox
# 20       Tony Rolt    10            R             20     0.0       Gearbox
# 19   Eugène Martin     7            R             19     0.0  Oil pressure

# %% [markdown]
# For each year, team combo we want the `driverName`.

# %%
# def race_victories(year, teamName):
#     championship = results[results.year == year] #get the right set of races
#     team = championship[championship.constructorName == teamName] #get the results for the team in question
#     drivers = team[championship.driverName == "1"] #get all the victories of the team
    
#     rounds = championship["round"].max() #how many total races in the season
    
#     victories = list(team_wins.prixName) #the list of all races won
#     rounds_won = len(victories) #number of races won
    
#     dominance = rounds_won / float(rounds)
#     return [year, teamName, dominance, rounds, rounds_won, victories]

year = 1950
constructor = "Alfa Romeo"

team = results[results.constructorName == constructor]
champ = team[team.year == year]

# %%
champ.head()
# Out:
#     raceId2            prixName  year  round    prixDate constructorName  \
# 0         1  British Grand Prix  1950      1  1950-05-13      Alfa Romeo
# 12        1  British Grand Prix  1950      1  1950-05-13      Alfa Romeo
# 2         1  British Grand Prix  1950      1  1950-05-13      Alfa Romeo
# 1         1  British Grand Prix  1950      1  1950-05-13      Alfa Romeo
# 34        2   Monaco Grand Prix  1950      2  1950-05-21      Alfa Romeo
#
#        driverName  grid positionText  positionOrder  points    status
# 0     Nino Farina     1            1              1     9.0  Finished
# 12    Juan Fangio     3            R             12     0.0  Oil leak
# 2     Reg Parnell     4            3              3     4.0  Finished
# 1   Luigi Fagioli     2            2              2     6.0  Finished
# 34  Luigi Fagioli     5            R             12     0.0  Accident
