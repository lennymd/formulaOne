# %% [markdown]
# # Formula 1 Championship Drivers
#
# I'm going to be looking at the gathered data from Formula 1 races from 1950–present. I got the data using the [Ergast Developer API](http://ergast.com/mrd/) and it has all the races from 1950 going forward. The data is stored across different relational tables, so I'll be doing some filtering and joining later.
#
#
# Some things to note about the data:
#
# * I last downloaded this data on 19-04-30, and it includes Azerbaijan GP 2019. I don't think it's too relevant to keep the races from 2019 in the analysis because I'll be looking at the past championship winners.
# * The tables are not chronologically organized in most cases. Races seem to start around Hamilton's debut with McLaren. Part of my initial cleaning and preparation is to get this re-organized. Drivers by date of birth, everything to races by the time they occured.
# * In the standings table, a new entry is not added after a race if the driver does not change standings.
# * When a cell is `\N` it means the cell is null, or the value wasn't recorded. This largely applies to things for which we had no data in the beginning.
# * Looking at the original `raceId`, something happened because Azerbaijan GP 2019 was the 1001st race but their id for the same race was 1014. I assume the counting was pushed ahead somewhere in the middle, but things seem to line up. **I'll come back to look at this later**.

# %% [markdown]
# ## Cleaning the data — part 1
#
# The original data is saved (sans zip) in `data/f1db_raw`. I made a copy of the folder and renamed it to `f1db_excelPrep`.
#
# The first cleaning thing I'm doing is going through every table in `data/f1db_excelPrep/` and:
# * adding the headings for each table using the [f1db_schema.txt](../data/f1db_schema.txt) as a guideline
# * removing the `\N` wherever it appears
# * formatting dates to yyyy-mm-dd, and creating columns for month, date, and year separately.
# * Sort drivers, and races chronologically and create new temporary driver and race Ids.
#
# I'll do this in excel and save the files in the folder: `data/f1db_excelPrep/`.
#
# During this I noticed in constructor results that there is a `D` status that I don't know what it means. **I will look into this later.**

# %% [markdown]
# ## Cleaning the data —part 2
#
# In the first part of cleaning, I re-organized the `driverId`'s and `raceId`'s chronologically, so now I want to pass that info to the other tables so that everything is chronological.
#
# What do I need to update for each table?
#
# * circuits: *nothing*
# * constructor_results: raceId
# * constructor_standings: raceId
# * constructors: *nothing*
# * driver_standings: raceId, driverId
# * driver: *nothing*
# * lap_times: raceId, driverId
# * pit_stops: raceId, driverId
# * qualifying: raceId, driverId
# * races: *nothing*
# * results: raceId, driverId
# * seasons: *nothing*
# * status: *nothing*
#
# The tables that don't need to be updated, I'll go ahead and make direct copies of and put them in the `data/f1db_working/` which will be the tables I use for analysis.

# %%
import numpy as np
import pandas as pd

# %%
drivers = pd.read_csv("../data/f1db_excelPrep/driver.csv")

# %%
drivers.head()
# Out:
#    driverId  driverRef  number code  forename    surname         dob  \
# 0       741  etancelin     NaN  NaN  Philippe  Étancelin  1896-12-28
# 1       703      legat     NaN  NaN    Arthur      Legat  1898-11-01
# 2       786    fagioli     NaN  NaN     Luigi    Fagioli  1898-06-09
# 3       791  biondetti     NaN  NaN  Clemente  Biondetti  1898-08-18
# 4       589     chiron     NaN  NaN     Louis     Chiron  1899-08-03
#
#   nationality                                                url  driverId2  \
# 0      French  http://en.wikipedia.org/wiki/Philippe_%C3%89ta...          1
# 1     Belgian          http://en.wikipedia.org/wiki/Arthur_Legat          2
# 2     Italian         http://en.wikipedia.org/wiki/Luigi_Fagioli          3
# 3     Italian    http://en.wikipedia.org/wiki/Clemente_Biondetti          4
# 4  Monegasque          http://en.wikipedia.org/wiki/Louis_Chiron          5
#
#    dob_year  dob_month  dob_day
# 0      1896         12       28
# 1      1898         11        1
# 2      1898          6        9
# 3      1898          8       18
# 4      1899          8        3

# %%
drivers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 847 entries, 0 to 846
# Data columns (total 13 columns):
# driverId       847 non-null int64
# driverRef      847 non-null object
# number         44 non-null float64
# code           90 non-null object
# forename       847 non-null object
# surname        847 non-null object
# dob            847 non-null object
# nationality    847 non-null object
# url            846 non-null object
# driverId2      847 non-null int64
# dob_year       847 non-null int64
# dob_month      847 non-null int64
# dob_day        847 non-null int64
# dtypes: float64(1), int64(5), object(7)
# memory usage: 86.1+ KB

# %%
newDriverId = drivers[["driverId","driverId2"]]

# %%
newDriverId.head()
# Out:
#    driverId  driverId2
# 0       741          1
# 1       703          2
# 2       786          3
# 3       791          4
# 4       589          5

# %%
newDriverId.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 847 entries, 0 to 846
# Data columns (total 2 columns):
# driverId     847 non-null int64
# driverId2    847 non-null int64
# dtypes: int64(2)
# memory usage: 13.3 KB

# %%
races = pd.read_csv("../data/f1db_excelPrep/races.csv")

# %%
races.head()
# Out:
#    raceId  year  round  circuitId                name     date time  \
# 0     833  1950      1          9  British Grand Prix  5/13/50  NaN
# 1     834  1950      2          6   Monaco Grand Prix  5/21/50  NaN
# 2     835  1950      3         19    Indianapolis 500  5/30/50  NaN
# 3     836  1950      4         66    Swiss Grand Prix   6/4/50  NaN
# 4     837  1950      5         13  Belgian Grand Prix  6/18/50  NaN
#
#                                                  url  raceId2  race_year  \
# 0  http://en.wikipedia.org/wiki/1950_British_Gran...        1       1950
# 1  http://en.wikipedia.org/wiki/1950_Monaco_Grand...        2       1950
# 2  http://en.wikipedia.org/wiki/1950_Indianapolis...        3       1950
# 3  http://en.wikipedia.org/wiki/1950_Swiss_Grand_...        4       1950
# 4  http://en.wikipedia.org/wiki/1950_Belgian_Gran...        5       1950
#
#    race_month  race_day
# 0           5        13
# 1           5        21
# 2           5        30
# 3           6         4
# 4           6        18

# %%
races.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1018 entries, 0 to 1017
# Data columns (total 12 columns):
# raceId        1018 non-null int64
# year          1018 non-null int64
# round         1018 non-null int64
# circuitId     1018 non-null int64
# name          1018 non-null object
# date          1018 non-null object
# time          287 non-null object
# url           1018 non-null object
# raceId2       1018 non-null int64
# race_year     1018 non-null int64
# race_month    1018 non-null int64
# race_day      1018 non-null int64
# dtypes: int64(8), object(4)
# memory usage: 95.5+ KB

# %%
newRaceId = races[["raceId","raceId2"]]

# %%
newRaceId.head()
# Out:
#    raceId  raceId2
# 0     833        1
# 1     834        2
# 2     835        3
# 3     836        4
# 4     837        5

# %%
newRaceId.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1018 entries, 0 to 1017
# Data columns (total 2 columns):
# raceId     1018 non-null int64
# raceId2    1018 non-null int64
# dtypes: int64(2)
# memory usage: 16.0 KB

# %% [markdown]
# Now that we have `newRaceId` and `newDriverId` dataframes we can do inner joins with the other tables on the `raceId` and `driverId` columns, respectively, and add that info in.

# %%
constructorResults = pd.read_csv("../data/f1db_excelPrep/constructor_results.csv")

# %%
constructorResults.head()
# Out:
#    constructorResultsId  raceId  constructorId  points status
# 0                     1      18              1    14.0    NaN
# 1                     2      18              2     8.0    NaN
# 2                     3      18              3     9.0    NaN
# 3                     4      18              4     5.0    NaN
# 4                     5      18              5     2.0    NaN

# %%
constructorResults.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11390 entries, 0 to 11389
# Data columns (total 5 columns):
# constructorResultsId    11390 non-null int64
# raceId                  11390 non-null int64
# constructorId           11390 non-null int64
# points                  11390 non-null float64
# status                  17 non-null object
# dtypes: float64(1), int64(3), object(1)
# memory usage: 445.0+ KB

# %%
constructorResultsNew = pd.merge(constructorResults, newRaceId, on="raceId")

# %%
constructorResultsNew.head()
# Out:
#    constructorResultsId  raceId  constructorId  points status  raceId2
# 0                     1      18              1    14.0    NaN      786
# 1                     2      18              2     8.0    NaN      786
# 2                     3      18              3     9.0    NaN      786
# 3                     4      18              4     5.0    NaN      786
# 4                     5      18              5     2.0    NaN      786

# %%
constructorResultsNew.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11390 entries, 0 to 11389
# Data columns (total 6 columns):
# constructorResultsId    11390 non-null int64
# raceId                  11390 non-null int64
# constructorId           11390 non-null int64
# points                  11390 non-null float64
# status                  17 non-null object
# raceId2                 11390 non-null int64
# dtypes: float64(1), int64(4), object(1)
# memory usage: 622.9+ KB

# %% [markdown]
# Things worked well. We can save this dataframe to a csv since we don't need to add anything else to the constructor results.

# %%
constructorResultsNew.to_csv("../data/f1db_working/constructor_results.csv", index=False)

# %% [markdown]
# We can repeat the same process with the constructor_standings table.

# %%
constructorStandings = pd.read_csv("../data/f1db_excelPrep/constructor_standings.csv")

# %%
constructorStandings.head()
# Out:
#    constructorStandingsId  raceId  constructorId  points  position  \
# 0                       1      18              1    14.0         1
# 1                       2      18              2     8.0         3
# 2                       3      18              3     9.0         2
# 3                       4      18              4     5.0         4
# 4                       5      18              5     2.0         5
#
#   positionText  wins
# 0            1     1
# 1            3     0
# 2            2     0
# 3            4     0
# 4            5     0

# %%
constructorStandings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12146 entries, 0 to 12145
# Data columns (total 7 columns):
# constructorStandingsId    12146 non-null int64
# raceId                    12146 non-null int64
# constructorId             12146 non-null int64
# points                    12146 non-null float64
# position                  12146 non-null int64
# positionText              12146 non-null object
# wins                      12146 non-null int64
# dtypes: float64(1), int64(5), object(1)
# memory usage: 664.3+ KB

# %%
constructorStandings2 = constructorStandings.merge(newRaceId, on = "raceId")

# %%
constructorStandings2.head()
# Out:
#    constructorStandingsId  raceId  constructorId  points  position  \
# 0                       1      18              1    14.0         1
# 1                       2      18              2     8.0         3
# 2                       3      18              3     9.0         2
# 3                       4      18              4     5.0         4
# 4                       5      18              5     2.0         5
#
#   positionText  wins  raceId2
# 0            1     1      786
# 1            3     0      786
# 2            2     0      786
# 3            4     0      786
# 4            5     0      786

# %%
constructorStandings2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12146 entries, 0 to 12145
# Data columns (total 8 columns):
# constructorStandingsId    12146 non-null int64
# raceId                    12146 non-null int64
# constructorId             12146 non-null int64
# points                    12146 non-null float64
# position                  12146 non-null int64
# positionText              12146 non-null object
# wins                      12146 non-null int64
# raceId2                   12146 non-null int64
# dtypes: float64(1), int64(6), object(1)
# memory usage: 854.0+ KB

# %%
constructorStandings2.to_csv("../data/f1db_working/constructor_standings.csv", index=False)

# %% [markdown]
# Let's move on to the rest. We have to merge both the newRaceId and the newDriverId. We have to do it for:
#
# * driver_standings: raceId, driverId
# * lap_times: raceId, driverId
# * pit_stops: raceId, driverId
# * qualifying: raceId, driverId
# * results: raceId, driverId
#
# Can I do it in one line of work?

# %%
driverStandings = pd.read_csv("../data/f1db_excelPrep/driver_standings.csv")

# %%
driverStandings.head()
# Out:
#    driverStandingsId  raceId  driverId  points  position positionText  wins
# 0                  1      18         1    10.0         1            1     1
# 1                  2      18         2     8.0         2            2     0
# 2                  3      18         3     6.0         3            3     0
# 3                  4      18         4     5.0         4            4     0
# 4                  5      18         5     4.0         5            5     0

# %%
driverStandings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32226 entries, 0 to 32225
# Data columns (total 7 columns):
# driverStandingsId    32226 non-null int64
# raceId               32226 non-null int64
# driverId             32226 non-null int64
# points               32226 non-null float64
# position             32226 non-null int64
# positionText         32226 non-null object
# wins                 32226 non-null int64
# dtypes: float64(1), int64(5), object(1)
# memory usage: 1.7+ MB

# %%
driverStandings2 = driverStandings.merge(newRaceId, on = "raceId").merge(newDriverId, on = "driverId")

# %%
driverStandings2.head()
# Out:
#    driverStandingsId  raceId  driverId  points  position positionText  wins  \
# 0                  1      18         1    10.0         1            1     1
# 1                  9      19         1    14.0         1            1     1
# 2                 27      20         1    14.0         3            3     1
# 3                 48      21         1    20.0         2            2     1
# 4                 69      22         1    28.0         3            3     1
#
#    raceId2  driverId2
# 0      786        803
# 1      787        803
# 2      788        803
# 3      789        803
# 4      790        803

# %% [markdown]
# Honest to god let's check to make sure that this worked. Lewis Hamilton has `driverId = 1`, so let's see if that matches up if we look with the newDriverId

# %%
drivers[drivers.driverId2 == 803]
# Out:
#      driverId driverRef  number code forename   surname     dob nationality  \
# 802         1  hamilton    44.0  HAM    Lewis  Hamilton  1/7/85     British
#
#                                              url  driverId2  dob_year  \
# 802  http://en.wikipedia.org/wiki/Lewis_Hamilton        803      1985
#
#      dob_month  dob_day
# 802          1        7

# %%
driverStandings2.head()
# Out:
#    driverStandingsId  raceId  driverId  points  position positionText  wins  \
# 0                  1      18         1    10.0         1            1     1
# 1                  9      19         1    14.0         1            1     1
# 2                 27      20         1    14.0         3            3     1
# 3                 48      21         1    20.0         2            2     1
# 4                 69      22         1    28.0         3            3     1
#
#    raceId2  driverId2
# 0      786        803
# 1      787        803
# 2      788        803
# 3      789        803
# 4      790        803

# %%
driverStandings2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32226 entries, 0 to 32225
# Data columns (total 9 columns):
# driverStandingsId    32226 non-null int64
# raceId               32226 non-null int64
# driverId             32226 non-null int64
# points               32226 non-null float64
# position             32226 non-null int64
# positionText         32226 non-null object
# wins                 32226 non-null int64
# raceId2              32226 non-null int64
# driverId2            32226 non-null int64
# dtypes: float64(1), int64(7), object(1)
# memory usage: 2.5+ MB

# %% [markdown]
# This back-to-back (chained??) merge worked! Let's save this file first

# %%
driverStandings2.to_csv("../data/f1db_working/driver_standings.csv", index=False)

# %% [markdown]
# Now let's try and do the other tables in the same way.

# %%
grab_url = "../data/f1db_excelPrep/"
save_url = "../data/f1db_working/"
tables = ["lap_times","pit_stops", "qualifying","results"]

for table in tables:
    url = grab_url + table + ".csv"
    df1 = pd.read_csv(url)
    df2 = df1.merge(newRaceId, on = "raceId").merge(newDriverId, on = "driverId")
    df2.to_csv(save_url + table + ".csv", index=False)
    # uncomment the following to check things
#     print("###",table,"###")
#     df1.info(verbose=False)
#     print("---")
#     df2.info(verbose=False)
#     print("###############")
#     print()

# %% [markdown]
# Each of the tables is now prepped. For my analysis I'll be working primarily with the the results table. So I'll try to get all the information I need together.

# %% [markdown]
# ## Wrangling the results table.
#
# Let's create one master results table:
#
# ### Getting the results columns

# %%
results = pd.read_csv("../data/f1db_working/results.csv")

# %%
results.head(10)
# Out:
#    resultsId  raceId  driverId  constructorId  number  grid  position  \
# 0          1      18         1              1    22.0     1       1.0
# 1         27      19         1              1    22.0     9       5.0
# 2         57      20         1              1    22.0     3      13.0
# 3         69      21         1              1    22.0     5       3.0
# 4         90      22         1              1    22.0     3       2.0
# 5        109      23         1              1    22.0     3       1.0
# 6        147      24         1              1    22.0     1       NaN
# 7        158      25         1              1    22.0    13      10.0
# 8        169      26         1              1    22.0     4       1.0
# 9        189      27         1              1    22.0     1       1.0
#
#   positionText  positionOrder  points  laps     time  milliseconds  \
# 0            1              1    10.0    58  34:50.6     5690616.0
# 1            5              5     4.0    56   46.548     5525103.0
# 2           13             13     0.0    56      NaN           NaN
# 3            3              3     6.0    66    4.187     5903238.0
# 4            2              2     8.0    58    3.779     5213230.0
# 5            1              1    10.0    76  00:42.7     7242742.0
# 6            R             19     0.0    19      NaN           NaN
# 7           10             10     0.0    70   54.538     5564783.0
# 8            1              1    10.0    60  39:09.4     5949440.0
# 9            1              1    10.0    67  31:20.9     5480874.0
#
#    fastestLap  rank fastestLapTime  fastestLapSpeed  statusId  raceId2  \
# 0        39.0   2.0        01:27.5          218.300         1      786
# 1        53.0   3.0        01:35.5          209.033         1      787
# 2        25.0  19.0        01:35.5          203.969        11      788
# 3        20.0   3.0        01:22.0          204.323         1      789
# 4        31.0   2.0        01:26.5          222.085         1      790
# 5        71.0   6.0        01:18.5          153.152         1      791
# 6         4.0   3.0        01:17.5          202.559         4      792
# 7        40.0   5.0        01:17.5          205.022         1      793
# 8        16.0   3.0        01:32.8          199.398         1      794
# 9        17.0   2.0        01:16.0          216.552         1      795
#
#    driverId2
# 0        803
# 1        803
# 2        803
# 3        803
# 4        803
# 5        803
# 6        803
# 7        803
# 8        803
# 9        803

# %% [markdown]
# There is this unnamed column in the front. Let's get rid of it.

# %%
results.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24277 entries, 0 to 24276
# Data columns (total 20 columns):
# resultsId          24277 non-null int64
# raceId             24277 non-null int64
# driverId           24277 non-null int64
# constructorId      24277 non-null int64
# number             24271 non-null float64
# grid               24277 non-null int64
# position           13634 non-null float64
# positionText       24277 non-null object
# positionOrder      24277 non-null int64
# points             24277 non-null float64
# laps               24277 non-null int64
# time               6237 non-null object
# milliseconds       6236 non-null float64
# fastestLap         5862 non-null float64
# rank               6031 non-null float64
# fastestLapTime     5862 non-null object
# fastestLapSpeed    5862 non-null float64
# statusId           24277 non-null int64
# raceId2            24277 non-null int64
# driverId2          24277 non-null int64
# dtypes: float64(7), int64(10), object(3)
# memory usage: 3.7+ MB

# %%
results = results.sort_values("resultsId")

# %% [markdown]
# That seems to be gone now

# %%
results.head(10)
# Out:
#       resultsId  raceId  driverId  constructorId  number  grid  position  \
# 0             1      18         1              1    22.0     1       1.0
# 233           2      18         2              2     3.0     5       2.0
# 417           3      18         3              3     7.0     7       3.0
# 623           4      18         4              4     5.0    11       4.0
# 937           5      18         5              1    23.0     3       5.0
# 1049          6      18         6              3     8.0    13       6.0
# 1085          7      18         7              5    14.0    17       7.0
# 1112          8      18         8              6     1.0    15       8.0
# 1410          9      18         9              2     4.0     2       NaN
# 1490         10      18        10              7    12.0    18       NaN
#
#      positionText  positionOrder  points  laps     time  milliseconds  \
# 0               1              1    10.0    58  34:50.6     5690616.0
# 233             2              2     8.0    58    5.478     5696094.0
# 417             3              3     6.0    58    8.163     5698779.0
# 623             4              4     5.0    58   17.181     5707797.0
# 937             5              5     4.0    58   18.014     5708630.0
# 1049            6              6     3.0    57      NaN           NaN
# 1085            7              7     2.0    55      NaN           NaN
# 1112            8              8     1.0    53      NaN           NaN
# 1410            R              9     0.0    47      NaN           NaN
# 1490            R             10     0.0    43      NaN           NaN
#
#       fastestLap  rank fastestLapTime  fastestLapSpeed  statusId  raceId2  \
# 0           39.0   2.0        01:27.5          218.300         1      786
# 233         41.0   3.0        01:27.7          217.586         1      786
# 417         41.0   5.0        01:28.1          216.719         1      786
# 623         58.0   7.0        01:28.6          215.464         1      786
# 937         43.0   1.0        01:27.4          218.385         1      786
# 1049        50.0  14.0        01:29.6          212.974        11      786
# 1085        22.0  12.0        01:29.5          213.224         5      786
# 1112        20.0   4.0        01:27.9          217.180         5      786
# 1410        15.0   9.0        01:28.8          215.100         4      786
# 1490        23.0  13.0        01:29.6          213.166         3      786
#
#       driverId2
# 0           803
# 233         768
# 417         804
# 623         786
# 937         787
# 1049        805
# 1085        776
# 1112        777
# 1410        799
# 1490        793

# %%
results.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 24277 entries, 0 to 23056
# Data columns (total 20 columns):
# resultsId          24277 non-null int64
# raceId             24277 non-null int64
# driverId           24277 non-null int64
# constructorId      24277 non-null int64
# number             24271 non-null float64
# grid               24277 non-null int64
# position           13634 non-null float64
# positionText       24277 non-null object
# positionOrder      24277 non-null int64
# points             24277 non-null float64
# laps               24277 non-null int64
# time               6237 non-null object
# milliseconds       6236 non-null float64
# fastestLap         5862 non-null float64
# rank               6031 non-null float64
# fastestLapTime     5862 non-null object
# fastestLapSpeed    5862 non-null float64
# statusId           24277 non-null int64
# raceId2            24277 non-null int64
# driverId2          24277 non-null int64
# dtypes: float64(7), int64(10), object(3)
# memory usage: 3.9+ MB

# %%
list(results.columns)
# Out:
# ['resultsId',
#  'raceId',
#  'driverId',
#  'constructorId',
#  'number',
#  'grid',
#  'position',
#  'positionText',
#  'positionOrder',
#  'points',
#  'laps',
#  'time',
#  'milliseconds',
#  'fastestLap',
#  'rank',
#  'fastestLapTime',
#  'fastestLapSpeed',
#  'statusId',
#  'raceId2',
#  'driverId2']

# %% [markdown]
# Looking at the columns, I'm interested in:
#
# * raceId2
# * driverId2
# * constructorID
# * grid
# * position
# * positionText
# * positionOrder
# * points
# * statusId
#
# I can come back and add more columns, but let's create a new results table that has just these.

# %%
results[["raceId2","driverId2","constructorId","grid","positionText","positionOrder","points","statusId"]].head(20)
# Out:
#       raceId2  driverId2  constructorId  grid positionText  positionOrder  \
# 0         786        803              1     1            1              1
# 233       786        768              2     5            2              2
# 417       786        804              3     7            3              3
# 623       786        786              4    11            4              4
# 937       786        787              1     3            5              5
# 1049      786        805              3    13            6              6
# 1085      786        776              5    17            7              7
# 1112      786        777              6    15            8              8
# 1410      786        799              2     2            R              9
# 1490      786        793              7    18            R             10
# 1585      786        769              8    19            R             11
# 1676      786        806              4    20            R             12
# 1704      786        788              6     4            R             13
# 1975      786        738              9     8            R             14
# 2222      786        750              7     6            R             15
# 2478      786        795             10    22            R             16
# 2606      786        762              9    14            R             17
# 2823      786        781             11    12            R             18
# 3132      786        778              8    21            R             19
# 3156      786        813              5     9            R             20
#
#       points  statusId
# 0       10.0         1
# 233      8.0         1
# 417      6.0         1
# 623      5.0         1
# 937      4.0         1
# 1049     3.0        11
# 1085     2.0         5
# 1112     1.0         5
# 1410     0.0         4
# 1490     0.0         3
# 1585     0.0         7
# 1676     0.0         8
# 1704     0.0         5
# 1975     0.0         4
# 2222     0.0        10
# 2478     0.0         9
# 2606     0.0         4
# 2823     0.0         4
# 3132     0.0         4
# 3156     0.0         4

# %%
results2 = results[["raceId2","driverId2","constructorId","grid",
                    "positionText","positionOrder","points","statusId"]]

# %%
results2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 24277 entries, 0 to 23056
# Data columns (total 8 columns):
# raceId2          24277 non-null int64
# driverId2        24277 non-null int64
# constructorId    24277 non-null int64
# grid             24277 non-null int64
# positionText     24277 non-null object
# positionOrder    24277 non-null int64
# points           24277 non-null float64
# statusId         24277 non-null int64
# dtypes: float64(1), int64(6), object(1)
# memory usage: 1.7+ MB

# %% [markdown]
# Same number of lines in all of them. Now, let's sort the lines by raceId.

# %%
results2 = results2.sort_values("raceId2")

# %%
results2.head(8)
# Out:
#        raceId2  driverId2  constructorId  grid positionText  positionOrder  \
# 21977        1         58             51     4            3              3
# 21694        1         20             51     1            1              1
# 22223        1          3             51     2            2              2
# 21892        1        142            151    10            R             20
# 22255        1        105            105    20           10             10
# 22057        1         15            154     6            4              4
# 22254        1         68            151    12            R             21
# 21865        1         65            151    10            R             20
#
#        points  statusId
# 21977     4.0         1
# 21694     9.0         1
# 22223     6.0         1
# 21892     0.0         6
# 22255     0.0        16
# 22057     3.0        12
# 22254     0.0       126
# 21865     0.0         6

# %% [markdown]
# ### Getting driver Information
# This is good progress. Now I want to connect the driver, constructor, and race data that are associated with these Ids. Let's start with the drivers

# %%
drivers = pd.read_csv("../data/f1db_working/driver.csv")

# %%
drivers.head()
# Out:
#    driverId  driverRef  number code  forename    surname         dob  \
# 0       741  etancelin     NaN  NaN  Philippe  Étancelin  1896-12-28
# 1       703      legat     NaN  NaN    Arthur      Legat  1898-11-01
# 2       786    fagioli     NaN  NaN     Luigi    Fagioli  1898-06-09
# 3       791  biondetti     NaN  NaN  Clemente  Biondetti  1898-08-18
# 4       589     chiron     NaN  NaN     Louis     Chiron  1899-08-03
#
#   nationality                                                url  driverId2  \
# 0      French  http://en.wikipedia.org/wiki/Philippe_%C3%89ta...          1
# 1     Belgian          http://en.wikipedia.org/wiki/Arthur_Legat          2
# 2     Italian         http://en.wikipedia.org/wiki/Luigi_Fagioli          3
# 3     Italian    http://en.wikipedia.org/wiki/Clemente_Biondetti          4
# 4  Monegasque          http://en.wikipedia.org/wiki/Louis_Chiron          5
#
#    dob_year  dob_month  dob_day
# 0      1896         12       28
# 1      1898         11        1
# 2      1898          6        9
# 3      1898          8       18
# 4      1899          8        3

# %% [markdown]
# Before I get the columns I want, I want to add a column that has the full driver name.

# %%
def combine_name(row):
    name = row.forename + " " + row.surname

# %%
drivers["driverName"] = drivers[["forename","surname"]].apply(lambda x: ' '.join(x), axis=1)

# %%
drivers.head()
# Out:
#    driverId  driverRef  number code  forename    surname         dob  \
# 0       741  etancelin     NaN  NaN  Philippe  Étancelin  1896-12-28
# 1       703      legat     NaN  NaN    Arthur      Legat  1898-11-01
# 2       786    fagioli     NaN  NaN     Luigi    Fagioli  1898-06-09
# 3       791  biondetti     NaN  NaN  Clemente  Biondetti  1898-08-18
# 4       589     chiron     NaN  NaN     Louis     Chiron  1899-08-03
#
#   nationality                                                url  driverId2  \
# 0      French  http://en.wikipedia.org/wiki/Philippe_%C3%89ta...          1
# 1     Belgian          http://en.wikipedia.org/wiki/Arthur_Legat          2
# 2     Italian         http://en.wikipedia.org/wiki/Luigi_Fagioli          3
# 3     Italian    http://en.wikipedia.org/wiki/Clemente_Biondetti          4
# 4  Monegasque          http://en.wikipedia.org/wiki/Louis_Chiron          5
#
#    dob_year  dob_month  dob_day          driverName
# 0      1896         12       28  Philippe Étancelin
# 1      1898         11        1        Arthur Legat
# 2      1898          6        9       Luigi Fagioli
# 3      1898          8       18  Clemente Biondetti
# 4      1899          8        3        Louis Chiron

# %% [markdown]
# Good! Now I want to grab the driverId2, driverName, nationality, and dob for now:

# %%
drivers2 = drivers[["driverId2", "driverRef", "driverName", "nationality","dob"]]

# %%
drivers2.head()
# Out:
#    driverId2  driverRef          driverName nationality         dob
# 0          1  etancelin  Philippe Étancelin      French  1896-12-28
# 1          2      legat        Arthur Legat     Belgian  1898-11-01
# 2          3    fagioli       Luigi Fagioli     Italian  1898-06-09
# 3          4  biondetti  Clemente Biondetti     Italian  1898-08-18
# 4          5     chiron        Louis Chiron  Monegasque  1899-08-03

# %% [markdown]
# Let's try merging drivers2 with results2

# %%
i = results2.merge(drivers2, on="driverId2")

# %%
i.sort_values("raceId2").head(25)
# Out:
#      raceId2  driverId2  constructorId  grid positionText  positionOrder  \
# 0          1         58             51     4            3              3
# 287        1         83            126    19            N             13
# 52         1        142            151    10            R             20
# 229        1         56             51     3            R             12
# 55         1        105            105    20           10             10
# 56         1         15            154     6            4              4
# 204        1        112            154    21           11             11
# 197        1         88            151    13            6              6
# 195        1        130            105    16            9              9
# 289        1        104            105    20           10             10
# 183        1          1            154    14            8              8
# 176        1         44            105    18            R             15
# 137        1         16            154     9            5              5
# 69         1         68            151    12            R             21
# 70         1         65            151    10            R             20
# 118        1         92            105     5            R             14
# 116        1        106            154     7            R             19
# 114        1        202            126    17            R             16
# 74         1          5            105    11            R             18
# 180        1         26            151    15            7              7
# 44         1          3             51     2            2              2
# 91         1         90            105     8            R             17
# 7          1         20             51     1            1              1
# 530        2         39              6     6            R              8
# 198        2         88            151    16            6              6
#
#      points  statusId       driverRef            driverName nationality  \
# 0       4.0         1     reg_parnell           Reg Parnell     British
# 287     0.0        62           kelly             Joe Kelly       Irish
# 52      0.0         6            rolt             Tony Rolt     British
# 229     0.0        44          fangio           Juan Fangio   Argentine
# 55      0.0        16             fry               Joe Fry     British
# 56      3.0        12       cabantous        Yves Cabantous      French
# 204     0.0        16           claes          Johnny Claes     Belgian
# 197     0.0        13          gerard            Bob Gerard     British
# 195     0.0        16       hampshire       David Hampshire     British
# 289     0.0        16    shawe_taylor    Brian Shawe Taylor     British
# 183     0.0        15       etancelin    Philippe Étancelin      French
# 176     0.0         5          murray          David Murray     British
# 137     2.0        12          rosier          Louis Rosier      French
# 69      0.0       126  leslie_johnson        Leslie Johnson     British
# 70      0.0         6    peter_walker          Peter Walker     British
# 118     0.0        60            bira           Prince Bira        Thai
# 116     0.0        51          martin         Eugène Martin      French
# 114     0.0         7        crossley        Geoff Crossley     British
# 74      0.0         8          chiron          Louis Chiron  Monegasque
# 180     0.0        13        harrison         Cuth Harrison     British
# 44      6.0         1         fagioli         Luigi Fagioli     Italian
# 91      0.0         5     graffenried  Toulo de Graffenried       Swiss
# 7       9.0         1          farina           Nino Farina     Italian
# 530     0.0       109       villoresi       Luigi Villoresi     Italian
# 198     0.0        16          gerard            Bob Gerard     British
#
#             dob
# 0        7/2/11
# 287     3/13/13
# 52     10/16/18
# 229     6/24/11
# 55     10/26/15
# 56      10/8/04
# 204     8/11/16
# 197     1/19/14
# 195    12/29/17
# 289     1/28/15
# 183  1896-12-28
# 176    12/28/09
# 137     11/5/05
# 69      3/22/12
# 70      10/7/12
# 118     7/15/14
# 116     3/24/15
# 114     5/11/21
# 74   1899-08-03
# 180      7/6/06
# 44   1898-06-09
# 91      5/18/14
# 7      10/30/06
# 530     5/16/09
# 198     1/19/14

# %% [markdown]
# Why is dob showing up so weirdly?

# %%
drivers2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 847 entries, 0 to 846
# Data columns (total 5 columns):
# driverId2      847 non-null int64
# driverRef      847 non-null object
# driverName     847 non-null object
# nationality    847 non-null object
# dob            847 non-null object
# dtypes: int64(1), object(4)
# memory usage: 33.2+ KB

# %%
dobs = drivers2["dob"]

# %%
dobs.head(20)
# Out:
# 0     1896-12-28
# 1     1898-11-01
# 2     1898-06-09
# 3     1898-08-18
# 4     1899-08-03
# 5     1899-10-15
# 6     1899-10-13
# 7       12/27/00
# 8        3/29/00
# 9        7/19/02
# 10       4/27/02
# 11        6/9/03
# 12       5/23/03
# 13      11/23/03
# 14       10/8/04
# 15       11/5/05
# 16      12/22/05
# 17       7/25/05
# 18      10/12/06
# 19      10/30/06
# Name: dob, dtype: object

# %%
dobs2 = pd.to_datetime(dobs)

# %%
dobs2.head(20)
# Out:
# 0    1896-12-28
# 1    1898-11-01
# 2    1898-06-09
# 3    1898-08-18
# 4    1899-08-03
# 5    1899-10-15
# 6    1899-10-13
# 7    2000-12-27
# 8    2000-03-29
# 9    2002-07-19
# 10   2002-04-27
# 11   2003-06-09
# 12   2003-05-23
# 13   2003-11-23
# 14   2004-10-08
# 15   2005-11-05
# 16   2005-12-22
# 17   2005-07-25
# 18   2006-10-12
# 19   2006-10-30
# Name: dob, dtype: datetime64[ns]

# %% [markdown]
# Well this is fucked up. The dates are interepreted all funny. Good thing I went and made columns. Let's go back to drivers and try to fix this there

# %%
drivers.head(20)
# Out:
#     driverId   driverRef  number code  forename    surname         dob  \
# 0        741   etancelin     NaN  NaN  Philippe  Étancelin  1896-12-28
# 1        703       legat     NaN  NaN    Arthur      Legat  1898-11-01
# 2        786     fagioli     NaN  NaN     Luigi    Fagioli  1898-06-09
# 3        791   biondetti     NaN  NaN  Clemente  Biondetti  1898-08-18
# 4        589      chiron     NaN  NaN     Louis     Chiron  1899-08-03
# 5        750      brudes     NaN  NaN     Adolf     Brudes  1899-10-15
# 6        760       dusio     NaN  NaN     Piero      Dusio  1899-10-13
# 7        717  hans_stuck     NaN  NaN      Hans  von Stuck    12/27/00
# 8        749       aston     NaN  NaN      Bill      Aston     3/29/00
# 9        733      miller     NaN  NaN      Chet     Miller     7/19/02
# 10       755   schoeller     NaN  NaN    Rudolf  Schoeller     4/27/02
# 11       697     bonetto     NaN  NaN    Felice    Bonetto      6/9/03
# 12       709     klodwig     NaN  NaN     Ernst    Klodwig     5/23/03
# 13       782       jover     NaN  NaN      Juan      Jover    11/23/03
# 14       704   cabantous     NaN  NaN      Yves  Cabantous     10/8/04
# 15       627      rosier     NaN  NaN     Louis     Rosier     11/5/05
# 16       773      levegh     NaN  NaN    Pierre     Levegh    12/22/05
# 17       783    grignard     NaN  NaN   Georges   Grignard     7/25/05
# 18       641     taruffi     NaN  NaN     Piero    Taruffi    10/12/06
# 19       642      farina     NaN  NaN      Nino     Farina    10/30/06
#
#     nationality                                                url  driverId2  \
# 0        French  http://en.wikipedia.org/wiki/Philippe_%C3%89ta...          1
# 1       Belgian          http://en.wikipedia.org/wiki/Arthur_Legat          2
# 2       Italian         http://en.wikipedia.org/wiki/Luigi_Fagioli          3
# 3       Italian    http://en.wikipedia.org/wiki/Clemente_Biondetti          4
# 4    Monegasque          http://en.wikipedia.org/wiki/Louis_Chiron          5
# 5        German          http://en.wikipedia.org/wiki/Adolf_Brudes          6
# 6       Italian           http://en.wikipedia.org/wiki/Piero_Dusio          7
# 7        German        http://en.wikipedia.org/wiki/Hans_Von_Stuck          8
# 8       British            http://en.wikipedia.org/wiki/Bill_Aston          9
# 9      American           http://en.wikipedia.org/wiki/Chet_Miller         10
# 10        Swiss      http://en.wikipedia.org/wiki/Rudolf_Schoeller         11
# 11      Italian        http://en.wikipedia.org/wiki/Felice_Bonetto         12
# 12  East German         http://en.wikipedia.org/wiki/Ernst_Klodwig         13
# 13      Spanish            http://en.wikipedia.org/wiki/Juan_Jover         14
# 14       French  http://en.wikipedia.org/wiki/Yves_Giraud_Caban...         15
# 15       French          http://en.wikipedia.org/wiki/Louis_Rosier         16
# 16       French         http://en.wikipedia.org/wiki/Pierre_Levegh         17
# 17       French      http://en.wikipedia.org/wiki/Georges_Grignard         18
# 18      Italian         http://en.wikipedia.org/wiki/Piero_Taruffi         19
# 19      Italian           http://en.wikipedia.org/wiki/Nino_Farina         20
#
#     dob_year  dob_month  dob_day          driverName
# 0       1896         12       28  Philippe Étancelin
# 1       1898         11        1        Arthur Legat
# 2       1898          6        9       Luigi Fagioli
# 3       1898          8       18  Clemente Biondetti
# 4       1899          8        3        Louis Chiron
# 5       1899         10       15        Adolf Brudes
# 6       1899         10       13         Piero Dusio
# 7       1900         12       27      Hans von Stuck
# 8       1900          3       29          Bill Aston
# 9       1902          7       19         Chet Miller
# 10      1902          4       27    Rudolf Schoeller
# 11      1903          6        9      Felice Bonetto
# 12      1903          5       23       Ernst Klodwig
# 13      1903         11       23          Juan Jover
# 14      1904         10        8      Yves Cabantous
# 15      1905         11        5        Louis Rosier
# 16      1905         12       22       Pierre Levegh
# 17      1905          7       25    Georges Grignard
# 18      1906         10       12       Piero Taruffi
# 19      1906         10       30         Nino Farina

# %%
def combine_dob(row):
    year = str(row.dob_year)
    month = str(row.dob_month)
    day = str(row.dob_day)
    return year+"-"+month+"-"+day

# %%
dob2 = drivers[["dob_year", "dob_month", "dob_day"]]

# %%
dob2.head()
# Out:
#    dob_year  dob_month  dob_day
# 0      1896         12       28
# 1      1898         11        1
# 2      1898          6        9
# 3      1898          8       18
# 4      1899          8        3

# %%
dob2.apply(combine_dob, axis=1).head(20)
# Out:
# 0     1896-12-28
# 1      1898-11-1
# 2       1898-6-9
# 3      1898-8-18
# 4       1899-8-3
# 5     1899-10-15
# 6     1899-10-13
# 7     1900-12-27
# 8      1900-3-29
# 9      1902-7-19
# 10     1902-4-27
# 11      1903-6-9
# 12     1903-5-23
# 13    1903-11-23
# 14     1904-10-8
# 15     1905-11-5
# 16    1905-12-22
# 17     1905-7-25
# 18    1906-10-12
# 19    1906-10-30
# dtype: object

# %% [markdown]
# So now let's add that dob2 column again

# %%
drivers["dob2"] = drivers[["dob_year", "dob_month","dob_day"]].apply(combine_dob, axis=1)

# %%
drivers.head(10)
# Out:
#    driverId   driverRef  number code  forename    surname         dob  \
# 0       741   etancelin     NaN  NaN  Philippe  Étancelin  1896-12-28
# 1       703       legat     NaN  NaN    Arthur      Legat  1898-11-01
# 2       786     fagioli     NaN  NaN     Luigi    Fagioli  1898-06-09
# 3       791   biondetti     NaN  NaN  Clemente  Biondetti  1898-08-18
# 4       589      chiron     NaN  NaN     Louis     Chiron  1899-08-03
# 5       750      brudes     NaN  NaN     Adolf     Brudes  1899-10-15
# 6       760       dusio     NaN  NaN     Piero      Dusio  1899-10-13
# 7       717  hans_stuck     NaN  NaN      Hans  von Stuck    12/27/00
# 8       749       aston     NaN  NaN      Bill      Aston     3/29/00
# 9       733      miller     NaN  NaN      Chet     Miller     7/19/02
#
#   nationality                                                url  driverId2  \
# 0      French  http://en.wikipedia.org/wiki/Philippe_%C3%89ta...          1
# 1     Belgian          http://en.wikipedia.org/wiki/Arthur_Legat          2
# 2     Italian         http://en.wikipedia.org/wiki/Luigi_Fagioli          3
# 3     Italian    http://en.wikipedia.org/wiki/Clemente_Biondetti          4
# 4  Monegasque          http://en.wikipedia.org/wiki/Louis_Chiron          5
# 5      German          http://en.wikipedia.org/wiki/Adolf_Brudes          6
# 6     Italian           http://en.wikipedia.org/wiki/Piero_Dusio          7
# 7      German        http://en.wikipedia.org/wiki/Hans_Von_Stuck          8
# 8     British            http://en.wikipedia.org/wiki/Bill_Aston          9
# 9    American           http://en.wikipedia.org/wiki/Chet_Miller         10
#
#    dob_year  dob_month  dob_day          driverName        dob2
# 0      1896         12       28  Philippe Étancelin  1896-12-28
# 1      1898         11        1        Arthur Legat   1898-11-1
# 2      1898          6        9       Luigi Fagioli    1898-6-9
# 3      1898          8       18  Clemente Biondetti   1898-8-18
# 4      1899          8        3        Louis Chiron    1899-8-3
# 5      1899         10       15        Adolf Brudes  1899-10-15
# 6      1899         10       13         Piero Dusio  1899-10-13
# 7      1900         12       27      Hans von Stuck  1900-12-27
# 8      1900          3       29          Bill Aston   1900-3-29
# 9      1902          7       19         Chet Miller   1902-7-19

# %%
drivers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 847 entries, 0 to 846
# Data columns (total 15 columns):
# driverId       847 non-null int64
# driverRef      847 non-null object
# number         44 non-null float64
# code           90 non-null object
# forename       847 non-null object
# surname        847 non-null object
# dob            847 non-null object
# nationality    847 non-null object
# url            846 non-null object
# driverId2      847 non-null int64
# dob_year       847 non-null int64
# dob_month      847 non-null int64
# dob_day        847 non-null int64
# driverName     847 non-null object
# dob2           847 non-null object
# dtypes: float64(1), int64(5), object(9)
# memory usage: 99.3+ KB

# %%
drivers["dob2"] = pd.to_datetime(drivers["dob2"])
drivers["driverNationality"] = drivers["nationality"]

# %%
drivers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 847 entries, 0 to 846
# Data columns (total 16 columns):
# driverId             847 non-null int64
# driverRef            847 non-null object
# number               44 non-null float64
# code                 90 non-null object
# forename             847 non-null object
# surname              847 non-null object
# dob                  847 non-null object
# nationality          847 non-null object
# url                  846 non-null object
# driverId2            847 non-null int64
# dob_year             847 non-null int64
# dob_month            847 non-null int64
# dob_day              847 non-null int64
# driverName           847 non-null object
# dob2                 847 non-null datetime64[ns]
# driverNationality    847 non-null object
# dtypes: datetime64[ns](1), float64(1), int64(5), object(9)
# memory usage: 106.0+ KB

# %% [markdown]
# dob2 seems to be in working order, so let's get that back to the drivers2 and merging attempt:

# %%
drivers2 = drivers[["driverId2", "driverRef", "driverName"]]

# %%
drivers2.head(20)
# Out:
#     driverId2   driverRef          driverName
# 0           1   etancelin  Philippe Étancelin
# 1           2       legat        Arthur Legat
# 2           3     fagioli       Luigi Fagioli
# 3           4   biondetti  Clemente Biondetti
# 4           5      chiron        Louis Chiron
# 5           6      brudes        Adolf Brudes
# 6           7       dusio         Piero Dusio
# 7           8  hans_stuck      Hans von Stuck
# 8           9       aston          Bill Aston
# 9          10      miller         Chet Miller
# 10         11   schoeller    Rudolf Schoeller
# 11         12     bonetto      Felice Bonetto
# 12         13     klodwig       Ernst Klodwig
# 13         14       jover          Juan Jover
# 14         15   cabantous      Yves Cabantous
# 15         16      rosier        Louis Rosier
# 16         17      levegh       Pierre Levegh
# 17         18    grignard    Georges Grignard
# 18         19     taruffi       Piero Taruffi
# 19         20      farina         Nino Farina

# %%
drivers2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 847 entries, 0 to 846
# Data columns (total 3 columns):
# driverId2     847 non-null int64
# driverRef     847 non-null object
# driverName    847 non-null object
# dtypes: int64(1), object(2)
# memory usage: 19.9+ KB

# %%
results_pre1 = results2.merge(drivers2, on="driverId2")

# %%
results_pre1[results_pre1.raceId2 == 1].sort_values("positionOrder")
# Out:
#      raceId2  driverId2  constructorId  grid positionText  positionOrder  \
# 7          1         20             51     1            1              1
# 44         1          3             51     2            2              2
# 0          1         58             51     4            3              3
# 56         1         15            154     6            4              4
# 137        1         16            154     9            5              5
# 197        1         88            151    13            6              6
# 180        1         26            151    15            7              7
# 183        1          1            154    14            8              8
# 195        1        130            105    16            9              9
# 289        1        104            105    20           10             10
# 55         1        105            105    20           10             10
# 204        1        112            154    21           11             11
# 229        1         56             51     3            R             12
# 287        1         83            126    19            N             13
# 118        1         92            105     5            R             14
# 176        1         44            105    18            R             15
# 114        1        202            126    17            R             16
# 91         1         90            105     8            R             17
# 74         1          5            105    11            R             18
# 116        1        106            154     7            R             19
# 70         1         65            151    10            R             20
# 52         1        142            151    10            R             20
# 69         1         68            151    12            R             21
#
#      points  statusId       driverRef            driverName
# 7       9.0         1          farina           Nino Farina
# 44      6.0         1         fagioli         Luigi Fagioli
# 0       4.0         1     reg_parnell           Reg Parnell
# 56      3.0        12       cabantous        Yves Cabantous
# 137     2.0        12          rosier          Louis Rosier
# 197     0.0        13          gerard            Bob Gerard
# 180     0.0        13        harrison         Cuth Harrison
# 183     0.0        15       etancelin    Philippe Étancelin
# 195     0.0        16       hampshire       David Hampshire
# 289     0.0        16    shawe_taylor    Brian Shawe Taylor
# 55      0.0        16             fry               Joe Fry
# 204     0.0        16           claes          Johnny Claes
# 229     0.0        44          fangio           Juan Fangio
# 287     0.0        62           kelly             Joe Kelly
# 118     0.0        60            bira           Prince Bira
# 176     0.0         5          murray          David Murray
# 114     0.0         7        crossley        Geoff Crossley
# 91      0.0         5     graffenried  Toulo de Graffenried
# 74      0.0         8          chiron          Louis Chiron
# 116     0.0        51          martin         Eugène Martin
# 70      0.0         6    peter_walker          Peter Walker
# 52      0.0         6            rolt             Tony Rolt
# 69      0.0       126  leslie_johnson        Leslie Johnson

# %% [markdown]
# ### Getting Race Information
#
# This seems like we're moving along, so let's add race information next:

# %%
races = pd.read_csv("../data/f1db_working/races.csv")

# %%
races.head()
# Out:
#    raceId  year  round  circuitId                name     date time  \
# 0     833  1950      1          9  British Grand Prix  5/13/50  NaN
# 1     834  1950      2          6   Monaco Grand Prix  5/21/50  NaN
# 2     835  1950      3         19    Indianapolis 500  5/30/50  NaN
# 3     836  1950      4         66    Swiss Grand Prix   6/4/50  NaN
# 4     837  1950      5         13  Belgian Grand Prix  6/18/50  NaN
#
#                                                  url  raceId2  race_year  \
# 0  http://en.wikipedia.org/wiki/1950_British_Gran...        1       1950
# 1  http://en.wikipedia.org/wiki/1950_Monaco_Grand...        2       1950
# 2  http://en.wikipedia.org/wiki/1950_Indianapolis...        3       1950
# 3  http://en.wikipedia.org/wiki/1950_Swiss_Grand_...        4       1950
# 4  http://en.wikipedia.org/wiki/1950_Belgian_Gran...        5       1950
#
#    race_month  race_day
# 0           5        13
# 1           5        21
# 2           5        30
# 3           6         4
# 4           6        18

# %%
races.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1018 entries, 0 to 1017
# Data columns (total 12 columns):
# raceId        1018 non-null int64
# year          1018 non-null int64
# round         1018 non-null int64
# circuitId     1018 non-null int64
# name          1018 non-null object
# date          1018 non-null object
# time          287 non-null object
# url           1018 non-null object
# raceId2       1018 non-null int64
# race_year     1018 non-null int64
# race_month    1018 non-null int64
# race_day      1018 non-null int64
# dtypes: int64(8), object(4)
# memory usage: 95.5+ KB

# %%
def combine_date(row):
    year = str(row.race_year)
    month = str (row.race_month)
    day = str(row.race_day)
    return year+"-"+month+"-"+day

# %%
races["prixDate"] = races.apply(combine_date, axis=1)

# %%
races.head()
# Out:
#    raceId  year  round  circuitId                name     date time  \
# 0     833  1950      1          9  British Grand Prix  5/13/50  NaN
# 1     834  1950      2          6   Monaco Grand Prix  5/21/50  NaN
# 2     835  1950      3         19    Indianapolis 500  5/30/50  NaN
# 3     836  1950      4         66    Swiss Grand Prix   6/4/50  NaN
# 4     837  1950      5         13  Belgian Grand Prix  6/18/50  NaN
#
#                                                  url  raceId2  race_year  \
# 0  http://en.wikipedia.org/wiki/1950_British_Gran...        1       1950
# 1  http://en.wikipedia.org/wiki/1950_Monaco_Grand...        2       1950
# 2  http://en.wikipedia.org/wiki/1950_Indianapolis...        3       1950
# 3  http://en.wikipedia.org/wiki/1950_Swiss_Grand_...        4       1950
# 4  http://en.wikipedia.org/wiki/1950_Belgian_Gran...        5       1950
#
#    race_month  race_day   prixDate
# 0           5        13  1950-5-13
# 1           5        21  1950-5-21
# 2           5        30  1950-5-30
# 3           6         4   1950-6-4
# 4           6        18  1950-6-18

# %%
races["prixDate"] = pd.to_datetime(races["prixDate"])
races["prixName"] = races["name"]

# %%
races.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1018 entries, 0 to 1017
# Data columns (total 14 columns):
# raceId        1018 non-null int64
# year          1018 non-null int64
# round         1018 non-null int64
# circuitId     1018 non-null int64
# name          1018 non-null object
# date          1018 non-null object
# time          287 non-null object
# url           1018 non-null object
# raceId2       1018 non-null int64
# race_year     1018 non-null int64
# race_month    1018 non-null int64
# race_day      1018 non-null int64
# prixDate      1018 non-null datetime64[ns]
# prixName      1018 non-null object
# dtypes: datetime64[ns](1), int64(8), object(5)
# memory usage: 111.4+ KB

# %%
races2 = races[["raceId2", "year", "round", "circuitId", "prixName", "prixDate"]]

# %%
races2.head(20)
# Out:
#     raceId2  year  round  circuitId            prixName   prixDate
# 0         1  1950      1          9  British Grand Prix 1950-05-13
# 1         2  1950      2          6   Monaco Grand Prix 1950-05-21
# 2         3  1950      3         19    Indianapolis 500 1950-05-30
# 3         4  1950      4         66    Swiss Grand Prix 1950-06-04
# 4         5  1950      5         13  Belgian Grand Prix 1950-06-18
# 5         6  1950      6         55   French Grand Prix 1950-07-02
# 6         7  1950      7         14  Italian Grand Prix 1950-09-03
# 7         8  1951      1         66    Swiss Grand Prix 1951-05-27
# 8         9  1951      2         19    Indianapolis 500 1951-05-30
# 9        10  1951      3         13  Belgian Grand Prix 1951-06-17
# 10       11  1951      4         55   French Grand Prix 1951-07-01
# 11       12  1951      5          9  British Grand Prix 1951-07-14
# 12       13  1951      6         20   German Grand Prix 1951-07-29
# 13       14  1951      7         14  Italian Grand Prix 1951-09-16
# 14       15  1951      8         67  Spanish Grand Prix 1951-10-28
# 15       16  1952      1         66    Swiss Grand Prix 1952-05-18
# 16       17  1952      2         19    Indianapolis 500 1952-05-30
# 17       18  1952      3         13  Belgian Grand Prix 1952-06-22
# 18       19  1952      4         53   French Grand Prix 1952-07-06
# 19       20  1952      5          9  British Grand Prix 1952-07-19

# %%
races2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1018 entries, 0 to 1017
# Data columns (total 6 columns):
# raceId2      1018 non-null int64
# year         1018 non-null int64
# round        1018 non-null int64
# circuitId    1018 non-null int64
# prixName     1018 non-null object
# prixDate     1018 non-null datetime64[ns]
# dtypes: datetime64[ns](1), int64(4), object(1)
# memory usage: 47.8+ KB

# %%
results_pre2 = results2.merge(drivers2, on="driverId2").merge(races2, on="raceId2")

# %%
results_pre2.head()
# Out:
#    raceId2  driverId2  constructorId  grid positionText  positionOrder  \
# 0        1         58             51     4            3              3
# 1        1         20             51     1            1              1
# 2        1          3             51     2            2              2
# 3        1        142            151    10            R             20
# 4        1        105            105    20           10             10
#
#    points  statusId    driverRef     driverName  year  round  circuitId  \
# 0     4.0         1  reg_parnell    Reg Parnell  1950      1          9
# 1     9.0         1       farina    Nino Farina  1950      1          9
# 2     6.0         1      fagioli  Luigi Fagioli  1950      1          9
# 3     0.0         6         rolt      Tony Rolt  1950      1          9
# 4     0.0        16          fry        Joe Fry  1950      1          9
#
#              prixName   prixDate
# 0  British Grand Prix 1950-05-13
# 1  British Grand Prix 1950-05-13
# 2  British Grand Prix 1950-05-13
# 3  British Grand Prix 1950-05-13
# 4  British Grand Prix 1950-05-13

# %%
results_pre2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 24277 entries, 0 to 24276
# Data columns (total 15 columns):
# raceId2          24277 non-null int64
# driverId2        24277 non-null int64
# constructorId    24277 non-null int64
# grid             24277 non-null int64
# positionText     24277 non-null object
# positionOrder    24277 non-null int64
# points           24277 non-null float64
# statusId         24277 non-null int64
# driverRef        24277 non-null object
# driverName       24277 non-null object
# year             24277 non-null int64
# round            24277 non-null int64
# circuitId        24277 non-null int64
# prixName         24277 non-null object
# prixDate         24277 non-null datetime64[ns]
# dtypes: datetime64[ns](1), float64(1), int64(9), object(4)
# memory usage: 3.0+ MB

# %%
results_pre1.head()
# Out:
#    raceId2  driverId2  constructorId  grid positionText  positionOrder  \
# 0        1         58             51     4            3              3
# 1        6         58            105    11            R             13
# 2       11         58              6     9            4              4
# 3       12         58             66    20            5              5
# 4       14         58             66     8            W             21
#
#    points  statusId    driverRef   driverName
# 0     4.0         1  reg_parnell  Reg Parnell
# 1     0.0         5  reg_parnell  Reg Parnell
# 2     3.0        14  reg_parnell  Reg Parnell
# 3     2.0        15  reg_parnell  Reg Parnell
# 4     0.0        54  reg_parnell  Reg Parnell

# %% [markdown]
# ### Getting Constructor Information

# %%
constructors = pd.read_csv("../data/f1db_working/constructors.csv")

# %%
constructors.head()
# Out:
#    constructorId constructorRef        name nationality  \
# 0              1        mclaren     McLaren     British
# 1              2     bmw_sauber  BMW Sauber      German
# 2              3       williams    Williams     British
# 3              4        renault     Renault      French
# 4              5     toro_rosso  Toro Rosso     Italian
#
#                                                  url
# 0               http://en.wikipedia.org/wiki/McLaren
# 1            http://en.wikipedia.org/wiki/BMW_Sauber
# 2  http://en.wikipedia.org/wiki/Williams_Grand_Pr...
# 3  http://en.wikipedia.org/wiki/Renault_in_Formul...
# 4   http://en.wikipedia.org/wiki/Scuderia_Toro_Rosso

# %%
constructors.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 209 entries, 0 to 208
# Data columns (total 5 columns):
# constructorId     209 non-null int64
# constructorRef    209 non-null object
# name              209 non-null object
# nationality       209 non-null object
# url               209 non-null object
# dtypes: int64(1), object(4)
# memory usage: 8.2+ KB

# %%
constructors["constructorNationality"] = constructors["nationality"]
constructors["constructorName"] = constructors["name"]

# %%
constructors.head()
# Out:
#    constructorId constructorRef        name nationality  \
# 0              1        mclaren     McLaren     British
# 1              2     bmw_sauber  BMW Sauber      German
# 2              3       williams    Williams     British
# 3              4        renault     Renault      French
# 4              5     toro_rosso  Toro Rosso     Italian
#
#                                                  url constructorNationality  \
# 0               http://en.wikipedia.org/wiki/McLaren                British
# 1            http://en.wikipedia.org/wiki/BMW_Sauber                 German
# 2  http://en.wikipedia.org/wiki/Williams_Grand_Pr...                British
# 3  http://en.wikipedia.org/wiki/Renault_in_Formul...                 French
# 4   http://en.wikipedia.org/wiki/Scuderia_Toro_Rosso                Italian
#
#   constructorName
# 0         McLaren
# 1      BMW Sauber
# 2        Williams
# 3         Renault
# 4      Toro Rosso

# %%
constructors2 = constructors[["constructorId","constructorRef", "constructorName"]]

# %%
constructors2.head()
# Out:
#    constructorId constructorRef constructorName
# 0              1        mclaren         McLaren
# 1              2     bmw_sauber      BMW Sauber
# 2              3       williams        Williams
# 3              4        renault         Renault
# 4              5     toro_rosso      Toro Rosso

# %%
results_pre3 = results2.merge(drivers2, on="driverId2").merge(races2, on="raceId2").merge(constructors2, on="constructorId")

# %%
results_pre3.head()
# Out:
#    raceId2  driverId2  constructorId  grid positionText  positionOrder  \
# 0        1         58             51     4            3              3
# 1        1         20             51     1            1              1
# 2        1          3             51     2            2              2
# 3        1         56             51     3            R             12
# 4        6         20             51     2            7              7
#
#    points  statusId    driverRef     driverName  year  round  circuitId  \
# 0     4.0         1  reg_parnell    Reg Parnell  1950      1          9
# 1     9.0         1       farina    Nino Farina  1950      1          9
# 2     6.0         1      fagioli  Luigi Fagioli  1950      1          9
# 3     0.0        44       fangio    Juan Fangio  1950      1          9
# 4     0.0        48       farina    Nino Farina  1950      6         55
#
#              prixName   prixDate constructorRef constructorName
# 0  British Grand Prix 1950-05-13           alfa      Alfa Romeo
# 1  British Grand Prix 1950-05-13           alfa      Alfa Romeo
# 2  British Grand Prix 1950-05-13           alfa      Alfa Romeo
# 3  British Grand Prix 1950-05-13           alfa      Alfa Romeo
# 4   French Grand Prix 1950-07-02           alfa      Alfa Romeo

# %% [markdown]
# ### Getting Circuit information
#
# And we're just missing the circuit information.

# %%
circuits = pd.read_csv("../data/f1db_working/circuits.csv")

# %%
circuits.head()
# Out:
#    circuitId   circuitRef                            name      location  \
# 0          1  albert_park  Albert Park Grand Prix Circuit     Melbourne
# 1          2       sepang    Sepang International Circuit  Kuala Lumpur
# 2          3      bahrain   Bahrain International Circuit        Sakhir
# 3          4    catalunya  Circuit de Barcelona-Catalunya      Montmeló
# 4          5     istanbul                   Istanbul Park      Istanbul
#
#      country       lat        lng   alt  \
# 0  Australia -37.84970  144.96800  10.0
# 1   Malaysia   2.76083  101.73800   NaN
# 2    Bahrain  26.03250   50.51060   NaN
# 3      Spain  41.57000    2.26111   NaN
# 4     Turkey  40.95170   29.40500   NaN
#
#                                                  url
# 0  http://en.wikipedia.org/wiki/Melbourne_Grand_P...
# 1  http://en.wikipedia.org/wiki/Sepang_Internatio...
# 2  http://en.wikipedia.org/wiki/Bahrain_Internati...
# 3  http://en.wikipedia.org/wiki/Circuit_de_Barcel...
# 4         http://en.wikipedia.org/wiki/Istanbul_Park

# %%
circuits["circuitName"] = circuits.name

# %%
circuits.head()
# Out:
#    circuitId   circuitRef                            name      location  \
# 0          1  albert_park  Albert Park Grand Prix Circuit     Melbourne
# 1          2       sepang    Sepang International Circuit  Kuala Lumpur
# 2          3      bahrain   Bahrain International Circuit        Sakhir
# 3          4    catalunya  Circuit de Barcelona-Catalunya      Montmeló
# 4          5     istanbul                   Istanbul Park      Istanbul
#
#      country       lat        lng   alt  \
# 0  Australia -37.84970  144.96800  10.0
# 1   Malaysia   2.76083  101.73800   NaN
# 2    Bahrain  26.03250   50.51060   NaN
# 3      Spain  41.57000    2.26111   NaN
# 4     Turkey  40.95170   29.40500   NaN
#
#                                                  url  \
# 0  http://en.wikipedia.org/wiki/Melbourne_Grand_P...
# 1  http://en.wikipedia.org/wiki/Sepang_Internatio...
# 2  http://en.wikipedia.org/wiki/Bahrain_Internati...
# 3  http://en.wikipedia.org/wiki/Circuit_de_Barcel...
# 4         http://en.wikipedia.org/wiki/Istanbul_Park
#
#                       circuitName
# 0  Albert Park Grand Prix Circuit
# 1    Sepang International Circuit
# 2   Bahrain International Circuit
# 3  Circuit de Barcelona-Catalunya
# 4                   Istanbul Park

# %%
circuits2 = circuits[["circuitId", "circuitRef", "circuitName",]]

# %%
circuits2.head()
# Out:
#    circuitId   circuitRef                     circuitName
# 0          1  albert_park  Albert Park Grand Prix Circuit
# 1          2       sepang    Sepang International Circuit
# 2          3      bahrain   Bahrain International Circuit
# 3          4    catalunya  Circuit de Barcelona-Catalunya
# 4          5     istanbul                   Istanbul Park

# %%
results_pre4 = results2.merge(drivers2, on="driverId2").merge(races2, on="raceId2").merge(constructors2, on="constructorId").merge(circuits2, on="circuitId")

# %%
results_pre4.head()
# Out:
#    raceId2  driverId2  constructorId  grid positionText  positionOrder  \
# 0        1         58             51     4            3              3
# 1        1         20             51     1            1              1
# 2        1          3             51     2            2              2
# 3        1         56             51     3            R             12
# 4       12         20             51     3            R             14
#
#    points  statusId    driverRef     driverName  year  round  circuitId  \
# 0     4.0         1  reg_parnell    Reg Parnell  1950      1          9
# 1     9.0         1       farina    Nino Farina  1950      1          9
# 2     6.0         1      fagioli  Luigi Fagioli  1950      1          9
# 3     0.0        44       fangio    Juan Fangio  1950      1          9
# 4     1.0         8       farina    Nino Farina  1951      5          9
#
#              prixName   prixDate constructorRef constructorName   circuitRef  \
# 0  British Grand Prix 1950-05-13           alfa      Alfa Romeo  silverstone
# 1  British Grand Prix 1950-05-13           alfa      Alfa Romeo  silverstone
# 2  British Grand Prix 1950-05-13           alfa      Alfa Romeo  silverstone
# 3  British Grand Prix 1950-05-13           alfa      Alfa Romeo  silverstone
# 4  British Grand Prix 1951-07-14           alfa      Alfa Romeo  silverstone
#
#            circuitName
# 0  Silverstone Circuit
# 1  Silverstone Circuit
# 2  Silverstone Circuit
# 3  Silverstone Circuit
# 4  Silverstone Circuit

# %% [markdown]
# ### Getting Status IDs
#
# I'll add status info to the races

# %%
status = pd.read_csv("../data/f1db_working/status.csv")

# %%
status.head()
# Out:
#    statusId        status
# 0         1      Finished
# 1         2  Disqualified
# 2         3      Accident
# 3         4     Collision
# 4         5        Engine

# %%
status.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 135 entries, 0 to 134
# Data columns (total 2 columns):
# statusId    135 non-null int64
# status      135 non-null object
# dtypes: int64(1), object(1)
# memory usage: 2.2+ KB

# %%
results_pre4.merge(status, on="statusId")
# Out:
#        raceId2  driverId2  constructorId  grid positionText  positionOrder  \
# 0            1         58             51     4            3              3
# 1            1         20             51     1            1              1
# 2            1          3             51     2            2              2
# 3           12         56             51     2            2              2
# 4           29         56            105     4            2              2
# 5           12        204              6     1            1              1
# 6           20        139              6     2            1              1
# 7           37        204              6     2            1              1
# 8           37        316              6     3            2              2
# 9           29        139              6     1            1              1
# 10          54         56              6     2            1              1
# 11          71        350              6     6            1              1
# 12          71        316              6     4            2              2
# 13         116        385              6     5            2              2
# 14         136        385              6     5            3              3
# 15         156        512              6     6            3              3
# 16         229        537              6    19            8              8
# 17         290        582              6     3            2              2
# 18         382        581              6     2            3              3
# 19         382        568              6     1            5              5
# 20         476        611              6     3            2              2
# 21         492        629              6     5            1              1
# 22         508        629              6     5            3              3
# 23         556        699              6     4            2              2
# 24         572        699              6     6            2              2
# 25         623        730              6     2            1              1
# 26         623        709              6     5            3              3
# 27         638        709              6     4            2              2
# 28         650        730              6     5            3              3
# 29         674        730              6     1            2              2
# ...        ...        ...            ...   ...          ...            ...
# 24247      373        622             53    10            R             17
# 24248      972        813              6     2            R             19
# 24249      998        816              4    12            R             19
# 24250      582        746             18    17            R             12
# 24251      598        699             22     8            R             14
# 24252      608        721              3     6            R             18
# 24253      707        781             16    14            R             20
# 24254      682        774             21    16            R             19
# 24255      750        785              3    13           13             13
# 24256      824        740             15    17            R             20
# 24257      783        768              2     5           14             14
# 24258      761        781             11    17            R             17
# 24259      899        816              9     5            R             16
# 24260      964        777              6     3           14             14
# 24261      775        782              5    19           17             17
# 24262      911        795             15    17            R             19
# 24263      891        762              9     4           15             15
# 24264      964        821             10     6            R             15
# 24265        9         73            150     4            8              8
# 24266      128        256            183     6            9              9
# 24267      214        517             66     6            R             23
# 24268      801        793              7     8            R             19
# 24269      744        739             15    15            R             16
# 24270      776        779             12    20            R             19
# 24271      685        767             18    21            W             22
# 24272      685        762             18    20            W             21
# 24273      702        785             19    16            R             19
# 24274      841        807              3    18            R             24
# 24275      841        770            164    24            R             23
# 24276      932        777              6    18            R             16
#
#        points  statusId           driverRef             driverName  year  \
# 0        4.00         1         reg_parnell            Reg Parnell  1950
# 1        9.00         1              farina            Nino Farina  1950
# 2        6.00         1             fagioli          Luigi Fagioli  1950
# 3        6.00         1              fangio            Juan Fangio  1951
# 4        6.00         1              fangio            Juan Fangio  1953
# 5        8.00         1            gonzalez  José Froilán González  1951
# 6        9.00         1              ascari         Alberto Ascari  1952
# 7        8.14         1            gonzalez  José Froilán González  1954
# 8        6.14         1            hawthorn          Mike Hawthorn  1954
# 9        8.50         1              ascari         Alberto Ascari  1953
# 10       8.00         1              fangio            Juan Fangio  1956
# 11       8.00         1             collins          Peter Collins  1958
# 12       7.00         1            hawthorn          Mike Hawthorn  1958
# 13       6.00         1             surtees           John Surtees  1963
# 14       4.00         1             surtees           John Surtees  1965
# 15       4.00         1                amon             Chris Amon  1967
# 16       0.00         1                ickx             Jacky Ickx  1973
# 17       6.00         1               lauda             Niki Lauda  1977
# 18       4.00         1              tambay         Patrick Tambay  1983
# 19       2.00         1              arnoux            René Arnoux  1983
# 20       6.00         1             mansell          Nigel Mansell  1989
# 21       9.00         1               prost            Alain Prost  1990
# 22       4.00         1               prost            Alain Prost  1991
# 23       6.00         1               alesi             Jean Alesi  1994
# 24       6.00         1               alesi             Jean Alesi  1995
# 25      10.00         1  michael_schumacher     Michael Schumacher  1998
# 26       4.00         1              irvine           Eddie Irvine  1998
# 27       6.00         1              irvine           Eddie Irvine  1999
# 28       4.00         1  michael_schumacher     Michael Schumacher  2000
# 29       6.00         1  michael_schumacher     Michael Schumacher  2001
# ...       ...       ...                 ...                    ...   ...
# 24247    0.00       105             warwick          Derek Warwick  1982
# 24248    0.00       105              vettel       Sebastian Vettel  2017
# 24249    0.00       137           ricciardo       Daniel Ricciardo  2019
# 24250    0.00        93                lamy             Pedro Lamy  1996
# 24251    0.00        74               alesi             Jean Alesi  1997
# 24252    0.00        74            frentzen  Heinz-Harald Frentzen  1997
# 24253    0.00        74              button          Jenson Button  2003
# 24254    0.00        74            bernoldi       Enrique Bernoldi  2002
# 24255    0.00        59            pizzonia       Antônio Pizzonia  2005
# 24256    0.00        39                rosa       Pedro de la Rosa  2010
# 24257    0.00        39            heidfeld          Nick Heidfeld  2007
# 24258    0.00        39              button          Jenson Button  2006
# 24259    0.00        39           ricciardo       Daniel Ricciardo  2014
# 24260    0.00        34           raikkonen         Kimi Räikkönen  2017
# 24261    0.00        34              liuzzi      Vitantonio Liuzzi  2007
# 24262    0.00        34               sutil           Adrian Sutil  2014
# 24263    0.00        34              webber            Mark Webber  2013
# 24264    0.00       136               perez           Sergio Pérez  2017
# 24265    0.00       127              darter           Duane Carter  1951
# 24266    0.00       118        jack_brabham           Jack Brabham  1964
# 24267    0.00       107               marko           Helmut Marko  1972
# 24268    0.00        28               glock             Timo Glock  2008
# 24269    0.00        56          villeneuve     Jacques Villeneuve  2005
# 24270    0.00        35              albers      Christijan Albers  2007
# 24271    0.00        78               yoong             Alex Yoong  2002
# 24272    0.00        78              webber            Mark Webber  2002
# 24273    0.00        72            pizzonia       Antônio Pizzonia  2003
# 24274    0.00       129           maldonado       Pastor Maldonado  2011
# 24275    0.00       128         karthikeyan     Narain Karthikeyan  2011
# 24276    0.00       135           raikkonen         Kimi Räikkönen  2015
#
#        round  circuitId                   prixName   prixDate  constructorRef  \
# 0          1          9         British Grand Prix 1950-05-13            alfa
# 1          1          9         British Grand Prix 1950-05-13            alfa
# 2          1          9         British Grand Prix 1950-05-13            alfa
# 3          5          9         British Grand Prix 1951-07-14            alfa
# 4          6          9         British Grand Prix 1953-07-18        maserati
# 5          5          9         British Grand Prix 1951-07-14         ferrari
# 6          5          9         British Grand Prix 1952-07-19         ferrari
# 7          5          9         British Grand Prix 1954-07-17         ferrari
# 8          5          9         British Grand Prix 1954-07-17         ferrari
# 9          6          9         British Grand Prix 1953-07-18         ferrari
# 10         6          9         British Grand Prix 1956-07-14         ferrari
# 11         7          9         British Grand Prix 1958-07-19         ferrari
# 12         7          9         British Grand Prix 1958-07-19         ferrari
# 13         5          9         British Grand Prix 1963-07-20         ferrari
# 14         5          9         British Grand Prix 1965-07-10         ferrari
# 15         6          9         British Grand Prix 1967-07-15         ferrari
# 16         9          9         British Grand Prix 1973-07-14         ferrari
# 17        10          9         British Grand Prix 1977-07-16         ferrari
# 18         9          9         British Grand Prix 1983-07-16         ferrari
# 19         9          9         British Grand Prix 1983-07-16         ferrari
# 20         8          9         British Grand Prix 1989-07-16         ferrari
# 21         8          9         British Grand Prix 1990-07-15         ferrari
# 22         8          9         British Grand Prix 1991-07-14         ferrari
# 23         8          9         British Grand Prix 1994-07-10         ferrari
# 24         8          9         British Grand Prix 1995-07-16         ferrari
# 25         9          9         British Grand Prix 1998-07-12         ferrari
# 26         9          9         British Grand Prix 1998-07-12         ferrari
# 27         8          9         British Grand Prix 1999-07-11         ferrari
# 28         4          9         British Grand Prix 2000-04-23         ferrari
# 29        11          9         British Grand Prix 2001-07-15         ferrari
# ...      ...        ...                        ...        ...             ...
# 24247     16         44  Caesars Palace Grand Prix 1982-09-25         toleman
# 24248     16         22        Japanese Grand Prix 2017-10-08         ferrari
# 24249      1          1      Australian Grand Prix 2019-03-17         renault
# 24250      1          1      Australian Grand Prix 1996-03-10         minardi
# 24251      1          1      Australian Grand Prix 1997-03-09        benetton
# 24252     11         11       Hungarian Grand Prix 1997-08-10        williams
# 24253     10          8          French Grand Prix 2003-07-06             bar
# 24254      2          2       Malaysian Grand Prix 2002-03-17          arrows
# 24255     19         17         Chinese Grand Prix 2005-10-16        williams
# 24256      4         17         Chinese Grand Prix 2010-04-18          sauber
# 24257     15         16        Japanese Grand Prix 2007-09-30      bmw_sauber
# 24258     11          8          French Grand Prix 2006-07-16           honda
# 24259      2          2       Malaysian Grand Prix 2014-03-30        red_bull
# 24260      8         73      Azerbaijan Grand Prix 2017-06-25         ferrari
# 24261      7         19   United States Grand Prix 2007-06-17      toro_rosso
# 24262     14         15       Singapore Grand Prix 2014-09-21          sauber
# 24263     13         15       Singapore Grand Prix 2013-09-22        red_bull
# 24264      8         73      Azerbaijan Grand Prix 2017-06-25     force_india
# 24265      2         19           Indianapolis 500 1951-05-30           deidt
# 24266      7         57        Austrian Grand Prix 1964-08-23  brabham-climax
# 24267      6         51          French Grand Prix 1972-07-02             brm
# 24268     16         16        Japanese Grand Prix 2008-10-12          toyota
# 24269     13         11       Hungarian Grand Prix 2005-07-31          sauber
# 24270      8          8          French Grand Prix 2007-07-01          spyker
# 24271      5          4         Spanish Grand Prix 2002-04-28         minardi
# 24272      5          4         Spanish Grand Prix 2002-04-28         minardi
# 24273      5          4         Spanish Grand Prix 2003-05-04          jaguar
# 24274      2          2       Malaysian Grand Prix 2011-04-10        williams
# 24275      2          2       Malaysian Grand Prix 2011-04-10             hrt
# 24276     16         69   United States Grand Prix 2015-10-25         ferrari
#
#       constructorName    circuitRef                     circuitName  \
# 0          Alfa Romeo   silverstone             Silverstone Circuit
# 1          Alfa Romeo   silverstone             Silverstone Circuit
# 2          Alfa Romeo   silverstone             Silverstone Circuit
# 3          Alfa Romeo   silverstone             Silverstone Circuit
# 4            Maserati   silverstone             Silverstone Circuit
# 5             Ferrari   silverstone             Silverstone Circuit
# 6             Ferrari   silverstone             Silverstone Circuit
# 7             Ferrari   silverstone             Silverstone Circuit
# 8             Ferrari   silverstone             Silverstone Circuit
# 9             Ferrari   silverstone             Silverstone Circuit
# 10            Ferrari   silverstone             Silverstone Circuit
# 11            Ferrari   silverstone             Silverstone Circuit
# 12            Ferrari   silverstone             Silverstone Circuit
# 13            Ferrari   silverstone             Silverstone Circuit
# 14            Ferrari   silverstone             Silverstone Circuit
# 15            Ferrari   silverstone             Silverstone Circuit
# 16            Ferrari   silverstone             Silverstone Circuit
# 17            Ferrari   silverstone             Silverstone Circuit
# 18            Ferrari   silverstone             Silverstone Circuit
# 19            Ferrari   silverstone             Silverstone Circuit
# 20            Ferrari   silverstone             Silverstone Circuit
# 21            Ferrari   silverstone             Silverstone Circuit
# 22            Ferrari   silverstone             Silverstone Circuit
# 23            Ferrari   silverstone             Silverstone Circuit
# 24            Ferrari   silverstone             Silverstone Circuit
# 25            Ferrari   silverstone             Silverstone Circuit
# 26            Ferrari   silverstone             Silverstone Circuit
# 27            Ferrari   silverstone             Silverstone Circuit
# 28            Ferrari   silverstone             Silverstone Circuit
# 29            Ferrari   silverstone             Silverstone Circuit
# ...               ...           ...                             ...
# 24247         Toleman     las_vegas        Las Vegas Street Circuit
# 24248         Ferrari        suzuka                  Suzuka Circuit
# 24249         Renault   albert_park  Albert Park Grand Prix Circuit
# 24250         Minardi   albert_park  Albert Park Grand Prix Circuit
# 24251        Benetton   albert_park  Albert Park Grand Prix Circuit
# 24252        Williams   hungaroring                     Hungaroring
# 24253             BAR   magny_cours   Circuit de Nevers Magny-Cours
# 24254          Arrows        sepang    Sepang International Circuit
# 24255        Williams      shanghai  Shanghai International Circuit
# 24256          Sauber      shanghai  Shanghai International Circuit
# 24257      BMW Sauber          fuji                   Fuji Speedway
# 24258           Honda   magny_cours   Circuit de Nevers Magny-Cours
# 24259        Red Bull        sepang    Sepang International Circuit
# 24260         Ferrari           BAK               Baku City Circuit
# 24261      Toro Rosso  indianapolis     Indianapolis Motor Speedway
# 24262          Sauber    marina_bay       Marina Bay Street Circuit
# 24263        Red Bull    marina_bay       Marina Bay Street Circuit
# 24264     Force India           BAK               Baku City Circuit
# 24265           Deidt  indianapolis     Indianapolis Motor Speedway
# 24266  Brabham-Climax       zeltweg                         Zeltweg
# 24267             BRM       charade                 Charade Circuit
# 24268          Toyota          fuji                   Fuji Speedway
# 24269          Sauber   hungaroring                     Hungaroring
# 24270          Spyker   magny_cours   Circuit de Nevers Magny-Cours
# 24271         Minardi     catalunya  Circuit de Barcelona-Catalunya
# 24272         Minardi     catalunya  Circuit de Barcelona-Catalunya
# 24273          Jaguar     catalunya  Circuit de Barcelona-Catalunya
# 24274        Williams        sepang    Sepang International Circuit
# 24275             HRT        sepang    Sepang International Circuit
# 24276         Ferrari      americas         Circuit of the Americas
#
#                status
# 0            Finished
# 1            Finished
# 2            Finished
# 3            Finished
# 4            Finished
# 5            Finished
# 6            Finished
# 7            Finished
# 8            Finished
# 9            Finished
# 10           Finished
# 11           Finished
# 12           Finished
# 13           Finished
# 14           Finished
# 15           Finished
# 16           Finished
# 17           Finished
# 18           Finished
# 19           Finished
# 20           Finished
# 21           Finished
# 22           Finished
# 23           Finished
# 24           Finished
# 25           Finished
# 26           Finished
# 27           Finished
# 28           Finished
# 29           Finished
# ...               ...
# 24247     Spark plugs
# 24248     Spark plugs
# 24249          Damage
# 24250     Safety belt
# 24251            Fuel
# 24252            Fuel
# 24253            Fuel
# 24254            Fuel
# 24255   Tyre puncture
# 24256       Technical
# 24257       Technical
# 24258       Technical
# 24259       Technical
# 24260  Water pressure
# 24261  Water pressure
# 24262  Water pressure
# 24263  Water pressure
# 24264            Seat
# 24265        +20 Laps
# 24266        +29 Laps
# 24267      Eye injury
# 24268     Driver Seat
# 24269     Engine fire
# 24270      Refuelling
# 24271          Safety
# 24272          Safety
# 24273  Launch control
# 24274  Engine misfire
# 24275        +42 Laps
# 24276      Brake duct
#
# [24277 rows x 20 columns]

# %%
results_pre4 = results_pre4.merge(status, on="statusId")

# %%
results_pre4.head(10)
# Out:
#    raceId2  driverId2  constructorId  grid positionText  positionOrder  \
# 0        1         58             51     4            3              3
# 1        1         20             51     1            1              1
# 2        1          3             51     2            2              2
# 3       12         56             51     2            2              2
# 4       29         56            105     4            2              2
# 5       12        204              6     1            1              1
# 6       20        139              6     2            1              1
# 7       37        204              6     2            1              1
# 8       37        316              6     3            2              2
# 9       29        139              6     1            1              1
#
#    points  statusId    driverRef             driverName  year  round  \
# 0    4.00         1  reg_parnell            Reg Parnell  1950      1
# 1    9.00         1       farina            Nino Farina  1950      1
# 2    6.00         1      fagioli          Luigi Fagioli  1950      1
# 3    6.00         1       fangio            Juan Fangio  1951      5
# 4    6.00         1       fangio            Juan Fangio  1953      6
# 5    8.00         1     gonzalez  José Froilán González  1951      5
# 6    9.00         1       ascari         Alberto Ascari  1952      5
# 7    8.14         1     gonzalez  José Froilán González  1954      5
# 8    6.14         1     hawthorn          Mike Hawthorn  1954      5
# 9    8.50         1       ascari         Alberto Ascari  1953      6
#
#    circuitId            prixName   prixDate constructorRef constructorName  \
# 0          9  British Grand Prix 1950-05-13           alfa      Alfa Romeo
# 1          9  British Grand Prix 1950-05-13           alfa      Alfa Romeo
# 2          9  British Grand Prix 1950-05-13           alfa      Alfa Romeo
# 3          9  British Grand Prix 1951-07-14           alfa      Alfa Romeo
# 4          9  British Grand Prix 1953-07-18       maserati        Maserati
# 5          9  British Grand Prix 1951-07-14        ferrari         Ferrari
# 6          9  British Grand Prix 1952-07-19        ferrari         Ferrari
# 7          9  British Grand Prix 1954-07-17        ferrari         Ferrari
# 8          9  British Grand Prix 1954-07-17        ferrari         Ferrari
# 9          9  British Grand Prix 1953-07-18        ferrari         Ferrari
#
#     circuitRef          circuitName    status
# 0  silverstone  Silverstone Circuit  Finished
# 1  silverstone  Silverstone Circuit  Finished
# 2  silverstone  Silverstone Circuit  Finished
# 3  silverstone  Silverstone Circuit  Finished
# 4  silverstone  Silverstone Circuit  Finished
# 5  silverstone  Silverstone Circuit  Finished
# 6  silverstone  Silverstone Circuit  Finished
# 7  silverstone  Silverstone Circuit  Finished
# 8  silverstone  Silverstone Circuit  Finished
# 9  silverstone  Silverstone Circuit  Finished

# %%
results_pre4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 24277 entries, 0 to 24276
# Data columns (total 20 columns):
# raceId2            24277 non-null int64
# driverId2          24277 non-null int64
# constructorId      24277 non-null int64
# grid               24277 non-null int64
# positionText       24277 non-null object
# positionOrder      24277 non-null int64
# points             24277 non-null float64
# statusId           24277 non-null int64
# driverRef          24277 non-null object
# driverName         24277 non-null object
# year               24277 non-null int64
# round              24277 non-null int64
# circuitId          24277 non-null int64
# prixName           24277 non-null object
# prixDate           24277 non-null datetime64[ns]
# constructorRef     24277 non-null object
# constructorName    24277 non-null object
# circuitRef         24277 non-null object
# circuitName        24277 non-null object
# status             24277 non-null object
# dtypes: datetime64[ns](1), float64(1), int64(9), object(9)
# memory usage: 3.9+ MB

# %%
results_final = results_pre4[["raceId2", "prixName", "year", "round", "prixDate", "constructorName", "driverName",
                              "grid","positionText","positionOrder","points","status"]].sort_values(["raceId2","positionOrder"])

# %%
results_final.head(10)
# Out:
#        raceId2            prixName  year  round   prixDate constructorName  \
# 1            1  British Grand Prix  1950      1 1950-05-13      Alfa Romeo
# 2            1  British Grand Prix  1950      1 1950-05-13      Alfa Romeo
# 0            1  British Grand Prix  1950      1 1950-05-13      Alfa Romeo
# 16272        1  British Grand Prix  1950      1 1950-05-13     Talbot-Lago
# 16273        1  British Grand Prix  1950      1 1950-05-13     Talbot-Lago
# 6569         1  British Grand Prix  1950      1 1950-05-13             ERA
# 6568         1  British Grand Prix  1950      1 1950-05-13             ERA
# 18116        1  British Grand Prix  1950      1 1950-05-13     Talbot-Lago
# 7291         1  British Grand Prix  1950      1 1950-05-13        Maserati
# 7290         1  British Grand Prix  1950      1 1950-05-13        Maserati
#
#                driverName  grid positionText  positionOrder  points    status
# 1             Nino Farina     1            1              1     9.0  Finished
# 2           Luigi Fagioli     2            2              2     6.0  Finished
# 0             Reg Parnell     4            3              3     4.0  Finished
# 16272      Yves Cabantous     6            4              4     3.0   +2 Laps
# 16273        Louis Rosier     9            5              5     2.0   +2 Laps
# 6569           Bob Gerard    13            6              6     0.0   +3 Laps
# 6568        Cuth Harrison    15            7              7     0.0   +3 Laps
# 18116  Philippe Étancelin    14            8              8     0.0   +5 Laps
# 7291      David Hampshire    16            9              9     0.0   +6 Laps
# 7290              Joe Fry    20           10             10     0.0   +6 Laps

# %%
results_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 24277 entries, 1 to 20564
# Data columns (total 12 columns):
# raceId2            24277 non-null int64
# prixName           24277 non-null object
# year               24277 non-null int64
# round              24277 non-null int64
# prixDate           24277 non-null datetime64[ns]
# constructorName    24277 non-null object
# driverName         24277 non-null object
# grid               24277 non-null int64
# positionText       24277 non-null object
# positionOrder      24277 non-null int64
# points             24277 non-null float64
# status             24277 non-null object
# dtypes: datetime64[ns](1), float64(1), int64(5), object(5)
# memory usage: 2.4+ MB

# %%
results_final.to_csv("../data/f1db_results.csv", index=False)

# %% [markdown]
# Now let's just look at one season... from this

# %%
test1 = results_final[results_final.year == 1991]

# %%
test1.head()
# Out:
#        raceId2                  prixName  year  round   prixDate  \
# 5149       501  United States Grand Prix  1991      1 1991-03-10
# 5145       501  United States Grand Prix  1991      1 1991-03-10
# 5156       501  United States Grand Prix  1991      1 1991-03-10
# 5151       501  United States Grand Prix  1991      1 1991-03-10
# 10710      501  United States Grand Prix  1991      1 1991-03-10
#
#       constructorName       driverName  grid positionText  positionOrder  \
# 5149          McLaren     Ayrton Senna     1            1              1
# 5145          Ferrari      Alain Prost     2            2              2
# 5156         Benetton    Nelson Piquet     5            3              3
# 5151          Tyrrell   Stefano Modena    11            4              4
# 10710         Tyrrell  Satoru Nakajima    16            5              5
#
#        points    status
# 5149     10.0  Finished
# 5145      6.0  Finished
# 5156      4.0  Finished
# 5151      3.0  Finished
# 10710     2.0    +1 Lap

# %%
test1.to_csv("../data/f1db_results1991.csv", index=False)

# %% [markdown]
# Now that I have the 1991 season separate, I'll work with it to figure out the timeline

# %%
test2 = results_final[results_final.driverName == "Ayrton Senna"]

# %%
test2.head()
# Out:
#        raceId2                  prixName  year  round   prixDate  \
# 11436      389      Brazilian Grand Prix  1984      1 1984-03-25
# 6862       390  South African Grand Prix  1984      2 1984-04-07
# 16813      391        Belgian Grand Prix  1984      3 1984-04-29
# 23103      392     San Marino Grand Prix  1984      4 1984-05-06
# 11352      393         French Grand Prix  1984      5 1984-05-20
#
#       constructorName    driverName  grid positionText  positionOrder  points  \
# 11436         Toleman  Ayrton Senna    16            R             26     0.0
# 6862          Toleman  Ayrton Senna    13            6              6     1.0
# 16813         Toleman  Ayrton Senna    19            6              6     1.0
# 23103         Toleman  Ayrton Senna     0            F             28     0.0
# 11352         Toleman  Ayrton Senna    13            R             19     0.0
#
#                 status
# 11436            Turbo
# 6862           +3 Laps
# 16813          +2 Laps
# 23103  Did not qualify
# 11352            Turbo

# %%
test2.to_csv("../data/f1db_senna.csv", index=False)
