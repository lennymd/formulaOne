# %% [markdown]
# # Looking for the best Formula 1 season
#
# For my master's project, I'm making a piece about answering the question: **What championship winning team had the best Formula 1 season?**
#
# To do this I was working with data provided by the [Ergast Developer API](https://ergast.com/mrd/). I noticed an error in the driver-constructor pairing for the 1950 season and wanted to verify things without moving forward. I was originally going to create a table of the driver-constructor pairs for each race, and then compare it with the data I had.
#
# Instead I've chosen to go straight to the source for F1 information ([formula1.com](https://formula1.com)) and scrape the race results for each race. I did this scraping on 2019-06-21 and 2019-06-22 and I'll be now working with that data to do my analysis.
#
# Because it is data from a primary-source, I have some more confidence in it.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# The first thing to do is to import the data

# %%
race_results = pd.read_csv("../formula1-data/results_all_updated.csv")

# %%
race_results.head()
# Out:
#    raceId  year  raceRound         date           prix driverFirstName  \
# 0       1  1950          1  13 May 1950  Great Britain            Nino
# 1       1  1950          1  13 May 1950  Great Britain           Luigi
# 2       1  1950          1  13 May 1950  Great Britain             Reg
# 3       1  1950          1  13 May 1950  Great Britain     Yves Giraud
# 4       1  1950          1  13 May 1950  Great Britain           Louis
#
#   driverLastName driverCode  constructor finishingPosition  positionOrder  \
# 0         Farina        FAR   Alfa Romeo                 1              1
# 1        Fagioli        FAG   Alfa Romeo                 2              2
# 2        Parnell        PAR   Alfa Romeo                 3              3
# 3      Cabantous        CAB  Talbot-Lago                 4              4
# 4         Rosier        ROS  Talbot-Lago                 5              5
#
#    laps         time  points
# 0  70.0  2:13:23.600     9.0
# 1  70.0      +2.600s     6.0
# 2  70.0     +52.000s     4.0
# 3  68.0      +2 laps     3.0
# 4  68.0      +2 laps     2.0

# %%
race_results.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22535 entries, 0 to 22534
# Data columns (total 14 columns):
# raceId               22535 non-null int64
# year                 22535 non-null int64
# raceRound            22535 non-null int64
# date                 22535 non-null object
# prix                 22535 non-null object
# driverFirstName      22535 non-null object
# driverLastName       22535 non-null object
# driverCode           22535 non-null object
# constructor          22509 non-null object
# finishingPosition    22535 non-null object
# positionOrder        22535 non-null int64
# laps                 22311 non-null float64
# time                 22527 non-null object
# points               22535 non-null float64
# dtypes: float64(2), int64(4), object(8)
# memory usage: 2.4+ MB

# %% [markdown]
# Let's also check how many races we have:

# %%
race_results.raceId.max()
# Out:
# 1004

# %% [markdown]
# Things seem to be in good order. For most of the work, I won't particularly care for a few of the columns, namely:
#
# * laps
# * points
# * driverCode
# * date
#
# So, let's drop those:

# %%
results = race_results.copy().drop(columns=["date", "laps", "points", "driverCode"])
results = results[results.year < 2019]

# %%
results.head()
# Out:
#    raceId  year  raceRound           prix driverFirstName driverLastName  \
# 0       1  1950          1  Great Britain            Nino         Farina
# 1       1  1950          1  Great Britain           Luigi        Fagioli
# 2       1  1950          1  Great Britain             Reg        Parnell
# 3       1  1950          1  Great Britain     Yves Giraud      Cabantous
# 4       1  1950          1  Great Britain           Louis         Rosier
#
#    constructor finishingPosition  positionOrder         time
# 0   Alfa Romeo                 1              1  2:13:23.600
# 1   Alfa Romeo                 2              2      +2.600s
# 2   Alfa Romeo                 3              3     +52.000s
# 3  Talbot-Lago                 4              4      +2 laps
# 4  Talbot-Lago                 5              5      +2 laps

# %% [markdown]
# For most of my analysis, I'm looking only at the teams that won championships, so let's slice the results table and keep only the different championship runs. I scraped more of the F1 site to find the teams that the winning drivers were a part of each season and am working with that.

# %%
teams = pd.read_csv("../formula1-data/winners_clean.csv")

# %%
teams
# Out:
#     year              constructor constructor_clean
# 0   1950               Alfa Romeo        Alfa Romeo
# 1   1951               Alfa Romeo        Alfa Romeo
# 2   1952                  Ferrari           Ferrari
# 3   1953                  Ferrari           Ferrari
# 4   1954            Mercedes-Benz          Mercedes
# 5   1955            Mercedes-Benz          Mercedes
# 6   1956                  Ferrari           Ferrari
# 7   1957                 Maserati          Maserati
# 8   1958                  Ferrari           Ferrari
# 9   1959            Cooper Climax            Cooper
# 10  1960            Cooper Climax            Cooper
# 11  1961                  Ferrari           Ferrari
# 12  1962                      BRM               BRM
# 13  1963             Lotus Climax             Lotus
# 14  1964                  Ferrari           Ferrari
# 15  1965             Lotus Climax             Lotus
# 16  1966            Brabham Repco           Brabham
# 17  1967            Brabham Repco           Brabham
# 18  1968               Lotus Ford             Lotus
# 19  1969               Matra Ford             Matra
# 20  1970               Lotus Ford             Lotus
# 21  1971             Tyrrell Ford           Tyrrell
# 22  1972               Lotus Ford             Lotus
# 23  1973             Tyrrell Ford           Tyrrell
# 24  1974             McLaren Ford           McLaren
# 25  1975                  Ferrari           Ferrari
# 26  1976             McLaren Ford           McLaren
# 27  1977                  Ferrari           Ferrari
# 28  1978               Lotus Ford             Lotus
# 29  1979                  Ferrari           Ferrari
# ..   ...                      ...               ...
# 40  1990            McLaren Honda           McLaren
# 41  1991            McLaren Honda           McLaren
# 42  1992         Williams Renault          Williams
# 43  1993         Williams Renault          Williams
# 44  1994            Benetton Ford          Benetton
# 45  1995         Benetton Renault          Benetton
# 46  1996         Williams Renault          Williams
# 47  1997         Williams Renault          Williams
# 48  1998         McLaren Mercedes           McLaren
# 49  1999         McLaren Mercedes           McLaren
# 50  2000                  Ferrari           Ferrari
# 51  2001                  Ferrari           Ferrari
# 52  2002                  Ferrari           Ferrari
# 53  2003                  Ferrari           Ferrari
# 54  2004                  Ferrari           Ferrari
# 55  2005                  Renault           Renault
# 56  2006                  Renault           Renault
# 57  2007                  Ferrari           Ferrari
# 58  2008         McLaren Mercedes           McLaren
# 59  2009           Brawn Mercedes             Brawn
# 60  2010              RBR Renault   Red Bull Racing
# 61  2011  Red Bull Racing Renault   Red Bull Racing
# 62  2012  Red Bull Racing Renault   Red Bull Racing
# 63  2013  Red Bull Racing Renault   Red Bull Racing
# 64  2014                 Mercedes          Mercedes
# 65  2015                 Mercedes          Mercedes
# 66  2016                 Mercedes          Mercedes
# 67  2017                 Mercedes          Mercedes
# 68  2018                 Mercedes          Mercedes
# 69  2019                 Mercedes          Mercedes
#
# [70 rows x 3 columns]

# %% [markdown]
# One thing with the teams is that they change names of the year (look at McLaren for instance) and often their name is the constructor followed by the engine they're using during a particular year.
#
# To account for this, I created a column of clean names that keep the constructor consistent across the years. To slice my results data, I will merge this table to the results table and only keep the lines that match both `year` and `constructor`.

# %%
comparison = pd.merge(results, teams, how="left", on=["year", "constructor"], indicator=True)

# %%
comparison.head()
# Out:
#    raceId  year  raceRound           prix driverFirstName driverLastName  \
# 0       1  1950          1  Great Britain            Nino         Farina
# 1       1  1950          1  Great Britain           Luigi        Fagioli
# 2       1  1950          1  Great Britain             Reg        Parnell
# 3       1  1950          1  Great Britain     Yves Giraud      Cabantous
# 4       1  1950          1  Great Britain           Louis         Rosier
#
#    constructor finishingPosition  positionOrder         time  \
# 0   Alfa Romeo                 1              1  2:13:23.600
# 1   Alfa Romeo                 2              2      +2.600s
# 2   Alfa Romeo                 3              3     +52.000s
# 3  Talbot-Lago                 4              4      +2 laps
# 4  Talbot-Lago                 5              5      +2 laps
#
#   constructor_clean     _merge
# 0        Alfa Romeo       both
# 1        Alfa Romeo       both
# 2        Alfa Romeo       both
# 3               NaN  left_only
# 4               NaN  left_only

# %%
results_slice = comparison[comparison._merge == "both"]
results_slice.head(22)
# Out:
#      raceId  year  raceRound           prix driverFirstName driverLastName  \
# 0         1  1950          1  Great Britain            Nino         Farina
# 1         1  1950          1  Great Britain           Luigi        Fagioli
# 2         1  1950          1  Great Britain             Reg        Parnell
# 12        1  1950          1  Great Britain     Juan Manuel         Fangio
# 23        2  1950          2         Monaco     Juan Manuel         Fangio
# 33        2  1950          2         Monaco           Luigi        Fagioli
# 34        2  1950          2         Monaco            Nino         Farina
# 78        4  1950          4    Switzerland            Nino         Farina
# 79        4  1950          4    Switzerland           Luigi        Fagioli
# 89        4  1950          4    Switzerland     Juan Manuel         Fangio
# 96        5  1950          5        Belgium     Juan Manuel         Fangio
# 97        5  1950          5        Belgium           Luigi        Fagioli
# 99        5  1950          5        Belgium            Nino         Farina
# 110       6  1950          6         France     Juan Manuel         Fangio
# 111       6  1950          6         France           Luigi        Fagioli
# 118       6  1950          6         France            Nino         Farina
# 130       7  1950          7          Italy            Nino         Farina
# 133       7  1950          7          Italy           Luigi        Fagioli
# 143       7  1950          7          Italy           Piero        Taruffi
# 144       7  1950          7          Italy     Juan Manuel         Fangio
# 146       7  1950          7          Italy     Juan Manuel         Fangio
# 154       7  1950          7          Italy        Consalvo         Sanesi
#
#     constructor finishingPosition  positionOrder         time  \
# 0    Alfa Romeo                 1              1  2:13:23.600
# 1    Alfa Romeo                 2              2      +2.600s
# 2    Alfa Romeo                 3              3     +52.000s
# 12   Alfa Romeo                NC             13          DNF
# 23   Alfa Romeo                 1              1  3:13:18.700
# 33   Alfa Romeo                NC             11          DNF
# 34   Alfa Romeo                NC             12          DNF
# 78   Alfa Romeo                 1              1  2:02:53.700
# 79   Alfa Romeo                 2              2      +0.400s
# 89   Alfa Romeo                NC             12          DNF
# 96   Alfa Romeo                 1              1  2:47:26.000
# 97   Alfa Romeo                 2              2     +14.000s
# 99   Alfa Romeo                 4              4    +245.000s
# 110  Alfa Romeo                 1              1  2:57:52.800
# 111  Alfa Romeo                 2              2     +25.700s
# 118  Alfa Romeo                 7              9          DNF
# 130  Alfa Romeo                 1              1  2:51:17.400
# 133  Alfa Romeo                 3              4     +95.600s
# 143  Alfa Romeo                NC             14          SHC
# 144  Alfa Romeo                NC             15          DNF
# 146  Alfa Romeo                NC             17          DNF
# 154  Alfa Romeo                NC             25          DNF
#
#     constructor_clean _merge
# 0          Alfa Romeo   both
# 1          Alfa Romeo   both
# 2          Alfa Romeo   both
# 12         Alfa Romeo   both
# 23         Alfa Romeo   both
# 33         Alfa Romeo   both
# 34         Alfa Romeo   both
# 78         Alfa Romeo   both
# 79         Alfa Romeo   both
# 89         Alfa Romeo   both
# 96         Alfa Romeo   both
# 97         Alfa Romeo   both
# 99         Alfa Romeo   both
# 110        Alfa Romeo   both
# 111        Alfa Romeo   both
# 118        Alfa Romeo   both
# 130        Alfa Romeo   both
# 133        Alfa Romeo   both
# 143        Alfa Romeo   both
# 144        Alfa Romeo   both
# 146        Alfa Romeo   both
# 154        Alfa Romeo   both

# %% [markdown]
# Now that I've done this, I can go in and drop the old constructor column and the newly added `_merge` column

# %%
results2 = results_slice.drop(columns=["constructor", "_merge"])

# %%
results2 = results2.rename(index=str, columns={"constructor_clean": "constructor"})

# %%
results2.head()
# Out:
#     raceId  year  raceRound           prix driverFirstName driverLastName  \
# 0        1  1950          1  Great Britain            Nino         Farina
# 1        1  1950          1  Great Britain           Luigi        Fagioli
# 2        1  1950          1  Great Britain             Reg        Parnell
# 12       1  1950          1  Great Britain     Juan Manuel         Fangio
# 23       2  1950          2         Monaco     Juan Manuel         Fangio
#
#    finishingPosition  positionOrder         time constructor
# 0                  1              1  2:13:23.600  Alfa Romeo
# 1                  2              2      +2.600s  Alfa Romeo
# 2                  3              3     +52.000s  Alfa Romeo
# 12                NC             13          DNF  Alfa Romeo
# 23                 1              1  3:13:18.700  Alfa Romeo

# %%
results2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2293 entries, 0 to 22379
# Data columns (total 10 columns):
# raceId               2293 non-null int64
# year                 2293 non-null int64
# raceRound            2293 non-null int64
# prix                 2293 non-null object
# driverFirstName      2293 non-null object
# driverLastName       2293 non-null object
# finishingPosition    2293 non-null object
# positionOrder        2293 non-null int64
# time                 2293 non-null object
# constructor          2293 non-null object
# dtypes: int64(4), object(6)
# memory usage: 197.1+ KB

# %% [markdown]
# Now we can head into the analysis.

# %% [markdown]
# ---
#
# ## Idea 01: Wins
#
# The first way we can look to find an answer to the question is to look at the wins each team had in their run.

# %%
wins = results2[results2.finishingPosition == "1"]

# %%
wins.head()
# Out:
#      raceId  year  raceRound           prix driverFirstName driverLastName  \
# 0         1  1950          1  Great Britain            Nino         Farina
# 23        2  1950          2         Monaco     Juan Manuel         Fangio
# 78        4  1950          4    Switzerland            Nino         Farina
# 96        5  1950          5        Belgium     Juan Manuel         Fangio
# 110       6  1950          6         France     Juan Manuel         Fangio
#
#     finishingPosition  positionOrder         time constructor
# 0                   1              1  2:13:23.600  Alfa Romeo
# 23                  1              1  3:13:18.700  Alfa Romeo
# 78                  1              1  2:02:53.700  Alfa Romeo
# 96                  1              1  2:47:26.000  Alfa Romeo
# 110                 1              1  2:57:52.800  Alfa Romeo

# %%
wins.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 528 entries, 0 to 22375
# Data columns (total 10 columns):
# raceId               528 non-null int64
# year                 528 non-null int64
# raceRound            528 non-null int64
# prix                 528 non-null object
# driverFirstName      528 non-null object
# driverLastName       528 non-null object
# finishingPosition    528 non-null object
# positionOrder        528 non-null int64
# time                 528 non-null object
# constructor          528 non-null object
# dtypes: int64(4), object(6)
# memory usage: 45.4+ KB

# %%
wins.head(22)
# Out:
#      raceId  year  raceRound           prix driverFirstName driverLastName  \
# 0         1  1950          1  Great Britain            Nino         Farina
# 23        2  1950          2         Monaco     Juan Manuel         Fangio
# 78        4  1950          4    Switzerland            Nino         Farina
# 96        5  1950          5        Belgium     Juan Manuel         Fangio
# 110       6  1950          6         France     Juan Manuel         Fangio
# 130       7  1950          7          Italy            Nino         Farina
# 158       8  1951          1    Switzerland     Juan Manuel         Fangio
# 213      10  1951          3        Belgium            Nino         Farina
# 226      11  1951          4         France     Juan Manuel         Fangio
# 227      11  1951          4         France           Luigi        Fagioli
# 315      15  1951          9          Spain     Juan Manuel         Fangio
# 334      16  1952          1    Switzerland           Piero        Taruffi
# 389      18  1952          3        Belgium         Alberto         Ascari
# 411      19  1952          4         France         Alberto         Ascari
# 433      20  1952          5  Great Britain         Alberto         Ascari
# 464      21  1952          6        Germany         Alberto         Ascari
# 494      22  1952          7    Netherlands         Alberto         Ascari
# 513      23  1952          8          Italy         Alberto         Ascari
# 537      24  1953          1      Argentina         Alberto         Ascari
# 601      26  1953          3    Netherlands         Alberto         Ascari
# 621      27  1953          4        Belgium         Alberto         Ascari
# 642      28  1953          5         France            Mike       Hawthorn
#
#     finishingPosition  positionOrder         time constructor
# 0                   1              1  2:13:23.600  Alfa Romeo
# 23                  1              1  3:13:18.700  Alfa Romeo
# 78                  1              1  2:02:53.700  Alfa Romeo
# 96                  1              1  2:47:26.000  Alfa Romeo
# 110                 1              1  2:57:52.800  Alfa Romeo
# 130                 1              1  2:51:17.400  Alfa Romeo
# 158                 1              1  2:07:53.640  Alfa Romeo
# 213                 1              1  2:45:46.200  Alfa Romeo
# 226                 1              1  3:22:11.000  Alfa Romeo
# 227                 1              2          SHC  Alfa Romeo
# 315                 1              1  2:46:54.100  Alfa Romeo
# 334                 1              1  3:01:46.100     Ferrari
# 389                 1              1  3:03:46.300     Ferrari
# 411                 1              1  3:00:00.000     Ferrari
# 433                 1              1  2:44:11.000     Ferrari
# 464                 1              1  3:06:13.300     Ferrari
# 494                 1              1  2:53:28.500     Ferrari
# 513                 1              1  2:50:45.600     Ferrari
# 537                 1              1  3:01:04.600     Ferrari
# 601                 1              1  2:53:35.800     Ferrari
# 621                 1              1  2:48:30.300     Ferrari
# 642                 1              1  2:44:18.600     Ferrari

# %% [markdown]
# One thing with the earlier F1 races that I've noted in my previous analysis attempts is that the there were a lot of shared drives. In this dataset, those rows are easier to find. In the column for time, they have a value of `SHC`. In doing my calculations, I'll ignore these rows.

# %%
wins_clean = wins[wins["time"] != "SHC"]

# %%
wins_clean.head(6)
# Out:
#      raceId  year  raceRound           prix driverFirstName driverLastName  \
# 0         1  1950          1  Great Britain            Nino         Farina
# 23        2  1950          2         Monaco     Juan Manuel         Fangio
# 78        4  1950          4    Switzerland            Nino         Farina
# 96        5  1950          5        Belgium     Juan Manuel         Fangio
# 110       6  1950          6         France     Juan Manuel         Fangio
# 130       7  1950          7          Italy            Nino         Farina
#
#     finishingPosition  positionOrder         time constructor
# 0                   1              1  2:13:23.600  Alfa Romeo
# 23                  1              1  3:13:18.700  Alfa Romeo
# 78                  1              1  2:02:53.700  Alfa Romeo
# 96                  1              1  2:47:26.000  Alfa Romeo
# 110                 1              1  2:57:52.800  Alfa Romeo
# 130                 1              1  2:51:17.400  Alfa Romeo

# %%
wins_grouped = wins_clean.copy().groupby(["year", "constructor"])

# %%
count_wins = wins_grouped.finishingPosition.count()

# %%
count_wins.head(20)
# Out:
# year  constructor
# 1950  Alfa Romeo     6
# 1951  Alfa Romeo     4
# 1952  Ferrari        7
# 1953  Ferrari        7
# 1954  Mercedes       4
# 1955  Mercedes       5
# 1956  Ferrari        5
# 1957  Maserati       4
# 1958  Ferrari        2
# 1959  Cooper         5
# 1960  Cooper         6
# 1961  Ferrari        5
# 1962  BRM            4
# 1963  Lotus          7
# 1964  Ferrari        3
# 1965  Lotus          6
# 1966  Brabham        4
# 1967  Brabham        4
# 1968  Lotus          5
# 1969  Matra          6
# Name: finishingPosition, dtype: int64

# %%
count_wins = count_wins.to_frame().reset_index()

# %%
count_wins.head(13)
# Out:
#     year constructor  finishingPosition
# 0   1950  Alfa Romeo                  6
# 1   1951  Alfa Romeo                  4
# 2   1952     Ferrari                  7
# 3   1953     Ferrari                  7
# 4   1954    Mercedes                  4
# 5   1955    Mercedes                  5
# 6   1956     Ferrari                  5
# 7   1957    Maserati                  4
# 8   1958     Ferrari                  2
# 9   1959      Cooper                  5
# 10  1960      Cooper                  6
# 11  1961     Ferrari                  5
# 12  1962         BRM                  4

# %%
count_wins.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 69 entries, 0 to 68
# Data columns (total 3 columns):
# year                 69 non-null int64
# constructor          69 non-null object
# finishingPosition    69 non-null int64
# dtypes: int64(2), object(1)
# memory usage: 1.7+ KB

# %% [markdown]
# The dataFrame, `count_wins`, has the number of wins a team got in their championship run. Let's rename the last column from `positionOrder` to `wins`

# %%
count_wins = count_wins.rename(index=str, columns={"finishingPosition": "wins"})

# %%
count_wins.sort_values(by="wins",ascending=False)
# Out:
#     year      constructor  wins
# 66  2016         Mercedes    19
# 65  2015         Mercedes    16
# 64  2014         Mercedes    16
# 38  1988          McLaren    15
# 54  2004          Ferrari    15
# 52  2002          Ferrari    15
# 63  2013  Red Bull Racing    13
# 34  1984          McLaren    12
# 67  2017         Mercedes    12
# 61  2011  Red Bull Racing    12
# 46  1996         Williams    12
# 45  1995         Benetton    11
# 68  2018         Mercedes    11
# 39  1989          McLaren    10
# 50  2000          Ferrari    10
# 42  1992         Williams    10
# 43  1993         Williams    10
# 60  2010  Red Bull Racing     9
# 57  2007          Ferrari     9
# 48  1998          McLaren     9
# 37  1987         Williams     9
# 51  2001          Ferrari     9
# 44  1994         Benetton     8
# 47  1997         Williams     8
# 28  1978            Lotus     8
# 41  1991          McLaren     8
# 55  2005          Renault     8
# 56  2006          Renault     8
# 59  2009            Brawn     8
# 53  2003          Ferrari     8
# ..   ...              ...   ...
# 19  1969            Matra     6
# 58  2008          McLaren     6
# 20  1970            Lotus     6
# 25  1975          Ferrari     6
# 26  1976          McLaren     6
# 29  1979          Ferrari     6
# 0   1950       Alfa Romeo     6
# 40  1990          McLaren     6
# 30  1980         Williams     6
# 23  1973          Tyrrell     5
# 5   1955         Mercedes     5
# 6   1956          Ferrari     5
# 18  1968            Lotus     5
# 22  1972            Lotus     5
# 11  1961          Ferrari     5
# 9   1959           Cooper     5
# 36  1986          McLaren     4
# 24  1974          McLaren     4
# 33  1983          Brabham     4
# 12  1962              BRM     4
# 7   1957         Maserati     4
# 17  1967          Brabham     4
# 27  1977          Ferrari     4
# 4   1954         Mercedes     4
# 16  1966          Brabham     4
# 1   1951       Alfa Romeo     4
# 14  1964          Ferrari     3
# 31  1981          Brabham     3
# 8   1958          Ferrari     2
# 32  1982         Williams     1
#
# [69 rows x 3 columns]

# %% [markdown]
# Let's save the list:

# %%
count_wins.to_csv("../data/output/win_count.csv",index=False)

# %% [markdown]
# Looking at this list, Mercedes' 2016 run would be the best F1 season. But we're not accounting for the fact that the number of races per season has varied. Let's try to take that into account by finding the number of races in a season and dividing the number of wins by the number of races in the season.

# %%
normalize_wins = count_wins.copy()

# %%
def races_in_season(row):
    y = int(row["year"])
    season = results2[results2.year == y]
    number = season.raceRound.max()
    return number

# %%
normalize_wins["races"] = normalize_wins.apply(races_in_season, axis=1)

# %%
normalize_wins.head()
# Out:
#    year constructor  wins  races
# 0  1950  Alfa Romeo     6      7
# 1  1951  Alfa Romeo     4      9
# 2  1952     Ferrari     7      8
# 3  1953     Ferrari     7      9
# 4  1954    Mercedes     4      9

# %% [markdown]
# Now we can find the percentage of races each team had in their season:

# %%
normalize_wins["win_percentage"] = (normalize_wins["wins"] / normalize_wins["races"])

# %%
normalize_wins.head()
# Out:
#    year constructor  wins  races  win_percentage
# 0  1950  Alfa Romeo     6      7        0.857143
# 1  1951  Alfa Romeo     4      9        0.444444
# 2  1952     Ferrari     7      8        0.875000
# 3  1953     Ferrari     7      9        0.777778
# 4  1954    Mercedes     4      9        0.444444

# %% [markdown]
# And now we can resort from highest to lowest. I could scale things by 100 here to get percentages, but I can also do that when I get to plotting.

# %%
normalize_wins.sort_values(by="win_percentage",ascending=False)
# Out:
#     year      constructor  wins  races  win_percentage
# 38  1988          McLaren    15     16        0.937500
# 66  2016         Mercedes    19     21        0.904762
# 52  2002          Ferrari    15     17        0.882353
# 2   1952          Ferrari     7      8        0.875000
# 0   1950       Alfa Romeo     6      7        0.857143
# 65  2015         Mercedes    16     19        0.842105
# 64  2014         Mercedes    16     19        0.842105
# 54  2004          Ferrari    15     18        0.833333
# 3   1953          Ferrari     7      9        0.777778
# 46  1996         Williams    12     16        0.750000
# 34  1984          McLaren    12     16        0.750000
# 11  1961          Ferrari     5      7        0.714286
# 5   1955         Mercedes     5      7        0.714286
# 13  1963            Lotus     7     10        0.700000
# 63  2013  Red Bull Racing    13     19        0.684211
# 45  1995         Benetton    11     17        0.647059
# 21  1971          Tyrrell     7     11        0.636364
# 61  2011  Red Bull Racing    12     19        0.631579
# 43  1993         Williams    10     16        0.625000
# 42  1992         Williams    10     16        0.625000
# 39  1989          McLaren    10     16        0.625000
# 15  1965            Lotus     6     10        0.600000
# 67  2017         Mercedes    12     20        0.600000
# 10  1960           Cooper     6     10        0.600000
# 50  2000          Ferrari    10     17        0.588235
# 37  1987         Williams     9     16        0.562500
# 48  1998          McLaren     9     16        0.562500
# 6   1956          Ferrari     5      9        0.555556
# 9   1959           Cooper     5      9        0.555556
# 19  1969            Matra     6     11        0.545455
# ..   ...              ...   ...    ...             ...
# 59  2009            Brawn     8     17        0.470588
# 20  1970            Lotus     6     13        0.461538
# 7   1957         Maserati     4      9        0.444444
# 1   1951       Alfa Romeo     4      9        0.444444
# 12  1962              BRM     4      9        0.444444
# 16  1966          Brabham     4      9        0.444444
# 4   1954         Mercedes     4      9        0.444444
# 56  2006          Renault     8     18        0.444444
# 49  1999          McLaren     7     16        0.437500
# 30  1980         Williams     6     14        0.428571
# 25  1975          Ferrari     6     14        0.428571
# 55  2005          Renault     8     19        0.421053
# 18  1968            Lotus     5     12        0.416667
# 22  1972            Lotus     5     12        0.416667
# 29  1979          Ferrari     6     15        0.400000
# 26  1976          McLaren     6     16        0.375000
# 35  1985          McLaren     6     16        0.375000
# 40  1990          McLaren     6     16        0.375000
# 17  1967          Brabham     4     11        0.363636
# 23  1973          Tyrrell     5     14        0.357143
# 62  2012  Red Bull Racing     7     20        0.350000
# 58  2008          McLaren     6     18        0.333333
# 14  1964          Ferrari     3     10        0.300000
# 24  1974          McLaren     4     15        0.266667
# 33  1983          Brabham     4     15        0.266667
# 36  1986          McLaren     4     16        0.250000
# 27  1977          Ferrari     4     17        0.235294
# 31  1981          Brabham     3     15        0.200000
# 8   1958          Ferrari     2     11        0.181818
# 32  1982         Williams     1     16        0.062500
#
# [69 rows x 5 columns]

# %% [markdown]
# From this we can see that McLaren's 1988 run was actually better than Mercedes' 2016 run — McLaren only lost 1 race. Let's save this dataFrame for later.

# %%
normalize_wins.to_csv("../data/output/win_count_normalized.csv", index=False)

# %% [markdown]
# Now that we have this figured out, we can move to doing things with the podiums.

# %% [markdown]
# ---
#
# ## Idea 02: Podiums
#
# Looking at the wins is a good start, but there are a lot of factors about the team's performance over a season that it leaves out.
#
# * It only shows a very narrow slice of the team's drivers's performance. If we only know that one of the drivers won, we have no idea how the other driver did.
# * It offers a limited amount of comparison. Winning is a binary variable — you win or you don't. When looking at the history of the sport, things are greyer. For example, Keke Rosberg won the driver's cup in 1982, but he only had one victory that season. Looking only at the number of wins doesn't provide any information about how this happened.
#
# We can dig a little deeper and look at podiums. The podium refers to the drivers who finished first, second, and third in any given race. A team that consistenly has both drivers on the podium over a season is doing amazing. (ex: Mercedes in 2019 is dominating right now with Bottas and Hamilton in the podium for every race)

# %%
podiums = results2[results2.finishingPosition.isin(["1", "2", "3"])]

# %%
podiums.head(23)
# Out:
#      raceId  year  raceRound           prix driverFirstName driverLastName  \
# 0         1  1950          1  Great Britain            Nino         Farina
# 1         1  1950          1  Great Britain           Luigi        Fagioli
# 2         1  1950          1  Great Britain             Reg        Parnell
# 23        2  1950          2         Monaco     Juan Manuel         Fangio
# 78        4  1950          4    Switzerland            Nino         Farina
# 79        4  1950          4    Switzerland           Luigi        Fagioli
# 96        5  1950          5        Belgium     Juan Manuel         Fangio
# 97        5  1950          5        Belgium           Luigi        Fagioli
# 110       6  1950          6         France     Juan Manuel         Fangio
# 111       6  1950          6         France           Luigi        Fagioli
# 130       7  1950          7          Italy            Nino         Farina
# 133       7  1950          7          Italy           Luigi        Fagioli
# 158       8  1951          1    Switzerland     Juan Manuel         Fangio
# 160       8  1951          1    Switzerland            Nino         Farina
# 213      10  1951          3        Belgium            Nino         Farina
# 226      11  1951          4         France     Juan Manuel         Fangio
# 227      11  1951          4         France           Luigi        Fagioli
# 253      12  1951          6  Great Britain     Juan Manuel         Fangio
# 273      13  1951          7        Germany     Juan Manuel         Fangio
# 296      14  1951          8          Italy          Felice        Bonetto
# 297      14  1951          8          Italy            Nino         Farina
# 315      15  1951          9          Spain     Juan Manuel         Fangio
# 317      15  1951          9          Spain            Nino         Farina
#
#     finishingPosition  positionOrder         time constructor
# 0                   1              1  2:13:23.600  Alfa Romeo
# 1                   2              2      +2.600s  Alfa Romeo
# 2                   3              3     +52.000s  Alfa Romeo
# 23                  1              1  3:13:18.700  Alfa Romeo
# 78                  1              1  2:02:53.700  Alfa Romeo
# 79                  2              2      +0.400s  Alfa Romeo
# 96                  1              1  2:47:26.000  Alfa Romeo
# 97                  2              2     +14.000s  Alfa Romeo
# 110                 1              1  2:57:52.800  Alfa Romeo
# 111                 2              2     +25.700s  Alfa Romeo
# 130                 1              1  2:51:17.400  Alfa Romeo
# 133                 3              4     +95.600s  Alfa Romeo
# 158                 1              1  2:07:53.640  Alfa Romeo
# 160                 3              3     +79.310s  Alfa Romeo
# 213                 1              1  2:45:46.200  Alfa Romeo
# 226                 1              1  3:22:11.000  Alfa Romeo
# 227                 1              2          SHC  Alfa Romeo
# 253                 2              2     +51.000s  Alfa Romeo
# 273                 2              2     +30.500s  Alfa Romeo
# 296                 3              3          SHC  Alfa Romeo
# 297                 3              4       +1 lap  Alfa Romeo
# 315                 1              1  2:46:54.100  Alfa Romeo
# 317                 3              3    +105.540s  Alfa Romeo

# %% [markdown]
# As I mentioned earlier, shared drives were a common thing in the early years of Formula1 and they're findable in the data by looking for any rows for where the `time` is `SHC`.
#
# When looking at the podiums, I'll be doing the same.

# %%
podiums_clean = podiums[podiums.time != "SHC"]

# %%
podiums_clean.head(21)
# Out:
#      raceId  year  raceRound           prix driverFirstName driverLastName  \
# 0         1  1950          1  Great Britain            Nino         Farina
# 1         1  1950          1  Great Britain           Luigi        Fagioli
# 2         1  1950          1  Great Britain             Reg        Parnell
# 23        2  1950          2         Monaco     Juan Manuel         Fangio
# 78        4  1950          4    Switzerland            Nino         Farina
# 79        4  1950          4    Switzerland           Luigi        Fagioli
# 96        5  1950          5        Belgium     Juan Manuel         Fangio
# 97        5  1950          5        Belgium           Luigi        Fagioli
# 110       6  1950          6         France     Juan Manuel         Fangio
# 111       6  1950          6         France           Luigi        Fagioli
# 130       7  1950          7          Italy            Nino         Farina
# 133       7  1950          7          Italy           Luigi        Fagioli
# 158       8  1951          1    Switzerland     Juan Manuel         Fangio
# 160       8  1951          1    Switzerland            Nino         Farina
# 213      10  1951          3        Belgium            Nino         Farina
# 226      11  1951          4         France     Juan Manuel         Fangio
# 253      12  1951          6  Great Britain     Juan Manuel         Fangio
# 273      13  1951          7        Germany     Juan Manuel         Fangio
# 297      14  1951          8          Italy            Nino         Farina
# 315      15  1951          9          Spain     Juan Manuel         Fangio
# 317      15  1951          9          Spain            Nino         Farina
#
#     finishingPosition  positionOrder         time constructor
# 0                   1              1  2:13:23.600  Alfa Romeo
# 1                   2              2      +2.600s  Alfa Romeo
# 2                   3              3     +52.000s  Alfa Romeo
# 23                  1              1  3:13:18.700  Alfa Romeo
# 78                  1              1  2:02:53.700  Alfa Romeo
# 79                  2              2      +0.400s  Alfa Romeo
# 96                  1              1  2:47:26.000  Alfa Romeo
# 97                  2              2     +14.000s  Alfa Romeo
# 110                 1              1  2:57:52.800  Alfa Romeo
# 111                 2              2     +25.700s  Alfa Romeo
# 130                 1              1  2:51:17.400  Alfa Romeo
# 133                 3              4     +95.600s  Alfa Romeo
# 158                 1              1  2:07:53.640  Alfa Romeo
# 160                 3              3     +79.310s  Alfa Romeo
# 213                 1              1  2:45:46.200  Alfa Romeo
# 226                 1              1  3:22:11.000  Alfa Romeo
# 253                 2              2     +51.000s  Alfa Romeo
# 273                 2              2     +30.500s  Alfa Romeo
# 297                 3              4       +1 lap  Alfa Romeo
# 315                 1              1  2:46:54.100  Alfa Romeo
# 317                 3              3    +105.540s  Alfa Romeo

# %% [markdown]
# Now let's count them.

# %%
count_podiums = podiums_clean.groupby(["year", "constructor"]).finishingPosition.count()

# %%
count_podiums.head()
# Out:
# year  constructor
# 1950  Alfa Romeo     12
# 1951  Alfa Romeo      9
# 1952  Ferrari        17
# 1953  Ferrari        16
# 1954  Mercedes        7
# Name: finishingPosition, dtype: int64

# %%
count_podiums = count_podiums.to_frame().reset_index()

# %%
count_podiums.head()
# Out:
#    year constructor  finishingPosition
# 0  1950  Alfa Romeo                 12
# 1  1951  Alfa Romeo                  9
# 2  1952     Ferrari                 17
# 3  1953     Ferrari                 16
# 4  1954    Mercedes                  7

# %%
count_podiums.sort_values(by="finishingPosition",ascending=False).head(20)
# Out:
#     year      constructor  finishingPosition
# 66  2016         Mercedes                 33
# 65  2015         Mercedes                 32
# 64  2014         Mercedes                 31
# 54  2004          Ferrari                 29
# 52  2002          Ferrari                 27
# 61  2011  Red Bull Racing                 27
# 67  2017         Mercedes                 26
# 38  1988          McLaren                 25
# 68  2018         Mercedes                 25
# 51  2001          Ferrari                 24
# 63  2013  Red Bull Racing                 24
# 57  2007          Ferrari                 22
# 43  1993         Williams                 22
# 50  2000          Ferrari                 21
# 46  1996         Williams                 21
# 42  1992         Williams                 21
# 60  2010  Red Bull Racing                 20
# 48  1998          McLaren                 20
# 56  2006          Renault                 19
# 55  2005          Renault                 18

# %% [markdown]
# We can save this version of raw podium counts and get to normalizing the podiums over the season to better compare the different runs. But before that let's rename the column we used to count things.

# %%
count_podiums = count_podiums.rename(index=str, columns={"finishingPosition": "podiums"})

# %%
count_podiums.to_csv("../data/output/podium_count.csv")

# %% [markdown]
# To normalize the podiums, we'll need to get the number of possible podiums in a season. That's the number of races times 3. When counting the number of wins we figured out how to do the races already.

# %%
normalize_podiums = count_podiums.copy()

# %%
normalize_podiums["races"] = normalize_podiums.apply(races_in_season, axis=1)

# %%
normalize_podiums.head()
# Out:
#    year constructor  podiums  races
# 0  1950  Alfa Romeo       12      7
# 1  1951  Alfa Romeo        9      9
# 2  1952     Ferrari       17      8
# 3  1953     Ferrari       16      9
# 4  1954    Mercedes        7      9

# %% [markdown]
# While there are three podium spots every race, for the majority of Formula 1 seasons, teams have only had two drivers, so the maximum number of podium spots a team can have in a season is `2 * (number of races)`

# %%
def podiums_in_season(row):
    return row.races * 2

# %%
normalize_podiums["podium_spots"] = normalize_podiums.apply(podiums_in_season, axis=1)

# %%
normalize_podiums.head()
# Out:
#    year constructor  podiums  races  podium_spots
# 0  1950  Alfa Romeo       12      7            14
# 1  1951  Alfa Romeo        9      9            18
# 2  1952     Ferrari       17      8            16
# 3  1953     Ferrari       16      9            18
# 4  1954    Mercedes        7      9            18

# %% [markdown]
# And now we have everything to compute a podium percentage.

# %%
normalize_podiums["podium_percentage"] = normalize_podiums.podiums / normalize_podiums.podium_spots

# %%
normalize_podiums.head(20)
# Out:
#     year constructor  podiums  races  podium_spots  podium_percentage
# 0   1950  Alfa Romeo       12      7            14           0.857143
# 1   1951  Alfa Romeo        9      9            18           0.500000
# 2   1952     Ferrari       17      8            16           1.062500
# 3   1953     Ferrari       16      9            18           0.888889
# 4   1954    Mercedes        7      9            18           0.388889
# 5   1955    Mercedes       10      7            14           0.714286
# 6   1956     Ferrari       10      9            18           0.555556
# 7   1957    Maserati       10      9            18           0.555556
# 8   1958     Ferrari       14     11            22           0.636364
# 9   1959      Cooper       13      9            18           0.722222
# 10  1960      Cooper       14     10            20           0.700000
# 11  1961     Ferrari       14      7            14           1.000000
# 12  1962         BRM        8      9            18           0.444444
# 13  1963       Lotus        9     10            20           0.450000
# 14  1964     Ferrari       10     10            20           0.500000
# 15  1965       Lotus        7     10            20           0.350000
# 16  1966     Brabham        9      9            18           0.500000
# 17  1967     Brabham       14     11            22           0.636364
# 18  1968       Lotus        9     12            24           0.375000
# 19  1969       Matra       10     11            22           0.454545

# %%
normalize_podiums.sort_values(by="podium_percentage",ascending=False).head(20)
# Out:
#     year      constructor  podiums  races  podium_spots  podium_percentage
# 2   1952          Ferrari       17      8            16           1.062500
# 11  1961          Ferrari       14      7            14           1.000000
# 3   1953          Ferrari       16      9            18           0.888889
# 0   1950       Alfa Romeo       12      7            14           0.857143
# 65  2015         Mercedes       32     19            38           0.842105
# 64  2014         Mercedes       31     19            38           0.815789
# 54  2004          Ferrari       29     18            36           0.805556
# 52  2002          Ferrari       27     17            34           0.794118
# 66  2016         Mercedes       33     21            42           0.785714
# 38  1988          McLaren       25     16            32           0.781250
# 9   1959           Cooper       13      9            18           0.722222
# 5   1955         Mercedes       10      7            14           0.714286
# 61  2011  Red Bull Racing       27     19            38           0.710526
# 51  2001          Ferrari       24     17            34           0.705882
# 10  1960           Cooper       14     10            20           0.700000
# 43  1993         Williams       22     16            32           0.687500
# 46  1996         Williams       21     16            32           0.656250
# 42  1992         Williams       21     16            32           0.656250
# 67  2017         Mercedes       26     20            40           0.650000
# 57  2007          Ferrari       22     17            34           0.647059

# %% [markdown]
# The top four teams all had more than two drivers in their runs. What if we look at increasing the podium spots to match the fact that a team could have 3 drivers.

# %%
def podiums_in_season2(row):
    return row.races * 3

# %%
normalize_podiums["podium_spots2"] = normalize_podiums.apply(podiums_in_season2, axis=1)

# %%
normalize_podiums["podium_percentage2"] = normalize_podiums.podiums / normalize_podiums.podium_spots2

# %%
normalize_podiums.sort_values(by="podium_percentage2",ascending=False).head(20)
# Out:
#     year      constructor  podiums  races  podium_spots  podium_percentage  \
# 2   1952          Ferrari       17      8            16           1.062500
# 11  1961          Ferrari       14      7            14           1.000000
# 3   1953          Ferrari       16      9            18           0.888889
# 0   1950       Alfa Romeo       12      7            14           0.857143
# 65  2015         Mercedes       32     19            38           0.842105
# 64  2014         Mercedes       31     19            38           0.815789
# 54  2004          Ferrari       29     18            36           0.805556
# 52  2002          Ferrari       27     17            34           0.794118
# 66  2016         Mercedes       33     21            42           0.785714
# 38  1988          McLaren       25     16            32           0.781250
# 9   1959           Cooper       13      9            18           0.722222
# 5   1955         Mercedes       10      7            14           0.714286
# 61  2011  Red Bull Racing       27     19            38           0.710526
# 51  2001          Ferrari       24     17            34           0.705882
# 10  1960           Cooper       14     10            20           0.700000
# 43  1993         Williams       22     16            32           0.687500
# 46  1996         Williams       21     16            32           0.656250
# 42  1992         Williams       21     16            32           0.656250
# 67  2017         Mercedes       26     20            40           0.650000
# 57  2007          Ferrari       22     17            34           0.647059
#
#     podium_spots2  podium_percentage2
# 2              24            0.708333
# 11             21            0.666667
# 3              27            0.592593
# 0              21            0.571429
# 65             57            0.561404
# 64             57            0.543860
# 54             54            0.537037
# 52             51            0.529412
# 66             63            0.523810
# 38             48            0.520833
# 9              27            0.481481
# 5              21            0.476190
# 61             57            0.473684
# 51             51            0.470588
# 10             30            0.466667
# 43             48            0.458333
# 46             48            0.437500
# 42             48            0.437500
# 67             60            0.433333
# 57             51            0.431373

# %% [markdown]
# I guess it doesn't change things. But maybe I should account for the number of drivers in each season when I account for podiums. There are `3 * number of races` podium spots over a given season, But for most of the seasons, only two drivers so at most a team can only get `2 * number of races`. **Maybe we can divide the `podium_percentage` by the number of drivers a team had? That would create a podiums per season per driver and could help with comparisons?** I will come back to this later.
