# %% [markdown]
# # Looking for the best Formula 1 season
#
# For my master's project, I'm making a piece about answering the question: **What championship winning team had the best Formula 1 season?**
#
# To do this I was working with data provided by the [Ergast Developer API](https://ergast.com/mrd/). I noticed an error in the driver-constructor pairing for the 1950 season and wanted to verify things without moving forward. I was originally going to create a table of the driver-constructor pairs for each race, and then compare it with the data I had.
#
# Instead I went straight to the source for F1 information, [formula1.com](https://formula1.com), and scraped race information for each race from 1950 to 2018.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# The first thing to do is to import the data

# %%
race_results = pd.read_csv("../data/from_scripts/race_results.csv")

# %%
race_results.head()
# Out:
#    race_id  year  round_id    race_date      race_name                 driver  \
# 0        1  1950         1  13 May 1950  Great Britain            Nino Farina
# 1        1  1950         1  13 May 1950  Great Britain          Luigi Fagioli
# 2        1  1950         1  13 May 1950  Great Britain            Reg Parnell
# 3        1  1950         1  13 May 1950  Great Britain  Yves Giraud Cabantous
# 4        1  1950         1  13 May 1950  Great Britain           Louis Rosier
#
#   code  constructor position  position_order  laps         time  points
# 0  FAR   Alfa Romeo        1               1  70.0  2:13:23.600     9.0
# 1  FAG   Alfa Romeo        2               2  70.0      +2.600s     6.0
# 2  PAR   Alfa Romeo        3               3  70.0     +52.000s     4.0
# 3  CAB  Talbot-Lago        4               4  68.0      +2 laps     3.0
# 4  ROS  Talbot-Lago        5               5  68.0      +2 laps     2.0

# %%
race_results.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22395 entries, 0 to 22394
# Data columns (total 13 columns):
# race_id           22395 non-null int64
# year              22395 non-null int64
# round_id          22395 non-null int64
# race_date         22395 non-null object
# race_name         22395 non-null object
# driver            22395 non-null object
# code              22395 non-null object
# constructor       22369 non-null object
# position          22395 non-null object
# position_order    22395 non-null int64
# laps              22171 non-null float64
# time              22387 non-null object
# points            22395 non-null float64
# dtypes: float64(2), int64(4), object(7)
# memory usage: 2.2+ MB

# %% [markdown]
# Let's also check how many races we have:

# %%
race_results.race_id.max()
# Out:
# 997

# %% [markdown]
# Things seem to be in good order.
#
# Using the `race_results.csv` I also made a clean list of constructor names that I want to add to the `race_results` dataFrame.

# %%
constructors_all = pd.read_csv("../data/other/constructors_clean.csv")

# %%
constructors_all.head()
# Out:
#    year        constructor constructor_clean  constructor_alt
# 0  1950  Adams Offenhauser             Adams              NaN
# 1  1950         Alfa Romeo        Alfa Romeo              NaN
# 2  1950               Alta              Alta              NaN
# 3  1950         Cooper JAP            Cooper              NaN
# 4  1950  Deidt Offenhauser             Deidt              NaN

# %%
race_results = race_results.merge(constructors_all, on=["year", "constructor"])

# %%
race_results.sort_values(["race_id", "position_order"]).head(10)
# Out:
#     race_id  year  round_id    race_date      race_name  \
# 0         1  1950         1  13 May 1950  Great Britain
# 1         1  1950         1  13 May 1950  Great Britain
# 2         1  1950         1  13 May 1950  Great Britain
# 22        1  1950         1  13 May 1950  Great Britain
# 23        1  1950         1  13 May 1950  Great Britain
# 59        1  1950         1  13 May 1950  Great Britain
# 60        1  1950         1  13 May 1950  Great Britain
# 24        1  1950         1  13 May 1950  Great Britain
# 67        1  1950         1  13 May 1950  Great Britain
# 68        1  1950         1  13 May 1950  Great Britain
#
#                    driver code  constructor position  position_order  laps  \
# 0             Nino Farina  FAR   Alfa Romeo        1               1  70.0
# 1           Luigi Fagioli  FAG   Alfa Romeo        2               2  70.0
# 2             Reg Parnell  PAR   Alfa Romeo        3               3  70.0
# 22  Yves Giraud Cabantous  CAB  Talbot-Lago        4               4  68.0
# 23           Louis Rosier  ROS  Talbot-Lago        5               5  68.0
# 59             Bob Gerard  GER          ERA        6               6  67.0
# 60          Cuth Harrison  HAR          ERA        7               7  67.0
# 24     Philippe Etancelin  ETA  Talbot-Lago        8               8  65.0
# 67        David Hampshire  HAM     Maserati        9               9  64.0
# 68                Joe Fry  FRY     Maserati       10              10   NaN
#
#            time  points constructor_clean  constructor_alt
# 0   2:13:23.600     9.0        Alfa Romeo              NaN
# 1       +2.600s     6.0        Alfa Romeo              NaN
# 2      +52.000s     4.0        Alfa Romeo              NaN
# 22      +2 laps     3.0       Talbot-Lago              NaN
# 23      +2 laps     2.0       Talbot-Lago              NaN
# 59      +3 laps     0.0               ERA              NaN
# 60      +3 laps     0.0               ERA              NaN
# 24      +5 laps     0.0       Talbot-Lago              NaN
# 67      +6 laps     0.0          Maserati              NaN
# 68          SHC     0.0          Maserati              NaN

# %% [markdown]
# For the majority of the analysis, I'll only be looking at the championship runs, a subset of all these results. Let's cut a slice of the results that is only of the winning runs each year:

# %%
winning_teams = pd.read_csv("../data/from_scripts/winning_teams.csv")

# %%
winning_teams.head()
# Out:
#    year    constructor
# 0  1950     Alfa Romeo
# 1  1951     Alfa Romeo
# 2  1952        Ferrari
# 3  1953        Ferrari
# 4  1954  Mercedes-Benz

# %% [markdown]
# Let's connect the `race_results` and `winning_teams`

# %%
combine = pd.merge(race_results, winning_teams, how="left", on=["year", "constructor"], indicator="winners")

# %%
combine.head()
# Out:
#    race_id  year  round_id    race_date      race_name              driver  \
# 0        1  1950         1  13 May 1950  Great Britain         Nino Farina
# 1        1  1950         1  13 May 1950  Great Britain       Luigi Fagioli
# 2        1  1950         1  13 May 1950  Great Britain         Reg Parnell
# 3        1  1950         1  13 May 1950  Great Britain  Juan Manuel Fangio
# 4        2  1950         2  21 May 1950         Monaco  Juan Manuel Fangio
#
#   code constructor position  position_order   laps         time  points  \
# 0  FAR  Alfa Romeo        1               1   70.0  2:13:23.600     9.0
# 1  FAG  Alfa Romeo        2               2   70.0      +2.600s     6.0
# 2  PAR  Alfa Romeo        3               3   70.0     +52.000s     4.0
# 3  FAN  Alfa Romeo       NC              13   62.0          DNF     0.0
# 4  FAN  Alfa Romeo        1               1  100.0  3:13:18.700     9.0
#
#   constructor_clean  constructor_alt winners
# 0        Alfa Romeo              NaN    both
# 1        Alfa Romeo              NaN    both
# 2        Alfa Romeo              NaN    both
# 3        Alfa Romeo              NaN    both
# 4        Alfa Romeo              NaN    both

# %%
results = combine[combine.winners == "both"]
results.head(20)
# Out:
#     race_id  year  round_id    race_date      race_name              driver  \
# 0         1  1950         1  13 May 1950  Great Britain         Nino Farina
# 1         1  1950         1  13 May 1950  Great Britain       Luigi Fagioli
# 2         1  1950         1  13 May 1950  Great Britain         Reg Parnell
# 3         1  1950         1  13 May 1950  Great Britain  Juan Manuel Fangio
# 4         2  1950         2  21 May 1950         Monaco  Juan Manuel Fangio
# 5         2  1950         2  21 May 1950         Monaco       Luigi Fagioli
# 6         2  1950         2  21 May 1950         Monaco         Nino Farina
# 7         4  1950         4  04 Jun 1950    Switzerland         Nino Farina
# 8         4  1950         4  04 Jun 1950    Switzerland       Luigi Fagioli
# 9         4  1950         4  04 Jun 1950    Switzerland  Juan Manuel Fangio
# 10        5  1950         5  18 Jun 1950        Belgium  Juan Manuel Fangio
# 11        5  1950         5  18 Jun 1950        Belgium       Luigi Fagioli
# 12        5  1950         5  18 Jun 1950        Belgium         Nino Farina
# 13        6  1950         6  02 Jul 1950         France  Juan Manuel Fangio
# 14        6  1950         6  02 Jul 1950         France       Luigi Fagioli
# 15        6  1950         6  02 Jul 1950         France         Nino Farina
# 16        7  1950         7  03 Sep 1950          Italy         Nino Farina
# 17        7  1950         7  03 Sep 1950          Italy       Luigi Fagioli
# 18        7  1950         7  03 Sep 1950          Italy       Piero Taruffi
# 19        7  1950         7  03 Sep 1950          Italy  Juan Manuel Fangio
#
#    code constructor position  position_order   laps         time  points  \
# 0   FAR  Alfa Romeo        1               1   70.0  2:13:23.600     9.0
# 1   FAG  Alfa Romeo        2               2   70.0      +2.600s     6.0
# 2   PAR  Alfa Romeo        3               3   70.0     +52.000s     4.0
# 3   FAN  Alfa Romeo       NC              13   62.0          DNF     0.0
# 4   FAN  Alfa Romeo        1               1  100.0  3:13:18.700     9.0
# 5   FAG  Alfa Romeo       NC              11    0.0          DNF     0.0
# 6   FAR  Alfa Romeo       NC              12    0.0          DNF     0.0
# 7   FAR  Alfa Romeo        1               1   42.0  2:02:53.700     9.0
# 8   FAG  Alfa Romeo        2               2   42.0      +0.400s     6.0
# 9   FAN  Alfa Romeo       NC              12   33.0          DNF     0.0
# 10  FAN  Alfa Romeo        1               1   35.0  2:47:26.000     8.0
# 11  FAG  Alfa Romeo        2               2   35.0     +14.000s     6.0
# 12  FAR  Alfa Romeo        4               4   35.0    +245.000s     4.0
# 13  FAN  Alfa Romeo        1               1   64.0  2:57:52.800     9.0
# 14  FAG  Alfa Romeo        2               2   64.0     +25.700s     6.0
# 15  FAR  Alfa Romeo        7               9   55.0          DNF     0.0
# 16  FAR  Alfa Romeo        1               1   80.0  2:51:17.400     8.0
# 17  FAG  Alfa Romeo        3               4   80.0     +95.600s     4.0
# 18  TAR  Alfa Romeo       NC              14    NaN          SHC     0.0
# 19  FAN  Alfa Romeo       NC              15   34.0          DNF     1.0
#
#    constructor_clean  constructor_alt winners
# 0         Alfa Romeo              NaN    both
# 1         Alfa Romeo              NaN    both
# 2         Alfa Romeo              NaN    both
# 3         Alfa Romeo              NaN    both
# 4         Alfa Romeo              NaN    both
# 5         Alfa Romeo              NaN    both
# 6         Alfa Romeo              NaN    both
# 7         Alfa Romeo              NaN    both
# 8         Alfa Romeo              NaN    both
# 9         Alfa Romeo              NaN    both
# 10        Alfa Romeo              NaN    both
# 11        Alfa Romeo              NaN    both
# 12        Alfa Romeo              NaN    both
# 13        Alfa Romeo              NaN    both
# 14        Alfa Romeo              NaN    both
# 15        Alfa Romeo              NaN    both
# 16        Alfa Romeo              NaN    both
# 17        Alfa Romeo              NaN    both
# 18        Alfa Romeo              NaN    both
# 19        Alfa Romeo              NaN    both

# %% [markdown]
# Looking at this, I can go ahead and drop some columns that aren't immediately useful:
#
# * `race_date`
# * `points`
# * `winners`
# * `constructor_alt`

# %%
results = results.drop(columns=["race_date", "points", "winners", "constructor_alt"])

# %%
results.head()
# Out:
#    race_id  year  round_id      race_name              driver code  \
# 0        1  1950         1  Great Britain         Nino Farina  FAR
# 1        1  1950         1  Great Britain       Luigi Fagioli  FAG
# 2        1  1950         1  Great Britain         Reg Parnell  PAR
# 3        1  1950         1  Great Britain  Juan Manuel Fangio  FAN
# 4        2  1950         2         Monaco  Juan Manuel Fangio  FAN
#
#   constructor position  position_order   laps         time constructor_clean
# 0  Alfa Romeo        1               1   70.0  2:13:23.600        Alfa Romeo
# 1  Alfa Romeo        2               2   70.0      +2.600s        Alfa Romeo
# 2  Alfa Romeo        3               3   70.0     +52.000s        Alfa Romeo
# 3  Alfa Romeo       NC              13   62.0          DNF        Alfa Romeo
# 4  Alfa Romeo        1               1  100.0  3:13:18.700        Alfa Romeo

# %%
results.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2293 entries, 0 to 22058
# Data columns (total 12 columns):
# race_id              2293 non-null int64
# year                 2293 non-null int64
# round_id             2293 non-null int64
# race_name            2293 non-null object
# driver               2293 non-null object
# code                 2293 non-null object
# constructor          2293 non-null object
# position             2293 non-null object
# position_order       2293 non-null int64
# laps                 2267 non-null float64
# time                 2293 non-null object
# constructor_clean    2293 non-null object
# dtypes: float64(1), int64(4), object(7)
# memory usage: 232.9+ KB

# %% [markdown]
# Now we can head into the analysis.

# %% [markdown]
# ---
#
# ## Method 01: Wins
#
# The first way we can look to find an answer to the question is to look at the wins each team had in their run.

# %%
wins = results[results.position == "1"]

# %%
wins.head()
# Out:
#     race_id  year  round_id      race_name              driver code  \
# 0         1  1950         1  Great Britain         Nino Farina  FAR
# 4         2  1950         2         Monaco  Juan Manuel Fangio  FAN
# 7         4  1950         4    Switzerland         Nino Farina  FAR
# 10        5  1950         5        Belgium  Juan Manuel Fangio  FAN
# 13        6  1950         6         France  Juan Manuel Fangio  FAN
#
#    constructor position  position_order   laps         time constructor_clean
# 0   Alfa Romeo        1               1   70.0  2:13:23.600        Alfa Romeo
# 4   Alfa Romeo        1               1  100.0  3:13:18.700        Alfa Romeo
# 7   Alfa Romeo        1               1   42.0  2:02:53.700        Alfa Romeo
# 10  Alfa Romeo        1               1   35.0  2:47:26.000        Alfa Romeo
# 13  Alfa Romeo        1               1   64.0  2:57:52.800        Alfa Romeo

# %%
wins.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 528 entries, 0 to 22057
# Data columns (total 12 columns):
# race_id              528 non-null int64
# year                 528 non-null int64
# round_id             528 non-null int64
# race_name            528 non-null object
# driver               528 non-null object
# code                 528 non-null object
# constructor          528 non-null object
# position             528 non-null object
# position_order       528 non-null int64
# laps                 526 non-null float64
# time                 528 non-null object
# constructor_clean    528 non-null object
# dtypes: float64(1), int64(4), object(7)
# memory usage: 53.6+ KB

# %%
wins.head(15)
# Out:
#      race_id  year  round_id      race_name              driver code  \
# 0          1  1950         1  Great Britain         Nino Farina  FAR
# 4          2  1950         2         Monaco  Juan Manuel Fangio  FAN
# 7          4  1950         4    Switzerland         Nino Farina  FAR
# 10         5  1950         5        Belgium  Juan Manuel Fangio  FAN
# 13         6  1950         6         France  Juan Manuel Fangio  FAN
# 16         7  1950         7          Italy         Nino Farina  FAR
# 158        8  1951         1    Switzerland  Juan Manuel Fangio  FAN
# 162       10  1951         3        Belgium         Nino Farina  FAR
# 165       11  1951         4         France  Juan Manuel Fangio  FAN
# 166       11  1951         4         France       Luigi Fagioli  FAG
# 184       15  1951         9          Spain  Juan Manuel Fangio  FAN
# 334       16  1952         1    Switzerland       Piero Taruffi  TAR
# 342       18  1952         3        Belgium      Alberto Ascari  ASC
# 347       19  1952         4         France      Alberto Ascari  ASC
# 355       20  1952         5  Great Britain      Alberto Ascari  ASC
#
#     constructor position  position_order   laps         time constructor_clean
# 0    Alfa Romeo        1               1   70.0  2:13:23.600        Alfa Romeo
# 4    Alfa Romeo        1               1  100.0  3:13:18.700        Alfa Romeo
# 7    Alfa Romeo        1               1   42.0  2:02:53.700        Alfa Romeo
# 10   Alfa Romeo        1               1   35.0  2:47:26.000        Alfa Romeo
# 13   Alfa Romeo        1               1   64.0  2:57:52.800        Alfa Romeo
# 16   Alfa Romeo        1               1   80.0  2:51:17.400        Alfa Romeo
# 158  Alfa Romeo        1               1   42.0  2:07:53.640        Alfa Romeo
# 162  Alfa Romeo        1               1   36.0  2:45:46.200        Alfa Romeo
# 165  Alfa Romeo        1               1   77.0  3:22:11.000        Alfa Romeo
# 166  Alfa Romeo        1               2    NaN          SHC        Alfa Romeo
# 184  Alfa Romeo        1               1   70.0  2:46:54.100        Alfa Romeo
# 334     Ferrari        1               1   62.0  3:01:46.100           Ferrari
# 342     Ferrari        1               1   36.0  3:03:46.300           Ferrari
# 347     Ferrari        1               1   77.0  3:00:00.000           Ferrari
# 355     Ferrari        1               1   85.0  2:44:11.000           Ferrari

# %% [markdown]
# One thing with the earlier F1 races that I've noted in my previous analysis attempts is that the there were a lot of shared drives. In this dataset, those rows are easier to find. In the column for time, they have a value of `SHC`. In doing my calculations, I'll ignore these rows.

# %%
wins_clean = wins[wins["time"] != "SHC"]

# %%
wins_clean.head(15)
# Out:
#      race_id  year  round_id      race_name              driver code  \
# 0          1  1950         1  Great Britain         Nino Farina  FAR
# 4          2  1950         2         Monaco  Juan Manuel Fangio  FAN
# 7          4  1950         4    Switzerland         Nino Farina  FAR
# 10         5  1950         5        Belgium  Juan Manuel Fangio  FAN
# 13         6  1950         6         France  Juan Manuel Fangio  FAN
# 16         7  1950         7          Italy         Nino Farina  FAR
# 158        8  1951         1    Switzerland  Juan Manuel Fangio  FAN
# 162       10  1951         3        Belgium         Nino Farina  FAR
# 165       11  1951         4         France  Juan Manuel Fangio  FAN
# 184       15  1951         9          Spain  Juan Manuel Fangio  FAN
# 334       16  1952         1    Switzerland       Piero Taruffi  TAR
# 342       18  1952         3        Belgium      Alberto Ascari  ASC
# 347       19  1952         4         France      Alberto Ascari  ASC
# 355       20  1952         5  Great Britain      Alberto Ascari  ASC
# 362       21  1952         6        Germany      Alberto Ascari  ASC
#
#     constructor position  position_order   laps         time constructor_clean
# 0    Alfa Romeo        1               1   70.0  2:13:23.600        Alfa Romeo
# 4    Alfa Romeo        1               1  100.0  3:13:18.700        Alfa Romeo
# 7    Alfa Romeo        1               1   42.0  2:02:53.700        Alfa Romeo
# 10   Alfa Romeo        1               1   35.0  2:47:26.000        Alfa Romeo
# 13   Alfa Romeo        1               1   64.0  2:57:52.800        Alfa Romeo
# 16   Alfa Romeo        1               1   80.0  2:51:17.400        Alfa Romeo
# 158  Alfa Romeo        1               1   42.0  2:07:53.640        Alfa Romeo
# 162  Alfa Romeo        1               1   36.0  2:45:46.200        Alfa Romeo
# 165  Alfa Romeo        1               1   77.0  3:22:11.000        Alfa Romeo
# 184  Alfa Romeo        1               1   70.0  2:46:54.100        Alfa Romeo
# 334     Ferrari        1               1   62.0  3:01:46.100           Ferrari
# 342     Ferrari        1               1   36.0  3:03:46.300           Ferrari
# 347     Ferrari        1               1   77.0  3:00:00.000           Ferrari
# 355     Ferrari        1               1   85.0  2:44:11.000           Ferrari
# 362     Ferrari        1               1   18.0  3:06:13.300           Ferrari

# %%
wins_grouped = wins_clean.copy().groupby(["year", "constructor_clean"])

# %%
count_wins = wins_grouped.position.count().rename("wins")

# %%
count_wins.head(20)
# Out:
# year  constructor_clean
# 1950  Alfa Romeo           6
# 1951  Alfa Romeo           4
# 1952  Ferrari              7
# 1953  Ferrari              7
# 1954  Mercedes             4
# 1955  Mercedes             5
# 1956  Ferrari              5
# 1957  Maserati             4
# 1958  Ferrari              2
# 1959  Cooper               5
# 1960  Cooper               6
# 1961  Ferrari              5
# 1962  BRM                  4
# 1963  Lotus                7
# 1964  Ferrari              3
# 1965  Lotus                6
# 1966  Brabham              4
# 1967  Brabham              4
# 1968  Lotus                5
# 1969  Matra                6
# Name: wins, dtype: int64

# %%
count_wins = count_wins.to_frame().reset_index()

# %%
count_wins.head(13)
# Out:
#     year constructor_clean  wins
# 0   1950        Alfa Romeo     6
# 1   1951        Alfa Romeo     4
# 2   1952           Ferrari     7
# 3   1953           Ferrari     7
# 4   1954          Mercedes     4
# 5   1955          Mercedes     5
# 6   1956           Ferrari     5
# 7   1957          Maserati     4
# 8   1958           Ferrari     2
# 9   1959            Cooper     5
# 10  1960            Cooper     6
# 11  1961           Ferrari     5
# 12  1962               BRM     4

# %%
count_wins.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 69 entries, 0 to 68
# Data columns (total 3 columns):
# year                 69 non-null int64
# constructor_clean    69 non-null object
# wins                 69 non-null int64
# dtypes: int64(2), object(1)
# memory usage: 1.7+ KB

# %%
count_wins.sort_values(by="wins",ascending=False)
# Out:
#     year constructor_clean  wins
# 66  2016          Mercedes    19
# 65  2015          Mercedes    16
# 64  2014          Mercedes    16
# 38  1988           McLaren    15
# 54  2004           Ferrari    15
# 52  2002           Ferrari    15
# 63  2013          Red Bull    13
# 34  1984           McLaren    12
# 67  2017          Mercedes    12
# 61  2011          Red Bull    12
# 46  1996          Williams    12
# 45  1995          Benetton    11
# 68  2018          Mercedes    11
# 39  1989           McLaren    10
# 50  2000           Ferrari    10
# 42  1992          Williams    10
# 43  1993          Williams    10
# 60  2010          Red Bull     9
# 57  2007           Ferrari     9
# 48  1998           McLaren     9
# 37  1987          Williams     9
# 51  2001           Ferrari     9
# 44  1994          Benetton     8
# 47  1997          Williams     8
# 28  1978             Lotus     8
# 41  1991           McLaren     8
# 55  2005           Renault     8
# 56  2006           Renault     8
# 59  2009          Brawn GP     8
# 53  2003           Ferrari     8
# ..   ...               ...   ...
# 19  1969             Matra     6
# 58  2008           McLaren     6
# 20  1970             Lotus     6
# 25  1975           Ferrari     6
# 26  1976           McLaren     6
# 29  1979           Ferrari     6
# 0   1950        Alfa Romeo     6
# 40  1990           McLaren     6
# 30  1980          Williams     6
# 23  1973           Tyrrell     5
# 5   1955          Mercedes     5
# 6   1956           Ferrari     5
# 18  1968             Lotus     5
# 22  1972             Lotus     5
# 11  1961           Ferrari     5
# 9   1959            Cooper     5
# 36  1986           McLaren     4
# 24  1974           McLaren     4
# 33  1983           Brabham     4
# 12  1962               BRM     4
# 7   1957          Maserati     4
# 17  1967           Brabham     4
# 27  1977           Ferrari     4
# 4   1954          Mercedes     4
# 16  1966           Brabham     4
# 1   1951        Alfa Romeo     4
# 14  1964           Ferrari     3
# 31  1981           Brabham     3
# 8   1958           Ferrari     2
# 32  1982          Williams     1
#
# [69 rows x 3 columns]

# %% [markdown]
# Let me add an extra column for the run to reference and then we can save it:

# %%
def team_run(row):
    return (str(row.year) + " " + str(row.constructor_clean))
    
count_wins["run"] = count_wins.apply(team_run, axis=1)

# %%
count_wins.head(3)
# Out:
#    year constructor_clean  wins              run
# 0  1950        Alfa Romeo     6  1950 Alfa Romeo
# 1  1951        Alfa Romeo     4  1951 Alfa Romeo
# 2  1952           Ferrari     7     1952 Ferrari

# %%
count_wins.to_csv("../data/output/win_count.csv",index=False)

# %% [markdown]
# Looking at this list, Mercedes' 2016 run would be the best F1 season. But we're not accounting for the fact that the number of races per season has varied. Let's try to take that into account by finding the number of races in a season and dividing the number of wins by the number of races in the season.

# %%
normalize_wins = count_wins.copy()

# %%
def races_in_season(row):
    y = int(row.year)
    season = results[results.year == y]
    number = season.round_id.max()
    return number

# %%
normalize_wins["races"] = normalize_wins.apply(races_in_season, axis=1)

# %%
normalize_wins.head()
# Out:
#    year constructor_clean  wins              run  races
# 0  1950        Alfa Romeo     6  1950 Alfa Romeo      7
# 1  1951        Alfa Romeo     4  1951 Alfa Romeo      9
# 2  1952           Ferrari     7     1952 Ferrari      8
# 3  1953           Ferrari     7     1953 Ferrari      9
# 4  1954          Mercedes     4    1954 Mercedes      9

# %% [markdown]
# Now we can find the percentage of races each team had in their season:

# %%
normalize_wins["win_percentage"] = (normalize_wins["wins"] / normalize_wins["races"])*100

# %%
normalize_wins.head()
# Out:
#    year constructor_clean  wins              run  races  win_percentage
# 0  1950        Alfa Romeo     6  1950 Alfa Romeo      7       85.714286
# 1  1951        Alfa Romeo     4  1951 Alfa Romeo      9       44.444444
# 2  1952           Ferrari     7     1952 Ferrari      8       87.500000
# 3  1953           Ferrari     7     1953 Ferrari      9       77.777778
# 4  1954          Mercedes     4    1954 Mercedes      9       44.444444

# %% [markdown]
# And now we can sort the runs based on win percentages

# %%
normalize_wins.sort_values(by="win_percentage",ascending=False)
# Out:
#     year constructor_clean  wins              run  races  win_percentage
# 38  1988           McLaren    15     1988 McLaren     16       93.750000
# 66  2016          Mercedes    19    2016 Mercedes     21       90.476190
# 52  2002           Ferrari    15     2002 Ferrari     17       88.235294
# 2   1952           Ferrari     7     1952 Ferrari      8       87.500000
# 0   1950        Alfa Romeo     6  1950 Alfa Romeo      7       85.714286
# 65  2015          Mercedes    16    2015 Mercedes     19       84.210526
# 64  2014          Mercedes    16    2014 Mercedes     19       84.210526
# 54  2004           Ferrari    15     2004 Ferrari     18       83.333333
# 3   1953           Ferrari     7     1953 Ferrari      9       77.777778
# 46  1996          Williams    12    1996 Williams     16       75.000000
# 34  1984           McLaren    12     1984 McLaren     16       75.000000
# 11  1961           Ferrari     5     1961 Ferrari      7       71.428571
# 5   1955          Mercedes     5    1955 Mercedes      7       71.428571
# 13  1963             Lotus     7       1963 Lotus     10       70.000000
# 63  2013          Red Bull    13    2013 Red Bull     19       68.421053
# 45  1995          Benetton    11    1995 Benetton     17       64.705882
# 21  1971           Tyrrell     7     1971 Tyrrell     11       63.636364
# 61  2011          Red Bull    12    2011 Red Bull     19       63.157895
# 43  1993          Williams    10    1993 Williams     16       62.500000
# 42  1992          Williams    10    1992 Williams     16       62.500000
# 39  1989           McLaren    10     1989 McLaren     16       62.500000
# 15  1965             Lotus     6       1965 Lotus     10       60.000000
# 67  2017          Mercedes    12    2017 Mercedes     20       60.000000
# 10  1960            Cooper     6      1960 Cooper     10       60.000000
# 50  2000           Ferrari    10     2000 Ferrari     17       58.823529
# 37  1987          Williams     9    1987 Williams     16       56.250000
# 48  1998           McLaren     9     1998 McLaren     16       56.250000
# 6   1956           Ferrari     5     1956 Ferrari      9       55.555556
# 9   1959            Cooper     5      1959 Cooper      9       55.555556
# 19  1969             Matra     6       1969 Matra     11       54.545455
# ..   ...               ...   ...              ...    ...             ...
# 59  2009          Brawn GP     8    2009 Brawn GP     17       47.058824
# 20  1970             Lotus     6       1970 Lotus     13       46.153846
# 7   1957          Maserati     4    1957 Maserati      9       44.444444
# 1   1951        Alfa Romeo     4  1951 Alfa Romeo      9       44.444444
# 12  1962               BRM     4         1962 BRM      9       44.444444
# 16  1966           Brabham     4     1966 Brabham      9       44.444444
# 4   1954          Mercedes     4    1954 Mercedes      9       44.444444
# 56  2006           Renault     8     2006 Renault     18       44.444444
# 49  1999           McLaren     7     1999 McLaren     16       43.750000
# 30  1980          Williams     6    1980 Williams     14       42.857143
# 25  1975           Ferrari     6     1975 Ferrari     14       42.857143
# 55  2005           Renault     8     2005 Renault     19       42.105263
# 18  1968             Lotus     5       1968 Lotus     12       41.666667
# 22  1972             Lotus     5       1972 Lotus     12       41.666667
# 29  1979           Ferrari     6     1979 Ferrari     15       40.000000
# 26  1976           McLaren     6     1976 McLaren     16       37.500000
# 35  1985           McLaren     6     1985 McLaren     16       37.500000
# 40  1990           McLaren     6     1990 McLaren     16       37.500000
# 17  1967           Brabham     4     1967 Brabham     11       36.363636
# 23  1973           Tyrrell     5     1973 Tyrrell     14       35.714286
# 62  2012          Red Bull     7    2012 Red Bull     20       35.000000
# 58  2008           McLaren     6     2008 McLaren     18       33.333333
# 14  1964           Ferrari     3     1964 Ferrari     10       30.000000
# 24  1974           McLaren     4     1974 McLaren     15       26.666667
# 33  1983           Brabham     4     1983 Brabham     15       26.666667
# 36  1986           McLaren     4     1986 McLaren     16       25.000000
# 27  1977           Ferrari     4     1977 Ferrari     17       23.529412
# 31  1981           Brabham     3     1981 Brabham     15       20.000000
# 8   1958           Ferrari     2     1958 Ferrari     11       18.181818
# 32  1982          Williams     1    1982 Williams     16        6.250000
#
# [69 rows x 6 columns]

# %% [markdown]
# From this we can see that McLaren's 1988 run was actually better than Mercedes' 2016 run — McLaren only lost 1 race. Let's save it.

# %%
normalize_wins.to_csv("../data/output/win_count_normalized.csv", index=False)

# %% [markdown]
# Let's move on to method 2.

# %% [markdown]
# ---
#
# ## Method 02: Podiums
#
# Looking at the wins is a good start, but there are a lot of factors about the team's performance over a season that it leaves out.
#
# * It only shows a very narrow slice of the team's drivers's performance. If we only know that one of the drivers won, we have no idea how the other driver did.
# * It offers a limited amount of comparison. Winning is a binary variable — you win or you don't. When looking at the history of the sport, things are greyer. For example, Keke Rosberg won the driver's cup in 1982, but he only had one victory that season. Looking only at the number of wins doesn't provide any context about how this happened.
#
# We can dig a little deeper and look at podiums. The podium refers to the drivers who finished first, second, and third in any given race. A team that consistenly has both drivers on the podium over a season is doing amazing. (ex: Mercedes in 2019 is dominating right now with Bottas and Hamilton in the podium for every race)

# %%
podiums = results[results.position.isin(["1", "2", "3"])]

# %%
podiums.head(23)
# Out:
#      race_id  year  round_id      race_name              driver code  \
# 0          1  1950         1  Great Britain         Nino Farina  FAR
# 1          1  1950         1  Great Britain       Luigi Fagioli  FAG
# 2          1  1950         1  Great Britain         Reg Parnell  PAR
# 4          2  1950         2         Monaco  Juan Manuel Fangio  FAN
# 7          4  1950         4    Switzerland         Nino Farina  FAR
# 8          4  1950         4    Switzerland       Luigi Fagioli  FAG
# 10         5  1950         5        Belgium  Juan Manuel Fangio  FAN
# 11         5  1950         5        Belgium       Luigi Fagioli  FAG
# 13         6  1950         6         France  Juan Manuel Fangio  FAN
# 14         6  1950         6         France       Luigi Fagioli  FAG
# 16         7  1950         7          Italy         Nino Farina  FAR
# 17         7  1950         7          Italy       Luigi Fagioli  FAG
# 158        8  1951         1    Switzerland  Juan Manuel Fangio  FAN
# 159        8  1951         1    Switzerland         Nino Farina  FAR
# 162       10  1951         3        Belgium         Nino Farina  FAR
# 165       11  1951         4         France  Juan Manuel Fangio  FAN
# 166       11  1951         4         France       Luigi Fagioli  FAG
# 171       12  1951         6  Great Britain  Juan Manuel Fangio  FAN
# 175       13  1951         7        Germany  Juan Manuel Fangio  FAN
# 179       14  1951         8          Italy      Felice Bonetto  BON
# 180       14  1951         8          Italy         Nino Farina  FAR
# 184       15  1951         9          Spain  Juan Manuel Fangio  FAN
# 185       15  1951         9          Spain         Nino Farina  FAR
#
#     constructor position  position_order   laps         time constructor_clean
# 0    Alfa Romeo        1               1   70.0  2:13:23.600        Alfa Romeo
# 1    Alfa Romeo        2               2   70.0      +2.600s        Alfa Romeo
# 2    Alfa Romeo        3               3   70.0     +52.000s        Alfa Romeo
# 4    Alfa Romeo        1               1  100.0  3:13:18.700        Alfa Romeo
# 7    Alfa Romeo        1               1   42.0  2:02:53.700        Alfa Romeo
# 8    Alfa Romeo        2               2   42.0      +0.400s        Alfa Romeo
# 10   Alfa Romeo        1               1   35.0  2:47:26.000        Alfa Romeo
# 11   Alfa Romeo        2               2   35.0     +14.000s        Alfa Romeo
# 13   Alfa Romeo        1               1   64.0  2:57:52.800        Alfa Romeo
# 14   Alfa Romeo        2               2   64.0     +25.700s        Alfa Romeo
# 16   Alfa Romeo        1               1   80.0  2:51:17.400        Alfa Romeo
# 17   Alfa Romeo        3               4   80.0     +95.600s        Alfa Romeo
# 158  Alfa Romeo        1               1   42.0  2:07:53.640        Alfa Romeo
# 159  Alfa Romeo        3               3   42.0     +79.310s        Alfa Romeo
# 162  Alfa Romeo        1               1   36.0  2:45:46.200        Alfa Romeo
# 165  Alfa Romeo        1               1   77.0  3:22:11.000        Alfa Romeo
# 166  Alfa Romeo        1               2    NaN          SHC        Alfa Romeo
# 171  Alfa Romeo        2               2   90.0     +51.000s        Alfa Romeo
# 175  Alfa Romeo        2               2   20.0     +30.500s        Alfa Romeo
# 179  Alfa Romeo        3               3    NaN          SHC        Alfa Romeo
# 180  Alfa Romeo        3               4   79.0       +1 lap        Alfa Romeo
# 184  Alfa Romeo        1               1   70.0  2:46:54.100        Alfa Romeo
# 185  Alfa Romeo        3               3   70.0    +105.540s        Alfa Romeo

# %% [markdown]
# As I mentioned earlier, shared drives were a common thing in the early years of Formula1 and they're findable in the data by looking for any rows for where the `time` is `SHC`.
#
# When looking at the podiums, I'll be doing the same.

# %%
podiums_clean = podiums[podiums.time != "SHC"]

# %%
podiums_clean.head(21)
# Out:
#      race_id  year  round_id      race_name              driver code  \
# 0          1  1950         1  Great Britain         Nino Farina  FAR
# 1          1  1950         1  Great Britain       Luigi Fagioli  FAG
# 2          1  1950         1  Great Britain         Reg Parnell  PAR
# 4          2  1950         2         Monaco  Juan Manuel Fangio  FAN
# 7          4  1950         4    Switzerland         Nino Farina  FAR
# 8          4  1950         4    Switzerland       Luigi Fagioli  FAG
# 10         5  1950         5        Belgium  Juan Manuel Fangio  FAN
# 11         5  1950         5        Belgium       Luigi Fagioli  FAG
# 13         6  1950         6         France  Juan Manuel Fangio  FAN
# 14         6  1950         6         France       Luigi Fagioli  FAG
# 16         7  1950         7          Italy         Nino Farina  FAR
# 17         7  1950         7          Italy       Luigi Fagioli  FAG
# 158        8  1951         1    Switzerland  Juan Manuel Fangio  FAN
# 159        8  1951         1    Switzerland         Nino Farina  FAR
# 162       10  1951         3        Belgium         Nino Farina  FAR
# 165       11  1951         4         France  Juan Manuel Fangio  FAN
# 171       12  1951         6  Great Britain  Juan Manuel Fangio  FAN
# 175       13  1951         7        Germany  Juan Manuel Fangio  FAN
# 180       14  1951         8          Italy         Nino Farina  FAR
# 184       15  1951         9          Spain  Juan Manuel Fangio  FAN
# 185       15  1951         9          Spain         Nino Farina  FAR
#
#     constructor position  position_order   laps         time constructor_clean
# 0    Alfa Romeo        1               1   70.0  2:13:23.600        Alfa Romeo
# 1    Alfa Romeo        2               2   70.0      +2.600s        Alfa Romeo
# 2    Alfa Romeo        3               3   70.0     +52.000s        Alfa Romeo
# 4    Alfa Romeo        1               1  100.0  3:13:18.700        Alfa Romeo
# 7    Alfa Romeo        1               1   42.0  2:02:53.700        Alfa Romeo
# 8    Alfa Romeo        2               2   42.0      +0.400s        Alfa Romeo
# 10   Alfa Romeo        1               1   35.0  2:47:26.000        Alfa Romeo
# 11   Alfa Romeo        2               2   35.0     +14.000s        Alfa Romeo
# 13   Alfa Romeo        1               1   64.0  2:57:52.800        Alfa Romeo
# 14   Alfa Romeo        2               2   64.0     +25.700s        Alfa Romeo
# 16   Alfa Romeo        1               1   80.0  2:51:17.400        Alfa Romeo
# 17   Alfa Romeo        3               4   80.0     +95.600s        Alfa Romeo
# 158  Alfa Romeo        1               1   42.0  2:07:53.640        Alfa Romeo
# 159  Alfa Romeo        3               3   42.0     +79.310s        Alfa Romeo
# 162  Alfa Romeo        1               1   36.0  2:45:46.200        Alfa Romeo
# 165  Alfa Romeo        1               1   77.0  3:22:11.000        Alfa Romeo
# 171  Alfa Romeo        2               2   90.0     +51.000s        Alfa Romeo
# 175  Alfa Romeo        2               2   20.0     +30.500s        Alfa Romeo
# 180  Alfa Romeo        3               4   79.0       +1 lap        Alfa Romeo
# 184  Alfa Romeo        1               1   70.0  2:46:54.100        Alfa Romeo
# 185  Alfa Romeo        3               3   70.0    +105.540s        Alfa Romeo

# %% [markdown]
# Now let's count them.

# %%
count_podiums = podiums_clean.groupby(["year", "constructor_clean"]).position.count().rename("podiums")

# %%
count_podiums.head()
# Out:
# year  constructor_clean
# 1950  Alfa Romeo           12
# 1951  Alfa Romeo            9
# 1952  Ferrari              17
# 1953  Ferrari              16
# 1954  Mercedes              7
# Name: podiums, dtype: int64

# %%
count_podiums = count_podiums.to_frame().reset_index()

# %%
count_podiums.head()
# Out:
#    year constructor_clean  podiums
# 0  1950        Alfa Romeo       12
# 1  1951        Alfa Romeo        9
# 2  1952           Ferrari       17
# 3  1953           Ferrari       16
# 4  1954          Mercedes        7

# %%
count_podiums.sort_values(by="podiums",ascending=False).head(20)
# Out:
#     year constructor_clean  podiums
# 66  2016          Mercedes       33
# 65  2015          Mercedes       32
# 64  2014          Mercedes       31
# 54  2004           Ferrari       29
# 52  2002           Ferrari       27
# 61  2011          Red Bull       27
# 67  2017          Mercedes       26
# 38  1988           McLaren       25
# 68  2018          Mercedes       25
# 51  2001           Ferrari       24
# 63  2013          Red Bull       24
# 57  2007           Ferrari       22
# 43  1993          Williams       22
# 50  2000           Ferrari       21
# 46  1996          Williams       21
# 42  1992          Williams       21
# 60  2010          Red Bull       20
# 48  1998           McLaren       20
# 56  2006           Renault       19
# 55  2005           Renault       18

# %% [markdown]
# We can save this version of raw podium counts and get to normalizing the podiums over the season to better compare the different runs. But before that let's add the column to indicate each team's run:

# %%
count_podiums["run"] = count_podiums.apply(team_run, axis=1)

# %%
count_podiums.to_csv("../data/output/podium_count.csv")

# %% [markdown]
# To normalize the podiums, we'll need to get the number of possible podiums in a season. That's the number of races times 3. When counting the number of wins we figured out how to do the races already.

# %%
normalize_podiums = count_podiums.copy()

# %%
normalize_podiums["races"] = normalize_podiums.apply(races_in_season, axis=1)

# %%
normalize_podiums.head()
# Out:
#    year constructor_clean  podiums              run  races
# 0  1950        Alfa Romeo       12  1950 Alfa Romeo      7
# 1  1951        Alfa Romeo        9  1951 Alfa Romeo      9
# 2  1952           Ferrari       17     1952 Ferrari      8
# 3  1953           Ferrari       16     1953 Ferrari      9
# 4  1954          Mercedes        7    1954 Mercedes      9

# %% [markdown]
# While there are three podium spots every race, for the majority of Formula 1 seasons, teams have only had two drivers, so the maximum number of podium spots a team can have in a season is `2 * (number of races)`

# %%
normalize_podiums["available_podium_spots"] = normalize_podiums.races * 2

# %%
normalize_podiums.head()
# Out:
#    year constructor_clean  podiums              run  races  \
# 0  1950        Alfa Romeo       12  1950 Alfa Romeo      7
# 1  1951        Alfa Romeo        9  1951 Alfa Romeo      9
# 2  1952           Ferrari       17     1952 Ferrari      8
# 3  1953           Ferrari       16     1953 Ferrari      9
# 4  1954          Mercedes        7    1954 Mercedes      9
#
#    available_podium_spots
# 0                      14
# 1                      18
# 2                      16
# 3                      18
# 4                      18

# %% [markdown]
# And now we have everything to compute a podium percentage.

# %%
normalize_podiums["podium_percentage"] = (normalize_podiums.podiums / normalize_podiums.available_podium_spots ) * 100

# %%
normalize_podiums.head(20)
# Out:
#     year constructor_clean  podiums              run  races  \
# 0   1950        Alfa Romeo       12  1950 Alfa Romeo      7
# 1   1951        Alfa Romeo        9  1951 Alfa Romeo      9
# 2   1952           Ferrari       17     1952 Ferrari      8
# 3   1953           Ferrari       16     1953 Ferrari      9
# 4   1954          Mercedes        7    1954 Mercedes      9
# 5   1955          Mercedes       10    1955 Mercedes      7
# 6   1956           Ferrari       10     1956 Ferrari      9
# 7   1957          Maserati       10    1957 Maserati      9
# 8   1958           Ferrari       14     1958 Ferrari     11
# 9   1959            Cooper       13      1959 Cooper      9
# 10  1960            Cooper       14      1960 Cooper     10
# 11  1961           Ferrari       14     1961 Ferrari      7
# 12  1962               BRM        8         1962 BRM      9
# 13  1963             Lotus        9       1963 Lotus     10
# 14  1964           Ferrari       10     1964 Ferrari     10
# 15  1965             Lotus        7       1965 Lotus     10
# 16  1966           Brabham        9     1966 Brabham      9
# 17  1967           Brabham       14     1967 Brabham     11
# 18  1968             Lotus        9       1968 Lotus     12
# 19  1969             Matra       10       1969 Matra     11
#
#     available_podium_spots  podium_percentage
# 0                       14          85.714286
# 1                       18          50.000000
# 2                       16         106.250000
# 3                       18          88.888889
# 4                       18          38.888889
# 5                       14          71.428571
# 6                       18          55.555556
# 7                       18          55.555556
# 8                       22          63.636364
# 9                       18          72.222222
# 10                      20          70.000000
# 11                      14         100.000000
# 12                      18          44.444444
# 13                      20          45.000000
# 14                      20          50.000000
# 15                      20          35.000000
# 16                      18          50.000000
# 17                      22          63.636364
# 18                      24          37.500000
# 19                      22          45.454545

# %%
normalize_podiums.sort_values(by="podium_percentage",ascending=False).head(10)
# Out:
#     year constructor_clean  podiums              run  races  \
# 2   1952           Ferrari       17     1952 Ferrari      8
# 11  1961           Ferrari       14     1961 Ferrari      7
# 3   1953           Ferrari       16     1953 Ferrari      9
# 0   1950        Alfa Romeo       12  1950 Alfa Romeo      7
# 65  2015          Mercedes       32    2015 Mercedes     19
# 64  2014          Mercedes       31    2014 Mercedes     19
# 54  2004           Ferrari       29     2004 Ferrari     18
# 52  2002           Ferrari       27     2002 Ferrari     17
# 66  2016          Mercedes       33    2016 Mercedes     21
# 38  1988           McLaren       25     1988 McLaren     16
#
#     available_podium_spots  podium_percentage
# 2                       16         106.250000
# 11                      14         100.000000
# 3                       18          88.888889
# 0                       14          85.714286
# 65                      38          84.210526
# 64                      38          81.578947
# 54                      36          80.555556
# 52                      34          79.411765
# 66                      42          78.571429
# 38                      32          78.125000

# %% [markdown]
# The top four teams all had more than two drivers in their runs. This was a more common thing in the earlier years of Formula 1.
#
# Maybe I should normalize these percentages by accounting for the number of drivers per team in each season. Something like:
# `(podiums / podium_spots) / (number of drivers)`.
#
# To do this, I first need to get a full count of the teams in each season and how many drivers they have race in a season.

# %%
results.head()
# Out:
#    race_id  year  round_id      race_name              driver code  \
# 0        1  1950         1  Great Britain         Nino Farina  FAR
# 1        1  1950         1  Great Britain       Luigi Fagioli  FAG
# 2        1  1950         1  Great Britain         Reg Parnell  PAR
# 3        1  1950         1  Great Britain  Juan Manuel Fangio  FAN
# 4        2  1950         2         Monaco  Juan Manuel Fangio  FAN
#
#   constructor position  position_order   laps         time constructor_clean
# 0  Alfa Romeo        1               1   70.0  2:13:23.600        Alfa Romeo
# 1  Alfa Romeo        2               2   70.0      +2.600s        Alfa Romeo
# 2  Alfa Romeo        3               3   70.0     +52.000s        Alfa Romeo
# 3  Alfa Romeo       NC              13   62.0          DNF        Alfa Romeo
# 4  Alfa Romeo        1               1  100.0  3:13:18.700        Alfa Romeo

# %% [markdown]
# I had come up with a few different ways of doing this:
#
# * v1: count the total number of unique drivers in a season regardless of how many races they competed in
# * v2: count the number of unique drivers that raced in the team's first race of the season

# %%
def drivers_in_season_v1(row):
    season = results[(results.year == row.year)]
    team = season[(season.constructor_clean == row.constructor_clean)]
    
    return team.driver.nunique()

def drivers_in_season_v2(row):
    season = results[results.year == row.year]
    team = season[season.constructor_clean == row.constructor_clean]
    first_race = team.round_id.min()
    
    return team[team.round_id == first_race].driver.nunique()

# %%
normalize_podiums["num_drivers_v1"] = normalize_podiums.apply(drivers_in_season_v1, axis=1)
normalize_podiums["num_drivers_v2"] = normalize_podiums.apply(drivers_in_season_v2, axis=1)

# %%
normalize_podiums.head(20)
# Out:
#     year constructor_clean  podiums              run  races  \
# 0   1950        Alfa Romeo       12  1950 Alfa Romeo      7
# 1   1951        Alfa Romeo        9  1951 Alfa Romeo      9
# 2   1952           Ferrari       17     1952 Ferrari      8
# 3   1953           Ferrari       16     1953 Ferrari      9
# 4   1954          Mercedes        7    1954 Mercedes      9
# 5   1955          Mercedes       10    1955 Mercedes      7
# 6   1956           Ferrari       10     1956 Ferrari      9
# 7   1957          Maserati       10    1957 Maserati      9
# 8   1958           Ferrari       14     1958 Ferrari     11
# 9   1959            Cooper       13      1959 Cooper      9
# 10  1960            Cooper       14      1960 Cooper     10
# 11  1961           Ferrari       14     1961 Ferrari      7
# 12  1962               BRM        8         1962 BRM      9
# 13  1963             Lotus        9       1963 Lotus     10
# 14  1964           Ferrari       10     1964 Ferrari     10
# 15  1965             Lotus        7       1965 Lotus     10
# 16  1966           Brabham        9     1966 Brabham      9
# 17  1967           Brabham       14     1967 Brabham     11
# 18  1968             Lotus        9       1968 Lotus     12
# 19  1969             Matra       10       1969 Matra     11
#
#     available_podium_spots  podium_percentage  num_drivers_v1  num_drivers_v2
# 0                       14          85.714286               6               4
# 1                       18          50.000000               7               4
# 2                       16         106.250000              15               6
# 3                       18          88.888889              11               4
# 4                       18          38.888889               4               3
# 5                       14          71.428571               6               4
# 6                       18          55.555556               9               5
# 7                       18          55.555556              16               7
# 8                       22          63.636364               6               3
# 9                       18          72.222222              12               5
# 10                      20          70.000000              21               5
# 11                      14         100.000000               7               3
# 12                      18          44.444444               3               2
# 13                      20          45.000000               9               3
# 14                      20          50.000000               4               2
# 15                      20          35.000000               6               2
# 16                      18          50.000000               3               1
# 17                      22          63.636364               3               2
# 18                      24          37.500000               7               2
# 19                      22          45.454545               3               2

# %%
normalize_podiums["podium_percentage_perdriver_v1"] = (normalize_podiums.podium_percentage) / (normalize_podiums.num_drivers_v1)
normalize_podiums["podium_percentage_perdriver_v2"] = (normalize_podiums.podium_percentage) / (normalize_podiums.num_drivers_v2)

# %%
normalize_podiums.head()
# Out:
#    year constructor_clean  podiums              run  races  \
# 0  1950        Alfa Romeo       12  1950 Alfa Romeo      7
# 1  1951        Alfa Romeo        9  1951 Alfa Romeo      9
# 2  1952           Ferrari       17     1952 Ferrari      8
# 3  1953           Ferrari       16     1953 Ferrari      9
# 4  1954          Mercedes        7    1954 Mercedes      9
#
#    available_podium_spots  podium_percentage  num_drivers_v1  num_drivers_v2  \
# 0                      14          85.714286               6               4
# 1                      18          50.000000               7               4
# 2                      16         106.250000              15               6
# 3                      18          88.888889              11               4
# 4                      18          38.888889               4               3
#
#    podium_percentage_perdriver_v1  podium_percentage_perdriver_v2
# 0                       14.285714                       21.428571
# 1                        7.142857                       12.500000
# 2                        7.083333                       17.708333
# 3                        8.080808                       22.222222
# 4                        9.722222                       12.962963

# %%
normalize_podiums.sort_values(by="podium_percentage_perdriver_v1",ascending=False).head(10)
# Out:
#     year constructor_clean  podiums            run  races  \
# 65  2015          Mercedes       32  2015 Mercedes     19
# 64  2014          Mercedes       31  2014 Mercedes     19
# 54  2004           Ferrari       29   2004 Ferrari     18
# 52  2002           Ferrari       27   2002 Ferrari     17
# 66  2016          Mercedes       33  2016 Mercedes     21
# 38  1988           McLaren       25   1988 McLaren     16
# 61  2011          Red Bull       27  2011 Red Bull     19
# 51  2001           Ferrari       24   2001 Ferrari     17
# 43  1993          Williams       22  1993 Williams     16
# 42  1992          Williams       21  1992 Williams     16
#
#     available_podium_spots  podium_percentage  num_drivers_v1  num_drivers_v2  \
# 65                      38          84.210526               2               2
# 64                      38          81.578947               2               2
# 54                      36          80.555556               2               2
# 52                      34          79.411765               2               2
# 66                      42          78.571429               2               2
# 38                      32          78.125000               2               2
# 61                      38          71.052632               2               2
# 51                      34          70.588235               2               2
# 43                      32          68.750000               2               2
# 42                      32          65.625000               2               2
#
#     podium_percentage_perdriver_v1  podium_percentage_perdriver_v2
# 65                       42.105263                       42.105263
# 64                       40.789474                       40.789474
# 54                       40.277778                       40.277778
# 52                       39.705882                       39.705882
# 66                       39.285714                       39.285714
# 38                       39.062500                       39.062500
# 61                       35.526316                       35.526316
# 51                       35.294118                       35.294118
# 43                       34.375000                       34.375000
# 42                       32.812500                       32.812500

# %%
normalize_podiums.sort_values(by="podium_percentage_perdriver_v2",ascending=False).head(10)
# Out:
#     year constructor_clean  podiums            run  races  \
# 16  1966           Brabham        9   1966 Brabham      9
# 65  2015          Mercedes       32  2015 Mercedes     19
# 64  2014          Mercedes       31  2014 Mercedes     19
# 54  2004           Ferrari       29   2004 Ferrari     18
# 52  2002           Ferrari       27   2002 Ferrari     17
# 66  2016          Mercedes       33  2016 Mercedes     21
# 38  1988           McLaren       25   1988 McLaren     16
# 61  2011          Red Bull       27  2011 Red Bull     19
# 51  2001           Ferrari       24   2001 Ferrari     17
# 43  1993          Williams       22  1993 Williams     16
#
#     available_podium_spots  podium_percentage  num_drivers_v1  num_drivers_v2  \
# 16                      18          50.000000               3               1
# 65                      38          84.210526               2               2
# 64                      38          81.578947               2               2
# 54                      36          80.555556               2               2
# 52                      34          79.411765               2               2
# 66                      42          78.571429               2               2
# 38                      32          78.125000               2               2
# 61                      38          71.052632               2               2
# 51                      34          70.588235               2               2
# 43                      32          68.750000               2               2
#
#     podium_percentage_perdriver_v1  podium_percentage_perdriver_v2
# 16                       16.666667                       50.000000
# 65                       42.105263                       42.105263
# 64                       40.789474                       40.789474
# 54                       40.277778                       40.277778
# 52                       39.705882                       39.705882
# 66                       39.285714                       39.285714
# 38                       39.062500                       39.062500
# 61                       35.526316                       35.526316
# 51                       35.294118                       35.294118
# 43                       34.375000                       34.375000

# %% [markdown]
# Maybe we should try something different. Currently I'm trying to normalize things in a very flat manner by trying to set an overall number of podium spots.
#
# What if we go race by race and adjust the number of podium spots based on how many drivers competed in the race. If there were 1 or 2 drivers, the total number of podium spots the team could get in that race were 1 or 2; If there were more than 2, the total number of available spots was limited to three because that's the limit of the podium.

# %%
def available_podiums(row):
    season = results[results.year == row.year]
    team = season[season.constructor_clean == row.constructor_clean]
    rounds = team.round_id.unique()
    podium_spots_available = 0
    
    for i in rounds:
        driver_count = team[team.round_id == i].driver.nunique()
        podium_spots_available += min(3,driver_count)
        
    return podium_spots_available

# %%
normalize_podiums["available_podium_spots"] = normalize_podiums.apply(available_podiums, axis=1)

# %%
normalize_podiums.head(26)
# Out:
#     year constructor_clean  podiums              run  races  \
# 0   1950        Alfa Romeo       12  1950 Alfa Romeo      7
# 1   1951        Alfa Romeo        9  1951 Alfa Romeo      9
# 2   1952           Ferrari       17     1952 Ferrari      8
# 3   1953           Ferrari       16     1953 Ferrari      9
# 4   1954          Mercedes        7    1954 Mercedes      9
# 5   1955          Mercedes       10    1955 Mercedes      7
# 6   1956           Ferrari       10     1956 Ferrari      9
# 7   1957          Maserati       10    1957 Maserati      9
# 8   1958           Ferrari       14     1958 Ferrari     11
# 9   1959            Cooper       13      1959 Cooper      9
# 10  1960            Cooper       14      1960 Cooper     10
# 11  1961           Ferrari       14     1961 Ferrari      7
# 12  1962               BRM        8         1962 BRM      9
# 13  1963             Lotus        9       1963 Lotus     10
# 14  1964           Ferrari       10     1964 Ferrari     10
# 15  1965             Lotus        7       1965 Lotus     10
# 16  1966           Brabham        9     1966 Brabham      9
# 17  1967           Brabham       14     1967 Brabham     11
# 18  1968             Lotus        9       1968 Lotus     12
# 19  1969             Matra       10       1969 Matra     11
# 20  1970             Lotus        7       1970 Lotus     13
# 21  1971           Tyrrell       11     1971 Tyrrell     11
# 22  1972             Lotus        8       1972 Lotus     12
# 23  1973           Tyrrell       15     1973 Tyrrell     14
# 24  1974           McLaren       10     1974 McLaren     15
# 25  1975           Ferrari       11     1975 Ferrari     14
#
#     available_podium_spots  podium_percentage  num_drivers_v1  num_drivers_v2  \
# 0                       18          85.714286               6               4
# 1                       21          50.000000               7               4
# 2                       22         106.250000              15               6
# 3                       24          88.888889              11               4
# 4                       17          38.888889               4               3
# 5                       18          71.428571               6               4
# 6                       21          55.555556               9               5
# 7                       21          55.555556              16               7
# 8                       29          63.636364               6               3
# 9                       24          72.222222              12               5
# 10                      27          70.000000              21               5
# 11                      21         100.000000               7               3
# 12                      19          44.444444               3               2
# 13                      27          45.000000               9               3
# 14                      22          50.000000               4               2
# 15                      23          35.000000               6               2
# 16                      17          50.000000               3               1
# 17                      27          63.636364               3               2
# 18                      33          37.500000               7               2
# 19                      25          45.454545               3               2
# 20                      32          26.923077               8               5
# 21                      23          50.000000               3               2
# 22                      27          33.333333               4               2
# 23                      30          53.571429               4               2
# 24                      45          33.333333               6               3
# 25                      28          39.285714               2               2
#
#     podium_percentage_perdriver_v1  podium_percentage_perdriver_v2
# 0                        14.285714                       21.428571
# 1                         7.142857                       12.500000
# 2                         7.083333                       17.708333
# 3                         8.080808                       22.222222
# 4                         9.722222                       12.962963
# 5                        11.904762                       17.857143
# 6                         6.172840                       11.111111
# 7                         3.472222                        7.936508
# 8                        10.606061                       21.212121
# 9                         6.018519                       14.444444
# 10                        3.333333                       14.000000
# 11                       14.285714                       33.333333
# 12                       14.814815                       22.222222
# 13                        5.000000                       15.000000
# 14                       12.500000                       25.000000
# 15                        5.833333                       17.500000
# 16                       16.666667                       50.000000
# 17                       21.212121                       31.818182
# 18                        5.357143                       18.750000
# 19                       15.151515                       22.727273
# 20                        3.365385                        5.384615
# 21                       16.666667                       25.000000
# 22                        8.333333                       16.666667
# 23                       13.392857                       26.785714
# 24                        5.555556                       11.111111
# 25                       19.642857                       19.642857

# %%
normalize_podiums["podium_percentage"] = (normalize_podiums.podiums / normalize_podiums.available_podium_spots)* 100

# %%
normalize_podiums.sort_values(by="podium_percentage",ascending=False).head(20)
# Out:
#     year constructor_clean  podiums              run  races  \
# 65  2015          Mercedes       32    2015 Mercedes     19
# 64  2014          Mercedes       31    2014 Mercedes     19
# 54  2004           Ferrari       29     2004 Ferrari     18
# 52  2002           Ferrari       27     2002 Ferrari     17
# 66  2016          Mercedes       33    2016 Mercedes     21
# 38  1988           McLaren       25     1988 McLaren     16
# 2   1952           Ferrari       17     1952 Ferrari      8
# 61  2011          Red Bull       27    2011 Red Bull     19
# 51  2001           Ferrari       24     2001 Ferrari     17
# 43  1993          Williams       22    1993 Williams     16
# 0   1950        Alfa Romeo       12  1950 Alfa Romeo      7
# 57  2007           Ferrari       22     2007 Ferrari     17
# 3   1953           Ferrari       16     1953 Ferrari      9
# 11  1961           Ferrari       14     1961 Ferrari      7
# 46  1996          Williams       21    1996 Williams     16
# 42  1992          Williams       21    1992 Williams     16
# 67  2017          Mercedes       26    2017 Mercedes     20
# 63  2013          Red Bull       24    2013 Red Bull     19
# 48  1998           McLaren       20     1998 McLaren     16
# 39  1989           McLaren       18     1989 McLaren     16
#
#     available_podium_spots  podium_percentage  num_drivers_v1  num_drivers_v2  \
# 65                      38          84.210526               2               2
# 64                      38          81.578947               2               2
# 54                      36          80.555556               2               2
# 52                      34          79.411765               2               2
# 66                      42          78.571429               2               2
# 38                      32          78.125000               2               2
# 2                       22          77.272727              15               6
# 61                      38          71.052632               2               2
# 51                      34          70.588235               2               2
# 43                      32          68.750000               2               2
# 0                       18          66.666667               6               4
# 57                      33          66.666667               2               2
# 3                       24          66.666667              11               4
# 11                      21          66.666667               7               3
# 46                      32          65.625000               2               2
# 42                      32          65.625000               2               2
# 67                      40          65.000000               2               2
# 63                      38          63.157895               2               2
# 48                      32          62.500000               2               2
# 39                      29          62.068966               2               2
#
#     podium_percentage_perdriver_v1  podium_percentage_perdriver_v2
# 65                       42.105263                       42.105263
# 64                       40.789474                       40.789474
# 54                       40.277778                       40.277778
# 52                       39.705882                       39.705882
# 66                       39.285714                       39.285714
# 38                       39.062500                       39.062500
# 2                         7.083333                       17.708333
# 61                       35.526316                       35.526316
# 51                       35.294118                       35.294118
# 43                       34.375000                       34.375000
# 0                        14.285714                       21.428571
# 57                       32.352941                       32.352941
# 3                         8.080808                       22.222222
# 11                       14.285714                       33.333333
# 46                       32.812500                       32.812500
# 42                       32.812500                       32.812500
# 67                       32.500000                       32.500000
# 63                       31.578947                       31.578947
# 48                       31.250000                       31.250000
# 39                       28.125000                       28.125000

# %% [markdown]
# Let's drop a few of the extra columns and save this.

# %%
normalize_podiums = normalize_podiums.drop(columns=["num_drivers_v1", "num_drivers_v2", "podium_percentage_perdriver_v1", "podium_percentage_perdriver_v2"])

# %%
normalize_podiums.to_csv("../data/output/podium_count_normalized.csv", index=False)

# %% [markdown]
# ----
#
# We can actually merge the normalize_podiums and normalize_wins into one data frame and not have to load multiple data frames.

# %%
combination = pd.merge(normalize_wins, normalize_podiums, on=["year", "constructor_clean", "run", "races"])

# %%
combination.head()
# Out:
#    year constructor_clean  wins              run  races  win_percentage  \
# 0  1950        Alfa Romeo     6  1950 Alfa Romeo      7       85.714286
# 1  1951        Alfa Romeo     4  1951 Alfa Romeo      9       44.444444
# 2  1952           Ferrari     7     1952 Ferrari      8       87.500000
# 3  1953           Ferrari     7     1953 Ferrari      9       77.777778
# 4  1954          Mercedes     4    1954 Mercedes      9       44.444444
#
#    podiums  available_podium_spots  podium_percentage
# 0       12                      18          66.666667
# 1        9                      21          42.857143
# 2       17                      22          77.272727
# 3       16                      24          66.666667
# 4        7                      17          41.176471

# %% [markdown]
# Neat! let's now go and re-organize these columns:

# %%
podiums_and_wins = combination[["year", "constructor_clean", "run", "races", "wins",
                                "podiums", "available_podium_spots", "win_percentage", "podium_percentage"]]

# %%
podiums_and_wins.head(10)
# Out:
#    year constructor_clean              run  races  wins  podiums  \
# 0  1950        Alfa Romeo  1950 Alfa Romeo      7     6       12
# 1  1951        Alfa Romeo  1951 Alfa Romeo      9     4        9
# 2  1952           Ferrari     1952 Ferrari      8     7       17
# 3  1953           Ferrari     1953 Ferrari      9     7       16
# 4  1954          Mercedes    1954 Mercedes      9     4        7
# 5  1955          Mercedes    1955 Mercedes      7     5       10
# 6  1956           Ferrari     1956 Ferrari      9     5       10
# 7  1957          Maserati    1957 Maserati      9     4       10
# 8  1958           Ferrari     1958 Ferrari     11     2       14
# 9  1959            Cooper      1959 Cooper      9     5       13
#
#    available_podium_spots  win_percentage  podium_percentage
# 0                      18       85.714286          66.666667
# 1                      21       44.444444          42.857143
# 2                      22       87.500000          77.272727
# 3                      24       77.777778          66.666667
# 4                      17       44.444444          41.176471
# 5                      18       71.428571          55.555556
# 6                      21       55.555556          47.619048
# 7                      21       44.444444          47.619048
# 8                      29       18.181818          48.275862
# 9                      24       55.555556          54.166667

# %%
podiums_and_wins.to_csv("../data/output/wins_and_podiums.csv", index=False)
