# %% [markdown]
# # Looking for the best Formula 1 season
#
# For my master's project, I'm making a piece about answering the question: **What championship winning team had the best Formula 1 season?**
#
# To answer this question, I'll be checking three definitions of best:
#
# 1. most wins in a season
# 1. most podiums in a season
# 1. how close was the performance to perfect
#
# To do this I was working with data provided by the [Ergast Developer API](https://ergast.com/mrd/). I noticed an error in the driver-constructor pairing for the 1950 season and wanted to verify things without moving forward. I was originally going to create a table of the driver-constructor pairs for each race, and then compare it with the data I had.
#
# Instead I went straight to the source for F1 information, [formula1.com](https://formula1.com), and scraped race information for each race from 1950 to 2018. There were some holes with how disqualifications and withdrawal were recorded (or not, in this case) as we went back in time to earlier seasons.
#
# Now I've gone and gotten data from [statsf1.com](https://www.statsf1.com/) which is tabulated in an easy to understand manner and is more complete than the formula1.com data.

# %%
import pandas as pd
import numpy as np

# %%
race_results = pd.read_csv("../data/from_scripts/statsf1_race_results.csv")

# %%
race_results.head(30)
# Out:
#     race_id  year  round race_name position    p0                   driver  \
# 0         1  1950      1   Britain        1   1.0          Giuseppe FARINA
# 1         1  1950      1   Britain        2   2.0            Luigi FAGIOLI
# 2         1  1950      1   Britain        3   3.0              Reg PARNELL
# 3         1  1950      1   Britain        4   4.0    Yves GIRAUD-CABANTOUS
# 4         1  1950      1   Britain        5   5.0             Louis ROSIER
# 5         1  1950      1   Britain        6   6.0               Bob GERARD
# 6         1  1950      1   Britain        7   7.0            Cuth HARRISON
# 7         1  1950      1   Britain        8   8.0       Philippe ETANCELIN
# 8         1  1950      1   Britain        9   9.0          David HAMPSHIRE
# 9         1  1950      1   Britain       10  10.0                  Joe FRY
# 10        1  1950      1   Britain        &  10.0       Brian SHAWE-TAYLOR
# 11        1  1950      1   Britain       11  11.0             Johnny CLAES
# 12        1  1950      1   Britain       ab  12.0       Juan Manuel FANGIO
# 13        1  1950      1   Britain       nc  13.0                Joe KELLY
# 14        1  1950      1   Britain       ab  14.0              Prince BIRA
# 15        1  1950      1   Britain       ab  15.0             David MURRAY
# 16        1  1950      1   Britain       ab  16.0           Geoff CROSSLEY
# 17        1  1950      1   Britain       ab  17.0  Emmanuel de GRAFFENRIED
# 18        1  1950      1   Britain       ab  18.0             Louis CHIRON
# 19        1  1950      1   Britain       ab  19.0            Eugène MARTIN
# 20        1  1950      1   Britain       ab  20.0             Peter WALKER
# 21        1  1950      1   Britain        &  20.0                Tony ROLT
# 22        1  1950      1   Britain       ab  21.0           Leslie JOHNSON
# 23        1  1950      1   Britain        f  22.0           Felice BONETTO
# 24        1  1950      1   Britain        f  23.0             Raymond MAYS
# 25        2  1950      2    Monaco        1   1.0       Juan Manuel FANGIO
# 26        2  1950      2    Monaco        2   2.0           Alberto ASCARI
# 27        2  1950      2    Monaco        3   3.0             Louis CHIRON
# 28        2  1950      2    Monaco        4   4.0           Raymond SOMMER
# 29        2  1950      2    Monaco        5   5.0              Prince BIRA
#
#                team          constructor_long                            extra
# 0        Alfa Romeo     Alfa Romeo Alfa Romeo   2h 13m 23.6s  ( 146.378 km/h )
# 1        Alfa Romeo     Alfa Romeo Alfa Romeo         2h 13m 26.2s  ( +02.6s )
# 2        Alfa Romeo     Alfa Romeo Alfa Romeo         2h 14m 15.6s  ( +52.0s )
# 3       Talbot Lago        Talbot Lago Talbot
# 4       Talbot Lago        Talbot Lago Talbot
# 5               ERA                   ERA ERA
# 6               ERA                   ERA ERA
# 7       Talbot Lago        Talbot Lago Talbot
# 8          Maserati         Maserati Maserati
# 9          Maserati         Maserati Maserati
# 10              NaN
# 11      Talbot Lago        Talbot Lago Talbot
# 12       Alfa Romeo     Alfa Romeo Alfa Romeo                         Oil line
# 13             Alta                 Alta Alta
# 14         Maserati         Maserati Maserati                   Fuel injection
# 15         Maserati         Maserati Maserati                           Engine
# 16             Alta                 Alta Alta                     Transmission
# 17         Maserati         Maserati Maserati                   Connecting rod
# 18         Maserati         Maserati Maserati                           Clutch
# 19      Talbot Lago        Talbot Lago Talbot                     Oil pressure
# 20              ERA                   ERA ERA
# 21              NaN                                                    Gearbox
# 22              ERA                   ERA ERA                     Supercharger
# 23  Maserati Milano  Maserati Milano Maserati                      Not present
# 24              ERA                   ERA ERA                  Entry cancelled
# 25       Alfa Romeo     Alfa Romeo Alfa Romeo    3h 13m 18.7s  ( 98.701 km/h )
# 26          Ferrari           Ferrari Ferrari
# 27         Maserati         Maserati Maserati
# 28          Ferrari           Ferrari Ferrari
# 29         Maserati         Maserati Maserati

# %% [markdown]
# Let's verify that we have the right number of races. Between 1950 and the end of the 2018 season there were 997 races.

# %%
race_results.race_id.max()
# Out:
# 997

# %% [markdown]
# Before we get to analysis, there is some processing that needs to be done. First I want to fill in the teams.

# %%
def update_teams(row):
    prev = race_results.iloc[row.name -1]
    if row.position == "&":
        return prev.team
    else:
        return row.team
    
def update_constructor_long(row):
    prev = race_results.iloc[row.name -1]
    if row.position == "&":
        return prev.constructor_long
    else:
        return row.constructor_long

# %%
race_results["team"] = race_results.apply(update_teams, axis=1)
race_results["constructor_long"] = race_results.apply(update_teams, axis = 1)

# %%
race_results.head(30)
# Out:
#     race_id  year  round race_name position    p0                   driver  \
# 0         1  1950      1   Britain        1   1.0          Giuseppe FARINA
# 1         1  1950      1   Britain        2   2.0            Luigi FAGIOLI
# 2         1  1950      1   Britain        3   3.0              Reg PARNELL
# 3         1  1950      1   Britain        4   4.0    Yves GIRAUD-CABANTOUS
# 4         1  1950      1   Britain        5   5.0             Louis ROSIER
# 5         1  1950      1   Britain        6   6.0               Bob GERARD
# 6         1  1950      1   Britain        7   7.0            Cuth HARRISON
# 7         1  1950      1   Britain        8   8.0       Philippe ETANCELIN
# 8         1  1950      1   Britain        9   9.0          David HAMPSHIRE
# 9         1  1950      1   Britain       10  10.0                  Joe FRY
# 10        1  1950      1   Britain        &  10.0       Brian SHAWE-TAYLOR
# 11        1  1950      1   Britain       11  11.0             Johnny CLAES
# 12        1  1950      1   Britain       ab  12.0       Juan Manuel FANGIO
# 13        1  1950      1   Britain       nc  13.0                Joe KELLY
# 14        1  1950      1   Britain       ab  14.0              Prince BIRA
# 15        1  1950      1   Britain       ab  15.0             David MURRAY
# 16        1  1950      1   Britain       ab  16.0           Geoff CROSSLEY
# 17        1  1950      1   Britain       ab  17.0  Emmanuel de GRAFFENRIED
# 18        1  1950      1   Britain       ab  18.0             Louis CHIRON
# 19        1  1950      1   Britain       ab  19.0            Eugène MARTIN
# 20        1  1950      1   Britain       ab  20.0             Peter WALKER
# 21        1  1950      1   Britain        &  20.0                Tony ROLT
# 22        1  1950      1   Britain       ab  21.0           Leslie JOHNSON
# 23        1  1950      1   Britain        f  22.0           Felice BONETTO
# 24        1  1950      1   Britain        f  23.0             Raymond MAYS
# 25        2  1950      2    Monaco        1   1.0       Juan Manuel FANGIO
# 26        2  1950      2    Monaco        2   2.0           Alberto ASCARI
# 27        2  1950      2    Monaco        3   3.0             Louis CHIRON
# 28        2  1950      2    Monaco        4   4.0           Raymond SOMMER
# 29        2  1950      2    Monaco        5   5.0              Prince BIRA
#
#                team constructor_long                            extra
# 0        Alfa Romeo       Alfa Romeo   2h 13m 23.6s  ( 146.378 km/h )
# 1        Alfa Romeo       Alfa Romeo         2h 13m 26.2s  ( +02.6s )
# 2        Alfa Romeo       Alfa Romeo         2h 14m 15.6s  ( +52.0s )
# 3       Talbot Lago      Talbot Lago
# 4       Talbot Lago      Talbot Lago
# 5               ERA              ERA
# 6               ERA              ERA
# 7       Talbot Lago      Talbot Lago
# 8          Maserati         Maserati
# 9          Maserati         Maserati
# 10         Maserati         Maserati
# 11      Talbot Lago      Talbot Lago
# 12       Alfa Romeo       Alfa Romeo                         Oil line
# 13             Alta             Alta
# 14         Maserati         Maserati                   Fuel injection
# 15         Maserati         Maserati                           Engine
# 16             Alta             Alta                     Transmission
# 17         Maserati         Maserati                   Connecting rod
# 18         Maserati         Maserati                           Clutch
# 19      Talbot Lago      Talbot Lago                     Oil pressure
# 20              ERA              ERA
# 21              ERA              ERA                          Gearbox
# 22              ERA              ERA                     Supercharger
# 23  Maserati Milano  Maserati Milano                      Not present
# 24              ERA              ERA                  Entry cancelled
# 25       Alfa Romeo       Alfa Romeo    3h 13m 18.7s  ( 98.701 km/h )
# 26          Ferrari          Ferrari
# 27         Maserati         Maserati
# 28          Ferrari          Ferrari
# 29         Maserati         Maserati

# %% [markdown]
# Now we can look at processing the finishing order.  In scraping I had created a rough version of the final order, but now I want to refine it more.
#
# The position column gives us information about how the driver fared in the race. There are several options:
#
# * If the position is a number (in string form or otherwise) then that is the finishing position of the driver.
# * If the position is `&` then that driver record is for a shared drive and the finishing position of that driver is the same as the record directly above it.
# * If the position is `ab` then the driver retired. We will try two different interpretations: *leave the order as is* and, *change all the retired orders to the retired order for the race.*
# * IF the position is `nc` the driver did not classify for the final positions, so we can make that the average of the retired drivers as well.
# * If the position is `f` then the driver withdrew from a race. They will ranked as the last possible spot.
# * If the position is `np` then the driver did not star the race, but was on the grid. They will be ranked as the last possible spot.
# * If the position is `dsq`, the driver was disqualified and their finishing position will be the the last possible spot.
# * If the position is `npq`, `nq`, or `exc` the driver's order will be ignored.
# * If the position is `tf` do nothing.
#
# We'll do it in two parts, first updating everything but the shared drives.

# %%
def p_final(row):
    race = race_results[race_results.race_id == row.race_id]
    last_place = race.p0.max()
    avg_retire = np.round(race[race.position.isin(["ab", "nc"])].p0.mean())
    
    if (row.position == "dsq") or (row.position == "f") or (row.position == "np"):
        return last_place
    else:
        return row.p0

# %% [markdown]
# And then updating the shared drives:

# %%
shared_drives = race_results.index[race_results.position == "&"].tolist()

def update_p_final(row):
    prev = race_results.iloc[row.name -1]
    if row.name in shared_drives:
        return prev.p_final
    else:
        return row.p_final

# %%
race_results["p_final"] = race_results.apply(p_final, axis =1)
race_results["p_final"] = race_results.apply(update_p_final, axis=1)

# %%
race_results[race_results.race_id == 273]
# Out:
#       race_id  year  round race_name position    p0              driver  \
# 7174      273  1976      9   Britain      dsq  -1.0          James HUNT
# 7175      273  1976      9   Britain        1   1.0          Niki LAUDA
# 7176      273  1976      9   Britain        2   2.0      Jody SCHECKTER
# 7177      273  1976      9   Britain        3   3.0         John WATSON
# 7178      273  1976      9   Britain        4   4.0           Tom PRYCE
# 7179      273  1976      9   Britain        5   5.0          Alan JONES
# 7180      273  1976      9   Britain        6   6.0  Emerson FITTIPALDI
# 7181      273  1976      9   Britain        7   7.0         Harald ERTL
# 7182      273  1976      9   Britain        8   8.0         Carlos PACE
# 7183      273  1976      9   Britain        9   9.0  Jean-Pierre JARIER
# 7184      273  1976      9   Britain       ab  10.0      Gunnar NILSSON
# 7185      273  1976      9   Britain       ab  11.0     Ronnie PETERSON
# 7186      273  1976      9   Britain       ab  12.0        Brett LUNGER
# 7187      273  1976      9   Britain       ab  13.0   Patrick DEPAILLER
# 7188      273  1976      9   Britain       ab  14.0    Carlos REUTEMANN
# 7189      273  1976      9   Britain       ab  15.0     Arturo MERZARIO
# 7190      273  1976      9   Britain      dsq  -1.0      Clay REGAZZONI
# 7191      273  1976      9   Britain      dsq  -1.0     Jacques LAFFITE
# 7192      273  1976      9   Britain       ab  16.0           Bob EVANS
# 7193      273  1976      9   Britain       ab  17.0  Vittorio BRAMBILLA
# 7194      273  1976      9   Britain       ab  18.0     Henri PESCAROLO
# 7195      273  1976      9   Britain       ab  19.0          Chris AMON
# 7196      273  1976      9   Britain       ab  20.0      Mario ANDRETTI
# 7197      273  1976      9   Britain       ab  21.0         Jochen MASS
# 7198      273  1976      9   Britain       ab  22.0  Hans Joachim STUCK
# 7199      273  1976      9   Britain       ab  23.0         Guy EDWARDS
# 7200      273  1976      9   Britain       nq  24.0          Jacky ICKX
# 7201      273  1976      9   Britain       nq  25.0       Divina GALICA
# 7202      273  1976      9   Britain       nq  26.0          Mike WILDS
# 7203      273  1976      9   Britain       nq  27.0      Lella LOMBARDI
# 7204      273  1976      9   Britain        f  28.0       Ingo HOFFMANN
#
#             team constructor_long                                extra  \
# 7174     McLaren          McLaren   Started unofficially 1h 43m 27.61s
# 7175     Ferrari          Ferrari      1h 44m 19.66s  ( 183.881 km/h )
# 7176     Tyrrell          Tyrrell           1h 44m 35.84s  ( +16.18s )
# 7177      Penske           Penske
# 7178      Shadow           Shadow
# 7179     Surtees          Surtees
# 7180  Copersucar       Copersucar
# 7181     Hesketh          Hesketh
# 7182     Brabham          Brabham
# 7183      Shadow           Shadow
# 7184       Lotus            Lotus                               Engine
# 7185       March            March                        Fuel pressure
# 7186     Surtees          Surtees                              Gearbox
# 7187     Tyrrell          Tyrrell                               Engine
# 7188     Brabham          Brabham                         Oil pressure
# 7189       March            March                               Engine
# 7190     Ferrari          Ferrari                          Changed car
# 7191      Ligier           Ligier                          Changed car
# 7192     Brabham          Brabham                              Gearbox
# 7193       March            March                           Suspension
# 7194     Surtees          Surtees                        Fuel pressure
# 7195      Ensign           Ensign                               Engine
# 7196       Lotus            Lotus                             Ignition
# 7197     McLaren          McLaren                               Clutch
# 7198       March            March                                 Spin
# 7199     Hesketh          Hesketh                            Collision
# 7200    Williams         Williams
# 7201     Surtees          Surtees
# 7202      Shadow           Shadow
# 7203     Brabham          Brabham
# 7204  Copersucar       Copersucar                      Car unavailable
#
#       p_final
# 7174     28.0
# 7175      1.0
# 7176      2.0
# 7177      3.0
# 7178      4.0
# 7179      5.0
# 7180      6.0
# 7181      7.0
# 7182      8.0
# 7183      9.0
# 7184     10.0
# 7185     11.0
# 7186     12.0
# 7187     13.0
# 7188     14.0
# 7189     15.0
# 7190     28.0
# 7191     28.0
# 7192     16.0
# 7193     17.0
# 7194     18.0
# 7195     19.0
# 7196     20.0
# 7197     21.0
# 7198     22.0
# 7199     23.0
# 7200     24.0
# 7201     25.0
# 7202     26.0
# 7203     27.0
# 7204     28.0

# %% [markdown]
# I will work with a slice of this `race_results` dataFrame that only includes the team in their championship winning season. Let's make that slice now:

# %%
winning_teams = pd.read_csv("../data/other/winning_teams_statsf1_v2.csv")
winning_teams.head(15)
# Out:
#     year        team
# 0   1950  Alfa Romeo
# 1   1951  Alfa Romeo
# 2   1952     Ferrari
# 3   1953     Ferrari
# 4   1954    Mercedes
# 5   1955    Mercedes
# 6   1956     Ferrari
# 7   1957    Maserati
# 8   1958     Ferrari
# 9   1959      Cooper
# 10  1960      Cooper
# 11  1961     Ferrari
# 12  1962         BRM
# 13  1963       Lotus
# 14  1964     Ferrari

# %% [markdown]
# Now we combine this dataframe with the `race_results` one:

# %%
combine = pd.merge(race_results, winning_teams, how="left", on=["year", "team"], indicator="keep")

# %%
combine[combine.race_id == 1]
# Out:
#     race_id  year  round race_name position    p0                   driver  \
# 0         1  1950      1   Britain        1   1.0          Giuseppe FARINA
# 1         1  1950      1   Britain        2   2.0            Luigi FAGIOLI
# 2         1  1950      1   Britain        3   3.0              Reg PARNELL
# 3         1  1950      1   Britain        4   4.0    Yves GIRAUD-CABANTOUS
# 4         1  1950      1   Britain        5   5.0             Louis ROSIER
# 5         1  1950      1   Britain        6   6.0               Bob GERARD
# 6         1  1950      1   Britain        7   7.0            Cuth HARRISON
# 7         1  1950      1   Britain        8   8.0       Philippe ETANCELIN
# 8         1  1950      1   Britain        9   9.0          David HAMPSHIRE
# 9         1  1950      1   Britain       10  10.0                  Joe FRY
# 10        1  1950      1   Britain        &  10.0       Brian SHAWE-TAYLOR
# 11        1  1950      1   Britain       11  11.0             Johnny CLAES
# 12        1  1950      1   Britain       ab  12.0       Juan Manuel FANGIO
# 13        1  1950      1   Britain       nc  13.0                Joe KELLY
# 14        1  1950      1   Britain       ab  14.0              Prince BIRA
# 15        1  1950      1   Britain       ab  15.0             David MURRAY
# 16        1  1950      1   Britain       ab  16.0           Geoff CROSSLEY
# 17        1  1950      1   Britain       ab  17.0  Emmanuel de GRAFFENRIED
# 18        1  1950      1   Britain       ab  18.0             Louis CHIRON
# 19        1  1950      1   Britain       ab  19.0            Eugène MARTIN
# 20        1  1950      1   Britain       ab  20.0             Peter WALKER
# 21        1  1950      1   Britain        &  20.0                Tony ROLT
# 22        1  1950      1   Britain       ab  21.0           Leslie JOHNSON
# 23        1  1950      1   Britain        f  22.0           Felice BONETTO
# 24        1  1950      1   Britain        f  23.0             Raymond MAYS
#
#                team constructor_long                            extra  \
# 0        Alfa Romeo       Alfa Romeo   2h 13m 23.6s  ( 146.378 km/h )
# 1        Alfa Romeo       Alfa Romeo         2h 13m 26.2s  ( +02.6s )
# 2        Alfa Romeo       Alfa Romeo         2h 14m 15.6s  ( +52.0s )
# 3       Talbot Lago      Talbot Lago
# 4       Talbot Lago      Talbot Lago
# 5               ERA              ERA
# 6               ERA              ERA
# 7       Talbot Lago      Talbot Lago
# 8          Maserati         Maserati
# 9          Maserati         Maserati
# 10         Maserati         Maserati
# 11      Talbot Lago      Talbot Lago
# 12       Alfa Romeo       Alfa Romeo                         Oil line
# 13             Alta             Alta
# 14         Maserati         Maserati                   Fuel injection
# 15         Maserati         Maserati                           Engine
# 16             Alta             Alta                     Transmission
# 17         Maserati         Maserati                   Connecting rod
# 18         Maserati         Maserati                           Clutch
# 19      Talbot Lago      Talbot Lago                     Oil pressure
# 20              ERA              ERA
# 21              ERA              ERA                          Gearbox
# 22              ERA              ERA                     Supercharger
# 23  Maserati Milano  Maserati Milano                      Not present
# 24              ERA              ERA                  Entry cancelled
#
#     p_final       keep
# 0       1.0       both
# 1       2.0       both
# 2       3.0       both
# 3       4.0  left_only
# 4       5.0  left_only
# 5       6.0  left_only
# 6       7.0  left_only
# 7       8.0  left_only
# 8       9.0  left_only
# 9      10.0  left_only
# 10     10.0  left_only
# 11     11.0  left_only
# 12     12.0       both
# 13     13.0  left_only
# 14     14.0  left_only
# 15     15.0  left_only
# 16     16.0  left_only
# 17     17.0  left_only
# 18     18.0  left_only
# 19     19.0  left_only
# 20     20.0  left_only
# 21     20.0  left_only
# 22     21.0  left_only
# 23     23.0  left_only
# 24     23.0  left_only

# %%
results = combine[combine.keep == "both"]

# %%
results[results.year == 1982]
# Out:
#        race_id  year  round     race_name position    p0            driver  \
# 9649       358  1982      1  South Africa        2   2.0  Carlos REUTEMANN
# 9652       358  1982      1  South Africa        5   5.0      Keke ROSBERG
# 9680       359  1982      2        Brazil      dsq  -1.0      Keke ROSBERG
# 9697       359  1982      2        Brazil       ab  17.0  Carlos REUTEMANN
# 9711       360  1982      3      USA West        2   2.0      Keke ROSBERG
# 9729       360  1982      3      USA West       ab  19.0    Mario ANDRETTI
# 9756       362  1982      5       Belgium        2   2.0      Keke ROSBERG
# 9765       362  1982      5       Belgium       ab  10.0        Derek DALY
# 9792       363  1982      6        Monaco        6   6.0        Derek DALY
# 9797       363  1982      6        Monaco       ab  11.0      Keke ROSBERG
# 9821       364  1982      7      USA East        4   4.0      Keke ROSBERG
# 9822       364  1982      7      USA East        5   5.0        Derek DALY
# 9853       365  1982      8        Canada        7   7.0        Derek DALY
# 9859       365  1982      8        Canada       ab  13.0      Keke ROSBERG
# 9878       366  1982      9   Netherlands        3   3.0      Keke ROSBERG
# 9880       366  1982      9   Netherlands        5   5.0        Derek DALY
# 9912       367  1982     10       Britain        5   5.0        Derek DALY
# 9921       367  1982     10       Britain       ab  14.0      Keke ROSBERG
# 9942       368  1982     11        France        5   5.0      Keke ROSBERG
# 9944       368  1982     11        France        7   7.0        Derek DALY
# 9970       369  1982     12       Germany        3   3.0      Keke ROSBERG
# 9981       369  1982     12       Germany       ab  14.0        Derek DALY
# 10000      370  1982     13       Austria        2   2.0      Keke ROSBERG
# 10023      370  1982     13       Austria       ab  25.0        Derek DALY
# 10028      371  1982     14   Switzerland        1   1.0      Keke ROSBERG
# 10036      371  1982     14   Switzerland        9   9.0        Derek DALY
# 10064      372  1982     15         Italy        8   8.0      Keke ROSBERG
# 10080      372  1982     15         Italy       ab  24.0        Derek DALY
# 10092      373  1982     16     Las Vegas        5   5.0      Keke ROSBERG
# 10093      373  1982     16     Las Vegas        6   6.0        Derek DALY
#
#            team constructor_long                                extra  \
# 9649   Williams         Williams         1h 32m 23.347s  ( +14.946s )
# 9652   Williams         Williams         1h 32m 54.540s  ( +46.139s )
# 9680   Williams         Williams   Weight infringement 1h 44m 05.737s
# 9697   Williams         Williams                            Collision
# 9711   Williams         Williams         1h 58m 39.978s  ( +14.660s )
# 9729   Williams         Williams                           Suspension
# 9756   Williams         Williams         1h 35m 49.263s  ( +07.268s )
# 9765   Williams         Williams                             Accident
# 9792   Williams         Williams                             Accident
# 9797   Williams         Williams                           Suspension
# 9821   Williams         Williams      1h 59m 53.019s  ( +1m 11.976s )
# 9822   Williams         Williams      2h 00m 04.800s  ( +1m 23.757s )
# 9853   Williams         Williams                          Out of fuel
# 9859   Williams         Williams                              Gearbox
# 9878   Williams         Williams         1h 38m 25.619s  ( +22.365s )
# 9880   Williams         Williams
# 9912   Williams         Williams         1h 36m 15.242s  ( +41.430s )
# 9921   Williams         Williams                        Fuel pressure
# 9942   Williams         Williams      1h 35m 04.211s  ( +1m 30.994s )
# 9944   Williams         Williams
# 9970   Williams         Williams
# 9981   Williams         Williams                               Engine
# 10000  Williams         Williams         1h 25m 02.262s  ( +00.050s )
# 10023  Williams         Williams                            Collision
# 10028  Williams         Williams     1h 32m 41.087s  ( 196.796 km/h )
# 10036  Williams         Williams
# 10064  Williams         Williams
# 10080  Williams         Williams                            Collision
# 10092  Williams         Williams      1h 43m 08.263s  ( +1m 11.375s )
# 10093  Williams         Williams
#
#        p_final  keep
# 9649       2.0  both
# 9652       5.0  both
# 9680      29.0  both
# 9697      17.0  both
# 9711       2.0  both
# 9729      19.0  both
# 9756       2.0  both
# 9765      10.0  both
# 9792       6.0  both
# 9797      11.0  both
# 9821       4.0  both
# 9822       5.0  both
# 9853       7.0  both
# 9859      13.0  both
# 9878       3.0  both
# 9880       5.0  both
# 9912       5.0  both
# 9921      14.0  both
# 9942       5.0  both
# 9944       7.0  both
# 9970       3.0  both
# 9981      14.0  both
# 10000      2.0  both
# 10023     25.0  both
# 10028      1.0  both
# 10036      9.0  both
# 10064      8.0  both
# 10080     24.0  both
# 10092      5.0  both
# 10093      6.0  both

# %% [markdown]
# And those are all the result records for Williams in 1982.
#
# We can drop the `keep` column, save a copy of this data, and start doing the three analyses.

# %%
results = results.drop(columns=["keep"])

# %%
results.to_csv("../data/other/race_results_champions.csv", index=False)

# %% [markdown]
# ---
#
# ## Method 01: Wins
#
# Let's compare championship seasons by how many wins each team got in their season.
#
# We can look for wins by doing one of two things:
#
# * pick all rows where `p_final == 1`
# * pick all rows where `position == "1"`
#
# In terms of wins, there were three races where two drivers shared first: 1951 French GP (Alfa Romeo), 1956 Argentine GP (Ferrari), and 1957 British GP (Vanwall).
#
# For this analysis I care more that the constructor/team finished first than I do about it being a shared drive. By selecting rows using the position column, I also don't have to worry about shared drives.

# %%
wins = results[results.position == "1"]

# %%
wins.head(12)
# Out:
#      race_id  year  round    race_name position   p0              driver  \
# 0          1  1950      1      Britain        1  1.0     Giuseppe FARINA
# 25         2  1950      2       Monaco        1  1.0  Juan Manuel FANGIO
# 127        4  1950      4  Switzerland        1  1.0     Giuseppe FARINA
# 150        5  1950      5      Belgium        1  1.0  Juan Manuel FANGIO
# 164        6  1950      6       France        1  1.0  Juan Manuel FANGIO
# 188        7  1950      7        Italy        1  1.0     Giuseppe FARINA
# 222        8  1951      1  Switzerland        1  1.0  Juan Manuel FANGIO
# 309       10  1951      3      Belgium        1  1.0     Giuseppe FARINA
# 325       11  1951      4       France        1  1.0       Luigi FAGIOLI
# 433       15  1951      8        Spain        1  1.0  Juan Manuel FANGIO
# 458       16  1952      1  Switzerland        1  1.0       Piero TARUFFI
# 553       18  1952      3      Belgium        1  1.0      Alberto ASCARI
#
#            team constructor_long                             extra  p_final
# 0    Alfa Romeo       Alfa Romeo    2h 13m 23.6s  ( 146.378 km/h )      1.0
# 25   Alfa Romeo       Alfa Romeo     3h 13m 18.7s  ( 98.701 km/h )      1.0
# 127  Alfa Romeo       Alfa Romeo    2h 02m 53.7s  ( 149.279 km/h )      1.0
# 150  Alfa Romeo       Alfa Romeo      2h 47m 26s  ( 177.097 km/h )      1.0
# 164  Alfa Romeo       Alfa Romeo    2h 57m 52.8s  ( 168.729 km/h )      1.0
# 188  Alfa Romeo       Alfa Romeo    2h 51m 17.4s  ( 176.543 km/h )      1.0
# 222  Alfa Romeo       Alfa Romeo   2h 07m 53.64s  ( 143.444 km/h )      1.0
# 309  Alfa Romeo       Alfa Romeo    2h 45m 46.2s  ( 183.985 km/h )      1.0
# 325  Alfa Romeo       Alfa Romeo                                        1.0
# 433  Alfa Romeo       Alfa Romeo   2h 46m 54.10s  ( 158.939 km/h )      1.0
# 458     Ferrari          Ferrari    3h 01m 46.1s  ( 148.990 km/h )      1.0
# 553     Ferrari          Ferrari    3h 03m 46.3s  ( 165.962 km/h )      1.0

# %%
wins[wins.year== 1982]
# Out:
#        race_id  year  round    race_name position   p0        driver  \
# 10028      371  1982     14  Switzerland        1  1.0  Keke ROSBERG
#
#            team constructor_long                              extra  p_final
# 10028  Williams         Williams   1h 32m 41.087s  ( 196.796 km/h )      1.0

# %% [markdown]
# Now that we've verified the wins are correct, let's do the counting:

# %%
win_count = wins.groupby(["year", "team"]).p_final.count().rename("wins")

# %%
win_count.sort_values(ascending=False).head(10)
# Out:
# year  team
# 2016  Mercedes    19
# 2015  Mercedes    16
# 2014  Mercedes    16
# 2002  Ferrari     15
# 1988  McLaren     15
# 2004  Ferrari     15
# 2013  Red Bull    13
# 1996  Williams    12
# 2017  Mercedes    12
# 2011  Red Bull    12
# Name: wins, dtype: int64

# %% [markdown]
# Let's take it from a series to a dataframe:

# %%
win_count = win_count.to_frame().reset_index()

# %%
win_count.sort_values(by="wins",ascending=False).head(10)
# Out:
#     year      team  wins
# 63  2016  Mercedes    19
# 62  2015  Mercedes    16
# 61  2014  Mercedes    16
# 52  2002   Ferrari    15
# 38  1988   McLaren    15
# 54  2004   Ferrari    15
# 60  2013  Red Bull    13
# 58  2011  Red Bull    12
# 46  1996  Williams    12
# 34  1984   McLaren    12
