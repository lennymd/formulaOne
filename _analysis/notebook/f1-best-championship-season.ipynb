# %% [markdown]
# # Looking for the best Formula 1 season
#
# For my master's project, I'm making a piece about answering the question: **What championship winning team had the best Formula 1 season?**
#
# To do this I was working with data provided by the [Ergast Developer API](https://ergast.com/mrd/). I noticed an error in the driver-constructor pairing for the 1950 season and wanted to verify things without moving forward. I was originally going to create a table of the driver-constructor pairs for each race, and then compare it with the data I had.
#
# Instead I went straight to the source for F1 information, [formula1.com](https://formula1.com), and scraped race information for each race from 1950 to 2018. There were some holes with how disqualifications and withdrawal were recorded (or not, in this case) as we went back in time to earlier seasons.
#
# Now I've gone and gotten data from [statsf1.com](https://www.statsf1.com/) which is tabulated in an easy to understand manner and is more complete than the formula1.com data, and doesn't have the issues of the Ergast data.
#
# In terms of defining best, I'll try three different things:
#
# 1. Looking at the number of wins each team got in their season
# 1. Looking at the podiums a team won during their season
# 1. Averaging finishing positions to see how close they got to a perfect season (the case where they have the lowest average for each race)

# %%
import pandas as pd
import numpy as np

# %%
race_results = pd.read_csv("../data/from_scripts/statsf1/race_results.csv")

# %%
race_results.head()
# Out:
#    race_id  year  round race_name position  order                 driver  \
# 0        1  1950      1   Britain        1      1        Giuseppe FARINA
# 1        1  1950      1   Britain        2      2          Luigi FAGIOLI
# 2        1  1950      1   Britain        3      3            Reg PARNELL
# 3        1  1950      1   Britain        4      4  Yves GIRAUD-CABANTOUS
# 4        1  1950      1   Britain        5      5           Louis ROSIER
#
#    constructor                   team                            extra
# 0   Alfa Romeo  Alfa Romeo Alfa Romeo   2h 13m 23.6s  ( 146.378 km/h )
# 1   Alfa Romeo  Alfa Romeo Alfa Romeo         2h 13m 26.2s  ( +02.6s )
# 2   Alfa Romeo  Alfa Romeo Alfa Romeo         2h 14m 15.6s  ( +52.0s )
# 3  Talbot Lago     Talbot Lago Talbot
# 4  Talbot Lago     Talbot Lago Talbot

# %% [markdown]
# Quickly check for the races in this period (should be 997)

# %%
race_results.race_id.max()
# Out:
# 997

# %% [markdown]
# I will work with a slice of this `race_results` dataFrame that only includes the team in their championship winning season. Let's make that slice now:

# %%
winning_teams = pd.read_csv("../data/other/winning_teams_statsf1.csv")

# %%
winning_teams.head()
# Out:
#    year                   team
# 0  1950  Alfa Romeo Alfa Romeo
# 1  1951  Alfa Romeo Alfa Romeo
# 2  1952        Ferrari Ferrari
# 3  1953        Ferrari Ferrari
# 4  1954      Mercedes Mercedes

# %% [markdown]
# Now we combine this dataframe with the others:

# %%
combine = pd.merge(race_results, winning_teams, how="left", on=["year", "team"], indicator="keep")

# %%
combine[combine.race_id == 1]
# Out:
#     race_id  year  round race_name position  order                   driver  \
# 0         1  1950      1   Britain        1      1          Giuseppe FARINA
# 1         1  1950      1   Britain        2      2            Luigi FAGIOLI
# 2         1  1950      1   Britain        3      3              Reg PARNELL
# 3         1  1950      1   Britain        4      4    Yves GIRAUD-CABANTOUS
# 4         1  1950      1   Britain        5      5             Louis ROSIER
# 5         1  1950      1   Britain        6      6               Bob GERARD
# 6         1  1950      1   Britain        7      7            Cuth HARRISON
# 7         1  1950      1   Britain        8      8       Philippe ETANCELIN
# 8         1  1950      1   Britain        9      9          David HAMPSHIRE
# 9         1  1950      1   Britain       10     10                  Joe FRY
# 10        1  1950      1   Britain        &     10       Brian SHAWE-TAYLOR
# 11        1  1950      1   Britain       11     11             Johnny CLAES
# 12        1  1950      1   Britain       ab     12       Juan Manuel FANGIO
# 13        1  1950      1   Britain       nc     13                Joe KELLY
# 14        1  1950      1   Britain       ab     14              Prince BIRA
# 15        1  1950      1   Britain       ab     15             David MURRAY
# 16        1  1950      1   Britain       ab     16           Geoff CROSSLEY
# 17        1  1950      1   Britain       ab     17  Emmanuel de GRAFFENRIED
# 18        1  1950      1   Britain       ab     18             Louis CHIRON
# 19        1  1950      1   Britain       ab     19            Eugène MARTIN
# 20        1  1950      1   Britain       ab     20             Peter WALKER
# 21        1  1950      1   Britain        &     20                Tony ROLT
# 22        1  1950      1   Britain       ab     21           Leslie JOHNSON
# 23        1  1950      1   Britain        f     22           Felice BONETTO
# 24        1  1950      1   Britain        f     23             Raymond MAYS
#
#         constructor                      team  \
# 0        Alfa Romeo     Alfa Romeo Alfa Romeo
# 1        Alfa Romeo     Alfa Romeo Alfa Romeo
# 2        Alfa Romeo     Alfa Romeo Alfa Romeo
# 3       Talbot Lago        Talbot Lago Talbot
# 4       Talbot Lago        Talbot Lago Talbot
# 5               ERA                   ERA ERA
# 6               ERA                   ERA ERA
# 7       Talbot Lago        Talbot Lago Talbot
# 8          Maserati         Maserati Maserati
# 9          Maserati         Maserati Maserati
# 10         Maserati         Maserati Maserati
# 11      Talbot Lago        Talbot Lago Talbot
# 12       Alfa Romeo     Alfa Romeo Alfa Romeo
# 13             Alta                 Alta Alta
# 14         Maserati         Maserati Maserati
# 15         Maserati         Maserati Maserati
# 16             Alta                 Alta Alta
# 17         Maserati         Maserati Maserati
# 18         Maserati         Maserati Maserati
# 19      Talbot Lago        Talbot Lago Talbot
# 20              ERA                   ERA ERA
# 21              ERA                   ERA ERA
# 22              ERA                   ERA ERA
# 23  Maserati Milano  Maserati Milano Maserati
# 24              ERA                   ERA ERA
#
#                               extra       keep
# 0    2h 13m 23.6s  ( 146.378 km/h )       both
# 1          2h 13m 26.2s  ( +02.6s )       both
# 2          2h 14m 15.6s  ( +52.0s )       both
# 3                                    left_only
# 4                                    left_only
# 5                                    left_only
# 6                                    left_only
# 7                                    left_only
# 8                                    left_only
# 9                                    left_only
# 10                                   left_only
# 11                                   left_only
# 12                         Oil line       both
# 13                                   left_only
# 14                   Fuel injection  left_only
# 15                           Engine  left_only
# 16                     Transmission  left_only
# 17                   Connecting rod  left_only
# 18                           Clutch  left_only
# 19                     Oil pressure  left_only
# 20                                   left_only
# 21                          Gearbox  left_only
# 22                     Supercharger  left_only
# 23                      Not present  left_only
# 24                  Entry cancelled  left_only

# %%
results = combine[combine.keep == "both"]

# %%
results[results.year == 1950]
# Out:
#      race_id  year  round     race_name position  order              driver  \
# 0          1  1950      1       Britain        1      1     Giuseppe FARINA
# 1          1  1950      1       Britain        2      2       Luigi FAGIOLI
# 2          1  1950      1       Britain        3      3         Reg PARNELL
# 12         1  1950      1       Britain       ab     12  Juan Manuel FANGIO
# 25         2  1950      2        Monaco        1      1  Juan Manuel FANGIO
# 35         2  1950      2        Monaco       ab     11       Luigi FAGIOLI
# 36         2  1950      2        Monaco       ab     12     Giuseppe FARINA
# 77         3  1950      3  Indianapolis        &     25     Fred AGABASHIAN
# 94         3  1950      3  Indianapolis       nq     41        Johnny MAURO
# 127        4  1950      4   Switzerland        1      1     Giuseppe FARINA
# 128        4  1950      4   Switzerland        2      2       Luigi FAGIOLI
# 138        4  1950      4   Switzerland       ab     12  Juan Manuel FANGIO
# 150        5  1950      5       Belgium        1      1  Juan Manuel FANGIO
# 151        5  1950      5       Belgium        2      2       Luigi FAGIOLI
# 153        5  1950      5       Belgium        4      4     Giuseppe FARINA
# 164        6  1950      6        France        1      1  Juan Manuel FANGIO
# 165        6  1950      6        France        2      2       Luigi FAGIOLI
# 172        6  1950      6        France        7      7     Giuseppe FARINA
# 188        7  1950      7         Italy        1      1     Giuseppe FARINA
# 190        7  1950      7         Italy        &      2      Alberto ASCARI
# 191        7  1950      7         Italy        3      3       Luigi FAGIOLI
# 201        7  1950      7         Italy       ab     13       Piero TARUFFI
# 204        7  1950      7         Italy       ab     15  Juan Manuel FANGIO
# 212        7  1950      7         Italy       ab     23     Consalvo SANESI
#
#     constructor                   team                            extra  keep
# 0    Alfa Romeo  Alfa Romeo Alfa Romeo   2h 13m 23.6s  ( 146.378 km/h )  both
# 1    Alfa Romeo  Alfa Romeo Alfa Romeo         2h 13m 26.2s  ( +02.6s )  both
# 2    Alfa Romeo  Alfa Romeo Alfa Romeo         2h 14m 15.6s  ( +52.0s )  both
# 12   Alfa Romeo  Alfa Romeo Alfa Romeo                         Oil line  both
# 25   Alfa Romeo  Alfa Romeo Alfa Romeo    3h 13m 18.7s  ( 98.701 km/h )  both
# 35   Alfa Romeo  Alfa Romeo Alfa Romeo                          Pile-up  both
# 36   Alfa Romeo  Alfa Romeo Alfa Romeo                          Pile-up  both
# 77   Alfa Romeo  Alfa Romeo Alfa Romeo                         Oil line  both
# 94   Alfa Romeo  Alfa Romeo Alfa Romeo                                   both
# 127  Alfa Romeo  Alfa Romeo Alfa Romeo   2h 02m 53.7s  ( 149.279 km/h )  both
# 128  Alfa Romeo  Alfa Romeo Alfa Romeo         2h 02m 54.1s  ( +00.4s )  both
# 138  Alfa Romeo  Alfa Romeo Alfa Romeo                            Valve  both
# 150  Alfa Romeo  Alfa Romeo Alfa Romeo     2h 47m 26s  ( 177.097 km/h )  both
# 151  Alfa Romeo  Alfa Romeo Alfa Romeo         2h 47m 40s  ( +14.000s )  both
# 153  Alfa Romeo  Alfa Romeo Alfa Romeo      2h 51m 31s  ( +4m 05.000s )  both
# 164  Alfa Romeo  Alfa Romeo Alfa Romeo   2h 57m 52.8s  ( 168.729 km/h )  both
# 165  Alfa Romeo  Alfa Romeo Alfa Romeo         2h 58m 18.5s  ( +25.7s )  both
# 172  Alfa Romeo  Alfa Romeo Alfa Romeo                        Fuel pump  both
# 188  Alfa Romeo  Alfa Romeo Alfa Romeo   2h 51m 17.4s  ( 176.543 km/h )  both
# 190  Alfa Romeo  Alfa Romeo Alfa Romeo      2h 52m 36.0s  ( +1m 18.6s )  both
# 191  Alfa Romeo  Alfa Romeo Alfa Romeo      2h 52m 53.0s  ( +1m 35.6s )  both
# 201  Alfa Romeo  Alfa Romeo Alfa Romeo                                   both
# 204  Alfa Romeo  Alfa Romeo Alfa Romeo                          Gearbox  both
# 212  Alfa Romeo  Alfa Romeo Alfa Romeo                           Engine  both

# %% [markdown]
# And those are all the result records for Alfa Romeo in 1950.
#
# Now we can drop the `keep` column, save a copy of this data, and start doing the three analyses.

# %%
results = results.drop(columns=["keep"])

# %%
results.to_csv("../data/output/race_results_winners.csv", index=False)

# %% [markdown]
# ---
#
# ## Method 01: Wins
#
# Let's compare championship seasons by how many wins each team got in their season.

# %%
wins = results[results.position == "1"]

# %% [markdown]
# Just noticed that **the statsf1 data has the same alberto ascari error as the ergast data**...
#
# **I know that Ergast fixed their so I'll go back to that**
