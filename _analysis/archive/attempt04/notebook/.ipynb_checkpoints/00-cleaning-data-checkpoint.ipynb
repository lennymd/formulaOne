# %% [markdown]
# # Cleaning f1db data
#
# This notebook is to clean the series of csv tables coming from the [Ergast Developer API](https://ergast.com/mrd/db/). I'm downloading the raw csv tables and processing them here.
#
# Some things to note about the data:
#
# * The data is not chronologically organized in the csv case. Race numbering starts with 1 corresponding to 2007's first race, and then goes back at a point to fill in the 1950–2006 data and also add in the data moving forward.
# * In the standings table, a new entry is not added after a race if the driver does not change standings.
# * When a cell is `\N` it means the cell is null, or the value wasn't recorded. This largely applies to things for which we had no data in the beginning.
# * Looking at the original `raceId`, something happened because Azerbaijan GP 2019 was the 1001st race but their id for the same race was 1013. I assume the counting was pushed ahead somewhere in the middle, but things are still okay.
# * The `drivers` table is actually named `driver.csv`.
#
#
# **I last downloaded this data on 19-06-10.**

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## [01] Add headers to the csv tables
#
# First thing we'll do is add headers to each table based on this [schema text file](http://ergast.com/schemas/f1db_schema.txt). I will also couple removing the `\N` characters in this step.

# %%
baseurl = "../data/f1db_csv/"
destination = "../data/source/"

#names correspond to the csv files and not the table names given at the top of the schema text file
tables = ["circuits", "constructor_results", "constructor_standings", "constructors", "driver_standings", 
          "driver", "lap_times", "pit_stops", "qualifying", "races", "results", "seasons", "status"]

# all the headers are grouped by table and put into one big list
headers = [["circuitId", "circuitRef", "name", "location", "country","lat", "lng", "alt", "url"], #circuits
          ["constructorResultsId", "raceId", "constructorId", "points", "status"], #constructor_results
          ["constructorStandingsId", "constructorId", "points", "position", "positionText", "wins"], #constructor_standings
          ["constructorId", "constructorRef", "name", "nationality", "url"], #constructors
          ["driverStandingsId", "raceId", "driverId", "points", "position", "positionText", "wins"], #driver_standings
          ["driverId", "driverRef", "number", "code", "forename", "surname", "dob", "nationality", "url" ], #drivers
          ["raceId", "driverId", "lap", "position", "time", "milliseconds"], #lap_times
          ["raceId", "driverId", "stop", "lap", "time", "duration", "milliseconds"], #pit_stops
          ["qualifyId", "raceId", "driverId", "constructorId", "number",
           "position", "q1", "q2","q3"], #qualifying
          ["raceId", "year", "round", "circuitId", "name", "date", "time", "url"], #races
          ["resultId", "raceId", "driverId", "constructorId", "number", "grid", "position",
           "positionText", "positionOrder", "points", "laps", "time", "milliseconds",
           "fastestLap", "rank", "fastestLapTime", "fastestLapSpeed", "statusId"], #results
          ["year","url"], #seasons
          ["statusId", "status"] #status
          ]

for i in range(len(tables)):
    #pick the right table name and the right header
    table = tables[i]
    header = headers[i]
    
    #import the csv file associated with the table and add in the header to it
    df = pd.read_csv(baseurl+table+".csv",names=header)
    #get rid of the null characters
    df = df.replace("\\N","")
    #export back to a csv in the working folder
    df.to_csv(destination+table+".csv", index=False, mode="w+")
    
    #status updates
    print(table,"done", sep=" --> ")
# Out:
# circuits --> done
# constructor_results --> done
# constructor_standings --> done
# constructors --> done
# driver_standings --> done
# driver --> done
# lap_times --> done
# pit_stops --> done
# qualifying --> done
# races --> done
# results --> done
# seasons --> done
# status --> done

# %% [markdown]
# I could try to figure out how to sort the drivers chronologically and the races as well as I had done before, but I don't think that's actually as important to my analysis.
#
# ---

# %% [markdown]
# ## [02] Getting a "master" table to work with
#
# I'm going to do is create a "master" table with all the relevant columns I think are of interest.

# %%
results = pd.read_csv("../data/source/results.csv")

# %%
results.head()
# Out:
#    resultId  raceId  driverId  constructorId  number  grid  position  \
# 0         1      18         1              1    22.0     1       1.0
# 1         2      18         2              2     3.0     5       2.0
# 2         3      18         3              3     7.0     7       3.0
# 3         4      18         4              4     5.0    11       4.0
# 4         5      18         5              1    23.0     3       5.0
#
#   positionText  positionOrder  points  laps         time  milliseconds  \
# 0            1              1    10.0    58  1:34:50.616     5690616.0
# 1            2              2     8.0    58       +5.478     5696094.0
# 2            3              3     6.0    58       +8.163     5698779.0
# 3            4              4     5.0    58      +17.181     5707797.0
# 4            5              5     4.0    58      +18.014     5708630.0
#
#    fastestLap  rank fastestLapTime  fastestLapSpeed  statusId
# 0        39.0   2.0       1:27.452          218.300         1
# 1        41.0   3.0       1:27.739          217.586         1
# 2        41.0   5.0       1:28.090          216.719         1
# 3        58.0   7.0       1:28.603          215.464         1
# 4        43.0   1.0       1:27.418          218.385         1

# %%
results.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24340 entries, 0 to 24339
# Data columns (total 18 columns):
# resultId           24340 non-null int64
# raceId             24340 non-null int64
# driverId           24340 non-null int64
# constructorId      24340 non-null int64
# number             24334 non-null float64
# grid               24340 non-null int64
# position           13690 non-null float64
# positionText       24340 non-null object
# positionOrder      24340 non-null int64
# points             24340 non-null float64
# laps               24340 non-null int64
# time               6269 non-null object
# milliseconds       6268 non-null float64
# fastestLap         5922 non-null float64
# rank               6091 non-null float64
# fastestLapTime     5922 non-null object
# fastestLapSpeed    5922 non-null float64
# statusId           24340 non-null int64
# dtypes: float64(7), int64(8), object(3)
# memory usage: 3.3+ MB

# %% [markdown]
# We're starting with the results table. Columns on this I'm interested in:
#
# * **raceId**: the unique Id for the race
# * **driverId**: the unique Id for the driver
# * **constructorId**: the unique Id for the constructor(team)
# * **grid**: the driver's grid position (where they start the race)
# * **position**: the driver's finishing position as an float if the driver finished the race.
# * **positionText**: the driver's finishing position as text. This gives us more information about whether the driver finished or not.
# * **positionOrder**: the driver's finishing position in order from first to last for a given race. Usually the driver who retires first in the race is last and then the orders go up. Ordering takes into account if the driver withdrew, failed to qualify, was excluded from the final positions, or other such situations.
# * **points**: the number of points the driver got. Formula1 has changed the point systems several times since 1950. In this case points are awarded based on the season of the race.
# * **status**: information about the driver's finishing position. Wether they finished, retired, withdrew, had a collission, etc. It can also give us information about the car component that went wrong and caused a retirement.
#
# To this subset I want to add more information about the race, the driver and the constructor. I'll begin with the race information.
#
# Before that I'll make a copy of the results table to which I will add things.

# %%
master = results[["raceId", "driverId", "constructorId", "grid", "position", "positionText","positionOrder", "points", "statusId"]]

# %%
master.head()
# Out:
#    raceId  driverId  constructorId  grid  position positionText  \
# 0      18         1              1     1       1.0            1
# 1      18         2              2     5       2.0            2
# 2      18         3              3     7       3.0            3
# 3      18         4              4    11       4.0            4
# 4      18         5              1     3       5.0            5
#
#    positionOrder  points  statusId
# 0              1    10.0         1
# 1              2     8.0         1
# 2              3     6.0         1
# 3              4     5.0         1
# 4              5     4.0         1

# %% [markdown]
# ### Adding more race information

# %%
races = pd.read_csv("../data/source/races.csv")

# %%
races.head()
# Out:
#    raceId  year  round  circuitId                   name        date  \
# 0       1  2009      1          1  Australian Grand Prix  2009-03-29
# 1       2  2009      2          2   Malaysian Grand Prix  2009-04-05
# 2       3  2009      3         17     Chinese Grand Prix  2009-04-19
# 3       4  2009      4          3     Bahrain Grand Prix  2009-04-26
# 4       5  2009      5          4     Spanish Grand Prix  2009-05-10
#
#        time                                                url
# 0  06:00:00  http://en.wikipedia.org/wiki/2009_Australian_G...
# 1  09:00:00  http://en.wikipedia.org/wiki/2009_Malaysian_Gr...
# 2  07:00:00  http://en.wikipedia.org/wiki/2009_Chinese_Gran...
# 3  12:00:00  http://en.wikipedia.org/wiki/2009_Bahrain_Gran...
# 4  12:00:00  http://en.wikipedia.org/wiki/2009_Spanish_Gran...

# %%
races.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1018 entries, 0 to 1017
# Data columns (total 8 columns):
# raceId       1018 non-null int64
# year         1018 non-null int64
# round        1018 non-null int64
# circuitId    1018 non-null int64
# name         1018 non-null object
# date         1018 non-null object
# time         287 non-null object
# url          1018 non-null object
# dtypes: int64(4), object(4)
# memory usage: 63.7+ KB

# %% [markdown]
# From the races table, I care about the `year`, `round`, `name` columns.

# %%
races_slice = races[["raceId", "year", "round", "name"]]

# %% [markdown]
# Changing the name of the `name` column so it's more clear that it's the name of the grand prix:

# %%
races_slice = races_slice.rename(columns = {"name": "prixName"})

# %%
races_slice.head()
# Out:
#    raceId  year  round               prixName
# 0       1  2009      1  Australian Grand Prix
# 1       2  2009      2   Malaysian Grand Prix
# 2       3  2009      3     Chinese Grand Prix
# 3       4  2009      4     Bahrain Grand Prix
# 4       5  2009      5     Spanish Grand Prix

# %% [markdown]
# I will now add this slice of the race information data to the master table:

# %%
master = master.merge(races_slice, on="raceId")

# %%
master.head()
# Out:
#    raceId  driverId  constructorId  grid  position positionText  \
# 0      18         1              1     1       1.0            1
# 1      18         2              2     5       2.0            2
# 2      18         3              3     7       3.0            3
# 3      18         4              4    11       4.0            4
# 4      18         5              1     3       5.0            5
#
#    positionOrder  points  statusId  year  round               prixName
# 0              1    10.0         1  2008      1  Australian Grand Prix
# 1              2     8.0         1  2008      1  Australian Grand Prix
# 2              3     6.0         1  2008      1  Australian Grand Prix
# 3              4     5.0         1  2008      1  Australian Grand Prix
# 4              5     4.0         1  2008      1  Australian Grand Prix

# %% [markdown]
# ### Adding more driver information

# %%
drivers = pd.read_csv("../data/source/driver.csv")

# %%
drivers.head()
# Out:
#    driverId   driverRef  number code  forename     surname         dob  \
# 0         1    hamilton    44.0  HAM     Lewis    Hamilton  1985-01-07
# 1         2    heidfeld     NaN  HEI      Nick    Heidfeld  1977-05-10
# 2         3     rosberg     6.0  ROS      Nico     Rosberg  1985-06-27
# 3         4      alonso    14.0  ALO  Fernando      Alonso  1981-07-29
# 4         5  kovalainen     NaN  KOV    Heikki  Kovalainen  1981-10-19
#
#   nationality                                             url
# 0     British     http://en.wikipedia.org/wiki/Lewis_Hamilton
# 1      German      http://en.wikipedia.org/wiki/Nick_Heidfeld
# 2      German       http://en.wikipedia.org/wiki/Nico_Rosberg
# 3     Spanish    http://en.wikipedia.org/wiki/Fernando_Alonso
# 4     Finnish  http://en.wikipedia.org/wiki/Heikki_Kovalainen

# %%
drivers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 847 entries, 0 to 846
# Data columns (total 9 columns):
# driverId       847 non-null int64
# driverRef      847 non-null object
# number         44 non-null float64
# code           90 non-null object
# forename       847 non-null object
# surname        847 non-null object
# dob            847 non-null object
# nationality    847 non-null object
# url            846 non-null object
# dtypes: float64(1), int64(1), object(7)
# memory usage: 59.6+ KB

# %% [markdown]
# I'm interested in the `forename`, and `surname` columns.

# %%
drivers_slice = drivers[["driverId", "forename", "surname"]]

# %%
drivers_slice.head()
# Out:
#    driverId  forename     surname
# 0         1     Lewis    Hamilton
# 1         2      Nick    Heidfeld
# 2         3      Nico     Rosberg
# 3         4  Fernando      Alonso
# 4         5    Heikki  Kovalainen

# %%
master = master.merge(drivers_slice, on="driverId")

# %%
master.head()
# Out:
#    raceId  driverId  constructorId  grid  position positionText  \
# 0      18         1              1     1       1.0            1
# 1      19         1              1     9       5.0            5
# 2      20         1              1     3      13.0           13
# 3      21         1              1     5       3.0            3
# 4      22         1              1     3       2.0            2
#
#    positionOrder  points  statusId  year  round               prixName  \
# 0              1    10.0         1  2008      1  Australian Grand Prix
# 1              5     4.0         1  2008      2   Malaysian Grand Prix
# 2             13     0.0        11  2008      3     Bahrain Grand Prix
# 3              3     6.0         1  2008      4     Spanish Grand Prix
# 4              2     8.0         1  2008      5     Turkish Grand Prix
#
#   forename   surname
# 0    Lewis  Hamilton
# 1    Lewis  Hamilton
# 2    Lewis  Hamilton
# 3    Lewis  Hamilton
# 4    Lewis  Hamilton

# %% [markdown]
# ### Adding constructor information

# %%
constructors = pd.read_csv("../data/source/constructors.csv")

# %%
constructors.head()
# Out:
#    constructorId constructorRef        name nationality  \
# 0              1        mclaren     McLaren     British
# 1              2     bmw_sauber  BMW Sauber      German
# 2              3       williams    Williams     British
# 3              4        renault     Renault      French
# 4              5     toro_rosso  Toro Rosso     Italian
#
#                                                  url
# 0               http://en.wikipedia.org/wiki/McLaren
# 1            http://en.wikipedia.org/wiki/BMW_Sauber
# 2  http://en.wikipedia.org/wiki/Williams_Grand_Pr...
# 3  http://en.wikipedia.org/wiki/Renault_in_Formul...
# 4   http://en.wikipedia.org/wiki/Scuderia_Toro_Rosso

# %%
constructors.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 209 entries, 0 to 208
# Data columns (total 5 columns):
# constructorId     209 non-null int64
# constructorRef    209 non-null object
# name              209 non-null object
# nationality       209 non-null object
# url               209 non-null object
# dtypes: int64(1), object(4)
# memory usage: 8.2+ KB

# %% [markdown]
# For these, I'm interested in both the `constructorRef`, a shortname for each constructor, and the constructor `name`.

# %%
constructors_slice = constructors[["constructorId", "constructorRef", "name"]]

# %% [markdown]
# Changing the name of the `name` column so it is more clear that it's the name of the constructor

# %%
constructors_slice = constructors_slice.rename(columns = {"name": "constructor"})

# %%
constructors_slice.head()
# Out:
#    constructorId constructorRef constructor
# 0              1        mclaren     McLaren
# 1              2     bmw_sauber  BMW Sauber
# 2              3       williams    Williams
# 3              4        renault     Renault
# 4              5     toro_rosso  Toro Rosso

# %%
master = master.merge(constructors_slice, on="constructorId")

# %%
master.head()
# Out:
#    raceId  driverId  constructorId  grid  position positionText  \
# 0      18         1              1     1       1.0            1
# 1      19         1              1     9       5.0            5
# 2      20         1              1     3      13.0           13
# 3      21         1              1     5       3.0            3
# 4      22         1              1     3       2.0            2
#
#    positionOrder  points  statusId  year  round               prixName  \
# 0              1    10.0         1  2008      1  Australian Grand Prix
# 1              5     4.0         1  2008      2   Malaysian Grand Prix
# 2             13     0.0        11  2008      3     Bahrain Grand Prix
# 3              3     6.0         1  2008      4     Spanish Grand Prix
# 4              2     8.0         1  2008      5     Turkish Grand Prix
#
#   forename   surname constructorRef constructor
# 0    Lewis  Hamilton        mclaren     McLaren
# 1    Lewis  Hamilton        mclaren     McLaren
# 2    Lewis  Hamilton        mclaren     McLaren
# 3    Lewis  Hamilton        mclaren     McLaren
# 4    Lewis  Hamilton        mclaren     McLaren

# %% [markdown]
# ### Adding status information

# %%
status = pd.read_csv("../data/source/status.csv")

# %%
status.head()
# Out:
#    statusId        status
# 0         1      Finished
# 1         2  Disqualified
# 2         3      Accident
# 3         4     Collision
# 4         5        Engine

# %%
master = master.merge(status, on="statusId")

# %%
master.head()
# Out:
#    raceId  driverId  constructorId  grid  position positionText  \
# 0      18         1              1     1       1.0            1
# 1      19         1              1     9       5.0            5
# 2      21         1              1     5       3.0            3
# 3      22         1              1     3       2.0            2
# 4      23         1              1     3       1.0            1
#
#    positionOrder  points  statusId  year  round               prixName  \
# 0              1    10.0         1  2008      1  Australian Grand Prix
# 1              5     4.0         1  2008      2   Malaysian Grand Prix
# 2              3     6.0         1  2008      4     Spanish Grand Prix
# 3              2     8.0         1  2008      5     Turkish Grand Prix
# 4              1    10.0         1  2008      6      Monaco Grand Prix
#
#   forename   surname constructorRef constructor    status
# 0    Lewis  Hamilton        mclaren     McLaren  Finished
# 1    Lewis  Hamilton        mclaren     McLaren  Finished
# 2    Lewis  Hamilton        mclaren     McLaren  Finished
# 3    Lewis  Hamilton        mclaren     McLaren  Finished
# 4    Lewis  Hamilton        mclaren     McLaren  Finished

# %% [markdown]
# ---
#
# Now that my master dataFrame is set, let me rearrange the columns and save it to a csv file to work with in the analysis. Some columns—`statusId`, `constructorId`—are not needed.

# %%
master = master[["raceId", "year", "round", "prixName","constructor","constructorRef", "forename", "surname", "grid", "position", "positionText", "positionOrder", "points","status"]]

# %%
master.head()
# Out:
#    raceId  year  round               prixName constructor constructorRef  \
# 0      18  2008      1  Australian Grand Prix     McLaren        mclaren
# 1      19  2008      2   Malaysian Grand Prix     McLaren        mclaren
# 2      21  2008      4     Spanish Grand Prix     McLaren        mclaren
# 3      22  2008      5     Turkish Grand Prix     McLaren        mclaren
# 4      23  2008      6      Monaco Grand Prix     McLaren        mclaren
#
#   forename   surname  grid  position positionText  positionOrder  points  \
# 0    Lewis  Hamilton     1       1.0            1              1    10.0
# 1    Lewis  Hamilton     9       5.0            5              5     4.0
# 2    Lewis  Hamilton     5       3.0            3              3     6.0
# 3    Lewis  Hamilton     3       2.0            2              2     8.0
# 4    Lewis  Hamilton     3       1.0            1              1    10.0
#
#      status
# 0  Finished
# 1  Finished
# 2  Finished
# 3  Finished
# 4  Finished

# %% [markdown]
# I'm considering adding some new columns to clarify and combine fields:
# 1. one that has the full name of the driver `(forename + surname)`
# 1. one that has the full name of the grand prix `(year + prixName)`
#
# I will leave this for later because it doesn't seem as necessary right now (and I think I can do it when I'm working with D3).
#
# I will go ahead and sort the table by `year` > `round` > `positionOrder` so the first entry is the first position of the first race in 1950 and the last entry is the last position of the most recent race.

# %%
master = master.sort_values(by=["year", "round","positionOrder"])

# %%
master.head()
# Out:
#        raceId  year  round            prixName  constructor constructorRef  \
# 3886      833  1950      1  British Grand Prix   Alfa Romeo           alfa
# 3893      833  1950      1  British Grand Prix   Alfa Romeo           alfa
# 3891      833  1950      1  British Grand Prix   Alfa Romeo           alfa
# 17599     833  1950      1  British Grand Prix  Talbot-Lago           lago
# 17596     833  1950      1  British Grand Prix  Talbot-Lago           lago
#
#       forename    surname  grid  position positionText  positionOrder  points  \
# 3886      Nino     Farina     1       1.0            1              1     9.0
# 3893     Luigi    Fagioli     2       2.0            2              2     6.0
# 3891       Reg    Parnell     4       3.0            3              3     4.0
# 17599     Yves  Cabantous     6       4.0            4              4     3.0
# 17596    Louis     Rosier     9       5.0            5              5     2.0
#
#          status
# 3886   Finished
# 3893   Finished
# 3891   Finished
# 17599   +2 Laps
# 17596   +2 Laps

# %%
master.tail()
# Out:
#        raceId  year  round             prixName   constructor constructorRef  \
# 16219    1016  2019      7  Canadian Grand Prix      Williams       williams
# 17346    1016  2019      7  Canadian Grand Prix  Haas F1 Team           haas
# 21233    1016  2019      7  Canadian Grand Prix      Williams       williams
# 16057    1016  2019      7  Canadian Grand Prix    Toro Rosso     toro_rosso
# 16019    1016  2019      7  Canadian Grand Prix       McLaren        mclaren
#
#         forename    surname  grid  position positionText  positionOrder  \
# 16219     George    Russell    18      16.0           16             16
# 17346      Kevin  Magnussen     0      17.0           17             17
# 21233     Robert     Kubica    19      18.0           18             18
# 16057  Alexander      Albon    13       NaN            R             19
# 16019      Lando     Norris     8       NaN            R             20
#
#        points   status
# 16219     0.0  +2 Laps
# 17346     0.0  +2 Laps
# 21233     0.0  +3 Laps
# 16057     0.0  Retired
# 16019     0.0  Retired

# %% [markdown]
# Ready for saving:

# %%
master.to_csv("../data/working/master_results.csv", index=False, mode="w+")

# %% [markdown]
# ---
#
# ## [03] Slicing the master table
#
# I want to create a slice of the master table that only has information from the teams that won the championship. I think this will be a good way to minimize the amount of de-duplication I need to do.
#
# I have a csv file in the `/working` folder of the year and team the championship driver drove for, `championship_teams.csv`

# %%
champions = pd.read_csv("../data/working/championship_teams.csv")

# %%
champions.head()
# Out:
#    year constructor
# 0  1950  Alfa Romeo
# 1  1951  Alfa Romeo
# 2  1952     Ferrari
# 3  1953     Ferrari
# 4  1954    Mercedes

# %%
champions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 69 entries, 0 to 68
# Data columns (total 2 columns):
# year           69 non-null int64
# constructor    69 non-null object
# dtypes: int64(1), object(1)
# memory usage: 1.2+ KB

# %%
master.head()
# Out:
#        raceId  year  round            prixName  constructor constructorRef  \
# 3886      833  1950      1  British Grand Prix   Alfa Romeo           alfa
# 3893      833  1950      1  British Grand Prix   Alfa Romeo           alfa
# 3891      833  1950      1  British Grand Prix   Alfa Romeo           alfa
# 17599     833  1950      1  British Grand Prix  Talbot-Lago           lago
# 17596     833  1950      1  British Grand Prix  Talbot-Lago           lago
#
#       forename    surname  grid  position positionText  positionOrder  points  \
# 3886      Nino     Farina     1       1.0            1              1     9.0
# 3893     Luigi    Fagioli     2       2.0            2              2     6.0
# 3891       Reg    Parnell     4       3.0            3              3     4.0
# 17599     Yves  Cabantous     6       4.0            4              4     3.0
# 17596    Louis     Rosier     9       5.0            5              5     2.0
#
#          status
# 3886   Finished
# 3893   Finished
# 3891   Finished
# 17599   +2 Laps
# 17596   +2 Laps

# %%
comparison = pd.merge(master, champions, on=["year","constructor"], how="left", indicator="Winner")

# %%
comparison.head()
# Out:
#    raceId  year  round            prixName  constructor constructorRef  \
# 0     833  1950      1  British Grand Prix   Alfa Romeo           alfa
# 1     833  1950      1  British Grand Prix   Alfa Romeo           alfa
# 2     833  1950      1  British Grand Prix   Alfa Romeo           alfa
# 3     833  1950      1  British Grand Prix  Talbot-Lago           lago
# 4     833  1950      1  British Grand Prix  Talbot-Lago           lago
#
#   forename    surname  grid  position positionText  positionOrder  points  \
# 0     Nino     Farina     1       1.0            1              1     9.0
# 1    Luigi    Fagioli     2       2.0            2              2     6.0
# 2      Reg    Parnell     4       3.0            3              3     4.0
# 3     Yves  Cabantous     6       4.0            4              4     3.0
# 4    Louis     Rosier     9       5.0            5              5     2.0
#
#      status     Winner
# 0  Finished       both
# 1  Finished       both
# 2  Finished       both
# 3   +2 Laps  left_only
# 4   +2 Laps  left_only

# %%
master_slice = comparison[comparison.Winner == "both"]

# %%
master_slice.head(40)
# Out:
#      raceId  year  round            prixName constructor constructorRef  \
# 0       833  1950      1  British Grand Prix  Alfa Romeo           alfa
# 1       833  1950      1  British Grand Prix  Alfa Romeo           alfa
# 2       833  1950      1  British Grand Prix  Alfa Romeo           alfa
# 12      833  1950      1  British Grand Prix  Alfa Romeo           alfa
# 23      834  1950      2   Monaco Grand Prix  Alfa Romeo           alfa
# 33      834  1950      2   Monaco Grand Prix  Alfa Romeo           alfa
# 34      834  1950      2   Monaco Grand Prix  Alfa Romeo           alfa
# 79      836  1950      4    Swiss Grand Prix  Alfa Romeo           alfa
# 80      836  1950      4    Swiss Grand Prix  Alfa Romeo           alfa
# 90      836  1950      4    Swiss Grand Prix  Alfa Romeo           alfa
# 97      837  1950      5  Belgian Grand Prix  Alfa Romeo           alfa
# 98      837  1950      5  Belgian Grand Prix  Alfa Romeo           alfa
# 100     837  1950      5  Belgian Grand Prix  Alfa Romeo           alfa
# 111     838  1950      6   French Grand Prix  Alfa Romeo           alfa
# 112     838  1950      6   French Grand Prix  Alfa Romeo           alfa
# 119     838  1950      6   French Grand Prix  Alfa Romeo           alfa
# 131     839  1950      7  Italian Grand Prix  Alfa Romeo           alfa
# 133     839  1950      7  Italian Grand Prix  Alfa Romeo           alfa
# 134     839  1950      7  Italian Grand Prix  Alfa Romeo           alfa
# 144     839  1950      7  Italian Grand Prix  Alfa Romeo           alfa
# 145     839  1950      7  Italian Grand Prix  Alfa Romeo           alfa
# 147     839  1950      7  Italian Grand Prix  Alfa Romeo           alfa
# 155     839  1950      7  Italian Grand Prix  Alfa Romeo           alfa
# 160     825  1951      1    Swiss Grand Prix  Alfa Romeo           alfa
# 162     825  1951      1    Swiss Grand Prix  Alfa Romeo           alfa
# 163     825  1951      1    Swiss Grand Prix  Alfa Romeo           alfa
# 164     825  1951      1    Swiss Grand Prix  Alfa Romeo           alfa
# 215     827  1951      3  Belgian Grand Prix  Alfa Romeo           alfa
# 223     827  1951      3  Belgian Grand Prix  Alfa Romeo           alfa
# 225     827  1951      3  Belgian Grand Prix  Alfa Romeo           alfa
# 228     828  1951      4   French Grand Prix  Alfa Romeo           alfa
# 229     828  1951      4   French Grand Prix  Alfa Romeo           alfa
# 234     828  1951      4   French Grand Prix  Alfa Romeo           alfa
# 239     828  1951      4   French Grand Prix  Alfa Romeo           alfa
# 240     828  1951      4   French Grand Prix  Alfa Romeo           alfa
# 241     828  1951      4   French Grand Prix  Alfa Romeo           alfa
# 255     829  1951      5  British Grand Prix  Alfa Romeo           alfa
# 257     829  1951      5  British Grand Prix  Alfa Romeo           alfa
# 259     829  1951      5  British Grand Prix  Alfa Romeo           alfa
# 267     829  1951      5  British Grand Prix  Alfa Romeo           alfa
#
#      forename         surname  grid  position positionText  positionOrder  \
# 0        Nino          Farina     1       1.0            1              1
# 1       Luigi         Fagioli     2       2.0            2              2
# 2         Reg         Parnell     4       3.0            3              3
# 12       Juan          Fangio     3       NaN            R             12
# 23       Juan          Fangio     1       1.0            1              1
# 33       Nino          Farina     2       NaN            R             11
# 34      Luigi         Fagioli     5       NaN            R             12
# 79       Nino          Farina     2       1.0            1              1
# 80      Luigi         Fagioli     3       2.0            2              2
# 90       Juan          Fangio     1       NaN            R             12
# 97       Juan          Fangio     2       1.0            1              1
# 98      Luigi         Fagioli     3       2.0            2              2
# 100      Nino          Farina     1       4.0            4              4
# 111      Juan          Fangio     1       1.0            1              1
# 112     Luigi         Fagioli     3       2.0            2              2
# 119      Nino          Farina     2       7.0            7              7
# 131      Nino          Farina     3       1.0            1              1
# 133   Alberto          Ascari     6       2.0            2              2
# 134     Luigi         Fagioli     5       3.0            3              3
# 144      Juan          Fangio     7       NaN            R             13
# 145     Piero         Taruffi     7       NaN            R             13
# 147      Juan          Fangio     1       NaN            R             15
# 155  Consalvo          Sanesi     4       NaN            R             23
# 160      Juan          Fangio     1       1.0            1              1
# 162      Nino          Farina     2       3.0            3              3
# 163  Consalvo          Sanesi     4       4.0            4              4
# 164     Toulo  de Graffenried     5       5.0            5              5
# 215      Nino          Farina     2       1.0            1              1
# 223      Juan          Fangio     1       9.0            9              9
# 225  Consalvo          Sanesi     6       NaN            R             11
# 228      Juan          Fangio     7       1.0            1              1
# 229     Luigi         Fagioli     7       1.0            1              1
# 234      Nino          Farina     2       5.0            5              5
# 239  Consalvo          Sanesi     5      10.0           10             10
# 240      Juan          Fangio     1      11.0           11             11
# 241     Luigi         Fagioli     1      11.0           11             11
# 255      Juan          Fangio     2       2.0            2              2
# 257    Felice         Bonetto     7       4.0            4              4
# 259  Consalvo          Sanesi     6       6.0            6              6
# 267      Nino          Farina     3       NaN            R             14
#
#      points     status Winner
# 0       9.0   Finished   both
# 1       6.0   Finished   both
# 2       4.0   Finished   both
# 12      0.0   Oil leak   both
# 23      9.0   Finished   both
# 33      0.0   Accident   both
# 34      0.0   Accident   both
# 79      9.0   Finished   both
# 80      6.0   Finished   both
# 90      0.0     Engine   both
# 97      8.0   Finished   both
# 98      6.0   Finished   both
# 100     4.0   Finished   both
# 111     9.0   Finished   both
# 112     6.0   Finished   both
# 119     0.0  Fuel pump   both
# 131     8.0   Finished   both
# 133     3.0   Finished   both
# 134     4.0   Finished   both
# 144     0.0     Engine   both
# 145     0.0     Engine   both
# 147     1.0    Gearbox   both
# 155     0.0     Engine   both
# 160     9.0   Finished   both
# 162     4.0   Finished   both
# 163     3.0     +1 Lap   both
# 164     2.0    +2 Laps   both
# 215     8.0   Finished   both
# 223     1.0    +4 Laps   both
# 225     0.0   Radiator   both
# 228     5.0   Finished   both
# 229     4.0   Finished   both
# 234     2.0    +4 Laps   both
# 239     0.0   +19 Laps   both
# 240     0.0   +22 Laps   both
# 241     0.0   +22 Laps   both
# 255     6.0   Finished   both
# 257     3.0    +3 Laps   both
# 259     0.0    +6 Laps   both
# 267     1.0     Clutch   both

# %%
master_slice.tail(42)
# Out:
#        raceId  year  round                  prixName constructor  \
# 23781     989  2018      1     Australian Grand Prix    Mercedes
# 23787     989  2018      1     Australian Grand Prix    Mercedes
# 23801     990  2018      2        Bahrain Grand Prix    Mercedes
# 23802     990  2018      2        Bahrain Grand Prix    Mercedes
# 23821     991  2018      3        Chinese Grand Prix    Mercedes
# 23823     991  2018      3        Chinese Grand Prix    Mercedes
# 23840     992  2018      4     Azerbaijan Grand Prix    Mercedes
# 23853     992  2018      4     Azerbaijan Grand Prix    Mercedes
# 23860     993  2018      5        Spanish Grand Prix    Mercedes
# 23861     993  2018      5        Spanish Grand Prix    Mercedes
# 23882     994  2018      6         Monaco Grand Prix    Mercedes
# 23884     994  2018      6         Monaco Grand Prix    Mercedes
# 23901     995  2018      7       Canadian Grand Prix    Mercedes
# 23904     995  2018      7       Canadian Grand Prix    Mercedes
# 23920     996  2018      8         French Grand Prix    Mercedes
# 23926     996  2018      8         French Grand Prix    Mercedes
# 23955     997  2018      9       Austrian Grand Prix    Mercedes
# 23958     997  2018      9       Austrian Grand Prix    Mercedes
# 23961     998  2018     10        British Grand Prix    Mercedes
# 23963     998  2018     10        British Grand Prix    Mercedes
# 23980     999  2018     11         German Grand Prix    Mercedes
# 23981     999  2018     11         German Grand Prix    Mercedes
# 24000    1000  2018     12      Hungarian Grand Prix    Mercedes
# 24004    1000  2018     12      Hungarian Grand Prix    Mercedes
# 24021    1001  2018     13        Belgian Grand Prix    Mercedes
# 24023    1001  2018     13        Belgian Grand Prix    Mercedes
# 24040    1002  2018     14        Italian Grand Prix    Mercedes
# 24042    1002  2018     14        Italian Grand Prix    Mercedes
# 24060    1003  2018     15      Singapore Grand Prix    Mercedes
# 24063    1003  2018     15      Singapore Grand Prix    Mercedes
# 24080    1004  2018     16        Russian Grand Prix    Mercedes
# 24081    1004  2018     16        Russian Grand Prix    Mercedes
# 24100    1005  2018     17       Japanese Grand Prix    Mercedes
# 24101    1005  2018     17       Japanese Grand Prix    Mercedes
# 24122    1006  2018     18  United States Grand Prix    Mercedes
# 24124    1006  2018     18  United States Grand Prix    Mercedes
# 24143    1007  2018     19        Mexican Grand Prix    Mercedes
# 24144    1007  2018     19        Mexican Grand Prix    Mercedes
# 24160    1008  2018     20      Brazilian Grand Prix    Mercedes
# 24164    1008  2018     20      Brazilian Grand Prix    Mercedes
# 24180    1009  2018     21      Abu Dhabi Grand Prix    Mercedes
# 24184    1009  2018     21      Abu Dhabi Grand Prix    Mercedes
#
#       constructorRef  forename   surname  grid  position positionText  \
# 23781       mercedes     Lewis  Hamilton     1       2.0            2
# 23787       mercedes  Valtteri    Bottas    15       8.0            8
# 23801       mercedes  Valtteri    Bottas     3       2.0            2
# 23802       mercedes     Lewis  Hamilton     9       3.0            3
# 23821       mercedes  Valtteri    Bottas     3       2.0            2
# 23823       mercedes     Lewis  Hamilton     4       4.0            4
# 23840       mercedes     Lewis  Hamilton     2       1.0            1
# 23853       mercedes  Valtteri    Bottas     3       NaN            R
# 23860       mercedes     Lewis  Hamilton     1       1.0            1
# 23861       mercedes  Valtteri    Bottas     2       2.0            2
# 23882       mercedes     Lewis  Hamilton     3       3.0            3
# 23884       mercedes  Valtteri    Bottas     5       5.0            5
# 23901       mercedes  Valtteri    Bottas     2       2.0            2
# 23904       mercedes     Lewis  Hamilton     4       5.0            5
# 23920       mercedes     Lewis  Hamilton     1       1.0            1
# 23926       mercedes  Valtteri    Bottas     2       7.0            7
# 23955       mercedes     Lewis  Hamilton     2       NaN            R
# 23958       mercedes  Valtteri    Bottas     1       NaN            R
# 23961       mercedes     Lewis  Hamilton     1       2.0            2
# 23963       mercedes  Valtteri    Bottas     4       4.0            4
# 23980       mercedes     Lewis  Hamilton    14       1.0            1
# 23981       mercedes  Valtteri    Bottas     2       2.0            2
# 24000       mercedes     Lewis  Hamilton     1       1.0            1
# 24004       mercedes  Valtteri    Bottas     2       5.0            5
# 24021       mercedes     Lewis  Hamilton     1       2.0            2
# 24023       mercedes  Valtteri    Bottas    19       4.0            4
# 24040       mercedes     Lewis  Hamilton     3       1.0            1
# 24042       mercedes  Valtteri    Bottas     4       3.0            3
# 24060       mercedes     Lewis  Hamilton     1       1.0            1
# 24063       mercedes  Valtteri    Bottas     4       4.0            4
# 24080       mercedes     Lewis  Hamilton     2       1.0            1
# 24081       mercedes  Valtteri    Bottas     1       2.0            2
# 24100       mercedes     Lewis  Hamilton     1       1.0            1
# 24101       mercedes  Valtteri    Bottas     2       2.0            2
# 24122       mercedes     Lewis  Hamilton     1       3.0            3
# 24124       mercedes  Valtteri    Bottas     3       5.0            5
# 24143       mercedes     Lewis  Hamilton     3       4.0            4
# 24144       mercedes  Valtteri    Bottas     5       5.0            5
# 24160       mercedes     Lewis  Hamilton     1       1.0            1
# 24164       mercedes  Valtteri    Bottas     3       5.0            5
# 24180       mercedes     Lewis  Hamilton     1       1.0            1
# 24184       mercedes  Valtteri    Bottas     2       5.0            5
#
#        positionOrder  points         status Winner
# 23781              2    18.0       Finished   both
# 23787              8     4.0       Finished   both
# 23801              2    18.0       Finished   both
# 23802              3    15.0       Finished   both
# 23821              2    18.0       Finished   both
# 23823              4    12.0       Finished   both
# 23840              1    25.0       Finished   both
# 23853             14     0.0       Puncture   both
# 23860              1    25.0       Finished   both
# 23861              2    18.0       Finished   both
# 23882              3    15.0       Finished   both
# 23884              5    10.0       Finished   both
# 23901              2    18.0       Finished   both
# 23904              5    10.0       Finished   both
# 23920              1    25.0       Finished   both
# 23926              7     6.0       Finished   both
# 23955             16     0.0  Fuel pressure   both
# 23958             19     0.0     Hydraulics   both
# 23961              2    18.0       Finished   both
# 23963              4    12.0       Finished   both
# 23980              1    25.0       Finished   both
# 23981              2    18.0       Finished   both
# 24000              1    25.0       Finished   both
# 24004              5    10.0       Finished   both
# 24021              2    18.0       Finished   both
# 24023              4    12.0       Finished   both
# 24040              1    25.0       Finished   both
# 24042              3    15.0       Finished   both
# 24060              1    25.0       Finished   both
# 24063              4    12.0       Finished   both
# 24080              1    25.0       Finished   both
# 24081              2    18.0       Finished   both
# 24100              1    25.0       Finished   both
# 24101              2    18.0       Finished   both
# 24122              3    15.0       Finished   both
# 24124              5    10.0       Finished   both
# 24143              4    12.0       Finished   both
# 24144              5    10.0         +1 Lap   both
# 24160              1    25.0       Finished   both
# 24164              5    10.0       Finished   both
# 24180              1    25.0       Finished   both
# 24184              5    10.0       Finished   both

# %% [markdown]
# This slice looks good. Let's drop the `Winner` column used for comparison.

# %%
master_slice = master_slice.drop(columns=["Winner"])

# %%
master_slice.head()
# Out:
#     raceId  year  round            prixName constructor constructorRef  \
# 0      833  1950      1  British Grand Prix  Alfa Romeo           alfa
# 1      833  1950      1  British Grand Prix  Alfa Romeo           alfa
# 2      833  1950      1  British Grand Prix  Alfa Romeo           alfa
# 12     833  1950      1  British Grand Prix  Alfa Romeo           alfa
# 23     834  1950      2   Monaco Grand Prix  Alfa Romeo           alfa
#
#    forename  surname  grid  position positionText  positionOrder  points  \
# 0      Nino   Farina     1       1.0            1              1     9.0
# 1     Luigi  Fagioli     2       2.0            2              2     6.0
# 2       Reg  Parnell     4       3.0            3              3     4.0
# 12     Juan   Fangio     3       NaN            R             12     0.0
# 23     Juan   Fangio     1       1.0            1              1     9.0
#
#       status
# 0   Finished
# 1   Finished
# 2   Finished
# 12  Oil leak
# 23  Finished

# %%
master_slice.to_csv("../data/working/master_results_champions.csv", index=False, mode="w+")

# %% [markdown]
# ---
#
# ## [04] Removing driver info
#
# When handling some of the early races, there were instances of drivers sharing or switching cars and then sharing finishes (they split the points). Let me see if I remove that and keep just the position, and team information in a separate set of dataFrames.

# %%
master.head()
# Out:
#        raceId  year  round            prixName  constructor constructorRef  \
# 3886      833  1950      1  British Grand Prix   Alfa Romeo           alfa
# 3893      833  1950      1  British Grand Prix   Alfa Romeo           alfa
# 3891      833  1950      1  British Grand Prix   Alfa Romeo           alfa
# 17599     833  1950      1  British Grand Prix  Talbot-Lago           lago
# 17596     833  1950      1  British Grand Prix  Talbot-Lago           lago
#
#       forename    surname  grid  position positionText  positionOrder  points  \
# 3886      Nino     Farina     1       1.0            1              1     9.0
# 3893     Luigi    Fagioli     2       2.0            2              2     6.0
# 3891       Reg    Parnell     4       3.0            3              3     4.0
# 17599     Yves  Cabantous     6       4.0            4              4     3.0
# 17596    Louis     Rosier     9       5.0            5              5     2.0
#
#          status
# 3886   Finished
# 3893   Finished
# 3891   Finished
# 17599   +2 Laps
# 17596   +2 Laps

# %% [markdown]
# Looking at master, I want to remove the `forename`, `surname`, `grid`, `points`, `status` columns

# %%
master_noDriver = master.copy().drop(columns=["forename", "surname", "grid", "points", "status"])

# %%
master_noDriver.head()
# Out:
#        raceId  year  round            prixName  constructor constructorRef  \
# 3886      833  1950      1  British Grand Prix   Alfa Romeo           alfa
# 3893      833  1950      1  British Grand Prix   Alfa Romeo           alfa
# 3891      833  1950      1  British Grand Prix   Alfa Romeo           alfa
# 17599     833  1950      1  British Grand Prix  Talbot-Lago           lago
# 17596     833  1950      1  British Grand Prix  Talbot-Lago           lago
#
#        position positionText  positionOrder
# 3886        1.0            1              1
# 3893        2.0            2              2
# 3891        3.0            3              3
# 17599       4.0            4              4
# 17596       5.0            5              5

# %% [markdown]
# I will also do this to the slice of the master results for the championship teams:

# %%
master_slice_noDriver = master_slice.copy().drop(columns=["forename", "surname", "grid", "points", "status"])

# %%
master_slice_noDriver.head()
# Out:
#     raceId  year  round            prixName constructor constructorRef  \
# 0      833  1950      1  British Grand Prix  Alfa Romeo           alfa
# 1      833  1950      1  British Grand Prix  Alfa Romeo           alfa
# 2      833  1950      1  British Grand Prix  Alfa Romeo           alfa
# 12     833  1950      1  British Grand Prix  Alfa Romeo           alfa
# 23     834  1950      2   Monaco Grand Prix  Alfa Romeo           alfa
#
#     position positionText  positionOrder
# 0        1.0            1              1
# 1        2.0            2              2
# 2        3.0            3              3
# 12       NaN            R             12
# 23       1.0            1              1

# %% [markdown]
# I will take the moment to also look at the duplicates in these two.

# %% [markdown]
# ### [04.5] Cleaning duplicates
#
# Let's look at `master_noDriver` and `master_slice_noDriver` and try to clean the duplicates.

# %%
master_slice_noDriver.head()
# Out:
#     raceId  year  round            prixName constructor constructorRef  \
# 0      833  1950      1  British Grand Prix  Alfa Romeo           alfa
# 1      833  1950      1  British Grand Prix  Alfa Romeo           alfa
# 2      833  1950      1  British Grand Prix  Alfa Romeo           alfa
# 12     833  1950      1  British Grand Prix  Alfa Romeo           alfa
# 23     834  1950      2   Monaco Grand Prix  Alfa Romeo           alfa
#
#     position positionText  positionOrder
# 0        1.0            1              1
# 1        2.0            2              2
# 2        3.0            3              3
# 12       NaN            R             12
# 23       1.0            1              1

# %%
master_slice_noDriver.duplicated().value_counts()
# Out:
# False    2350
# True       21
# dtype: int64

# %% [markdown]
# It seems like there are 21 lines that are duplicated. Let's check them out

# %%
a = master_slice_noDriver.copy()

# %%
a["Duplicate"] = a.duplicated(keep=False).map({True:'Yes', False:'No'})

# %%
a.head(30)
# Out:
#      raceId  year  round            prixName constructor constructorRef  \
# 0       833  1950      1  British Grand Prix  Alfa Romeo           alfa
# 1       833  1950      1  British Grand Prix  Alfa Romeo           alfa
# 2       833  1950      1  British Grand Prix  Alfa Romeo           alfa
# 12      833  1950      1  British Grand Prix  Alfa Romeo           alfa
# 23      834  1950      2   Monaco Grand Prix  Alfa Romeo           alfa
# 33      834  1950      2   Monaco Grand Prix  Alfa Romeo           alfa
# 34      834  1950      2   Monaco Grand Prix  Alfa Romeo           alfa
# 79      836  1950      4    Swiss Grand Prix  Alfa Romeo           alfa
# 80      836  1950      4    Swiss Grand Prix  Alfa Romeo           alfa
# 90      836  1950      4    Swiss Grand Prix  Alfa Romeo           alfa
# 97      837  1950      5  Belgian Grand Prix  Alfa Romeo           alfa
# 98      837  1950      5  Belgian Grand Prix  Alfa Romeo           alfa
# 100     837  1950      5  Belgian Grand Prix  Alfa Romeo           alfa
# 111     838  1950      6   French Grand Prix  Alfa Romeo           alfa
# 112     838  1950      6   French Grand Prix  Alfa Romeo           alfa
# 119     838  1950      6   French Grand Prix  Alfa Romeo           alfa
# 131     839  1950      7  Italian Grand Prix  Alfa Romeo           alfa
# 133     839  1950      7  Italian Grand Prix  Alfa Romeo           alfa
# 134     839  1950      7  Italian Grand Prix  Alfa Romeo           alfa
# 144     839  1950      7  Italian Grand Prix  Alfa Romeo           alfa
# 145     839  1950      7  Italian Grand Prix  Alfa Romeo           alfa
# 147     839  1950      7  Italian Grand Prix  Alfa Romeo           alfa
# 155     839  1950      7  Italian Grand Prix  Alfa Romeo           alfa
# 160     825  1951      1    Swiss Grand Prix  Alfa Romeo           alfa
# 162     825  1951      1    Swiss Grand Prix  Alfa Romeo           alfa
# 163     825  1951      1    Swiss Grand Prix  Alfa Romeo           alfa
# 164     825  1951      1    Swiss Grand Prix  Alfa Romeo           alfa
# 215     827  1951      3  Belgian Grand Prix  Alfa Romeo           alfa
# 223     827  1951      3  Belgian Grand Prix  Alfa Romeo           alfa
# 225     827  1951      3  Belgian Grand Prix  Alfa Romeo           alfa
#
#      position positionText  positionOrder Duplicate
# 0         1.0            1              1        No
# 1         2.0            2              2        No
# 2         3.0            3              3        No
# 12        NaN            R             12        No
# 23        1.0            1              1        No
# 33        NaN            R             11        No
# 34        NaN            R             12        No
# 79        1.0            1              1        No
# 80        2.0            2              2        No
# 90        NaN            R             12        No
# 97        1.0            1              1        No
# 98        2.0            2              2        No
# 100       4.0            4              4        No
# 111       1.0            1              1        No
# 112       2.0            2              2        No
# 119       7.0            7              7        No
# 131       1.0            1              1        No
# 133       2.0            2              2        No
# 134       3.0            3              3        No
# 144       NaN            R             13       Yes
# 145       NaN            R             13       Yes
# 147       NaN            R             15        No
# 155       NaN            R             23        No
# 160       1.0            1              1        No
# 162       3.0            3              3        No
# 163       4.0            4              4        No
# 164       5.0            5              5        No
# 215       1.0            1              1        No
# 223       9.0            9              9        No
# 225       NaN            R             11        No

# %%
a[a.Duplicate == "Yes"]
# Out:
#       raceId  year  round              prixName    constructor constructorRef  \
# 144      839  1950      7    Italian Grand Prix     Alfa Romeo           alfa
# 145      839  1950      7    Italian Grand Prix     Alfa Romeo           alfa
# 228      828  1951      4     French Grand Prix     Alfa Romeo           alfa
# 229      828  1951      4     French Grand Prix     Alfa Romeo           alfa
# 240      828  1951      4     French Grand Prix     Alfa Romeo           alfa
# 241      828  1951      4     French Grand Prix     Alfa Romeo           alfa
# 298      831  1951      7    Italian Grand Prix     Alfa Romeo           alfa
# 299      831  1951      7    Italian Grand Prix     Alfa Romeo           alfa
# 348      817  1952      1      Swiss Grand Prix        Ferrari        ferrari
# 349      817  1952      1      Swiss Grand Prix        Ferrari        ferrari
# 426      820  1952      4     French Grand Prix        Ferrari        ferrari
# 427      820  1952      4     French Grand Prix        Ferrari        ferrari
# 718      814  1953      7     German Grand Prix        Ferrari        ferrari
# 719      814  1953      7     German Grand Prix        Ferrari        ferrari
# 728      814  1953      7     German Grand Prix        Ferrari        ferrari
# 729      814  1953      7     German Grand Prix        Ferrari        ferrari
# 1037     792  1955      1  Argentine Grand Prix       Mercedes       mercedes
# 1038     792  1955      1  Argentine Grand Prix       Mercedes       mercedes
# 1039     792  1955      1  Argentine Grand Prix       Mercedes       mercedes
# 1210     784  1956      1  Argentine Grand Prix        Ferrari        ferrari
# 1211     784  1956      1  Argentine Grand Prix        Ferrari        ferrari
# 1227     785  1956      2     Monaco Grand Prix        Ferrari        ferrari
# 1228     785  1956      2     Monaco Grand Prix        Ferrari        ferrari
# 1230     785  1956      2     Monaco Grand Prix        Ferrari        ferrari
# 1231     785  1956      2     Monaco Grand Prix        Ferrari        ferrari
# 1320     789  1956      6    British Grand Prix        Ferrari        ferrari
# 1321     789  1956      6    British Grand Prix        Ferrari        ferrari
# 1329     789  1956      6    British Grand Prix        Ferrari        ferrari
# 1330     789  1956      6    British Grand Prix        Ferrari        ferrari
# 1372     791  1956      8    Italian Grand Prix        Ferrari        ferrari
# 1373     791  1956      8    Italian Grand Prix        Ferrari        ferrari
# 1379     791  1956      8    Italian Grand Prix        Ferrari        ferrari
# 1380     791  1956      8    Italian Grand Prix        Ferrari        ferrari
# 1425     777  1957      2     Monaco Grand Prix       Maserati       maserati
# 1426     777  1957      2     Monaco Grand Prix       Maserati       maserati
# 1555     783  1957      8    Italian Grand Prix       Maserati       maserati
# 1556     783  1957      8    Italian Grand Prix       Maserati       maserati
# 1562     783  1957      8    Italian Grand Prix       Maserati       maserati
# 1563     783  1957      8    Italian Grand Prix       Maserati       maserati
# 2009     746  1960      1  Argentine Grand Prix  Cooper-Climax  cooper-climax
# 2010     746  1960      1  Argentine Grand Prix  Cooper-Climax  cooper-climax
#
#       position positionText  positionOrder Duplicate
# 144        NaN            R             13       Yes
# 145        NaN            R             13       Yes
# 228        1.0            1              1       Yes
# 229        1.0            1              1       Yes
# 240       11.0           11             11       Yes
# 241       11.0           11             11       Yes
# 298        3.0            3              3       Yes
# 299        3.0            3              3       Yes
# 348        NaN            R             10       Yes
# 349        NaN            R             10       Yes
# 426       11.0           11             11       Yes
# 427       11.0           11             11       Yes
# 718        8.0            8              8       Yes
# 719        8.0            8              8       Yes
# 728        NaN            R             17       Yes
# 729        NaN            R             17       Yes
# 1037       4.0            4              4       Yes
# 1038       4.0            4              4       Yes
# 1039       4.0            4              4       Yes
# 1210       1.0            1              1       Yes
# 1211       1.0            1              1       Yes
# 1227       2.0            2              2       Yes
# 1228       2.0            2              2       Yes
# 1230       4.0            4              4       Yes
# 1231       4.0            4              4       Yes
# 1320       2.0            2              2       Yes
# 1321       2.0            2              2       Yes
# 1329      10.0           10             10       Yes
# 1330      10.0           10             10       Yes
# 1372       2.0            2              2       Yes
# 1373       2.0            2              2       Yes
# 1379       8.0            8              8       Yes
# 1380       8.0            8              8       Yes
# 1425       NaN            R              8       Yes
# 1426       NaN            R              8       Yes
# 1555       5.0            5              5       Yes
# 1556       5.0            5              5       Yes
# 1562      11.0           11             11       Yes
# 1563      11.0           11             11       Yes
# 2009       3.0            3              3       Yes
# 2010       3.0            3              3       Yes

# %%
a[a.Duplicate == "Yes"].shape
# Out:
# (41, 10)
